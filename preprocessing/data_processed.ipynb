# %%
# In[1]: Benötigte Pakete importieren
import pandas as pd
from pathlib import Path

# Pfad zum raw-Ordner
raw_folder = Path('processed/fixations')

# Name der Datei, die du einlesen möchtest (ohne Extension)
file_name = 'P000_id007_meme_ncc_processed_fixations'  # z.B. 'P035_id146_kategorie'
file_path = raw_folder / file_name
    
# In[2]: CSV einlesen
# Wenn deine Dateien keine .csv-Endung haben, füge sie hier explizit an:
df = pd.read_csv(f"{file_path}.csv", sep=',', header=0, encoding='utf-8')

# Oder, falls die Dateien wirklich keine Extension haben, so:
# df = pd.read_csv(file_path, sep=',', header=0, encoding='utf-8')

# In[3]: Auf die wichtigsten Spalten kürzen
# wichtige_spalten = ['Spalte1', 'Spalte2', 'Spalte3']  # ersetze durch deine Spaltennamen
# df_kurz = df[wichtige_spalten]

# In[4]: Ergebnisse anzeigen
print("Original-Shape:", df.shape)
df
# Out:
# Original-Shape: (11, 5)
#     start_time  end_time  duration           x           y
# 0        0.000   183.041   183.041  340.222958  211.222904
# 1      216.298   332.787   116.489  433.662105  230.239079
# 2      399.352   665.511   266.159  472.597729  630.843735
# 3      732.209  1397.784   665.575  446.367709  140.055741
# 4     1414.424  1697.296   282.872  447.146005  135.982642
# 5     1763.800  3278.095  1514.295  484.248045  612.793803
# 6     3294.717  3461.057   166.340  456.666158  610.237996
# 7     3527.672  4209.873   682.201  460.208914  173.656518
# 8     4343.040  4559.347   216.307  462.617343  190.007488
# 9     4659.181  4975.416   316.235  466.507027  710.451884
# 10    4991.987  5258.196   266.209  415.125910  750.337451

# %%
import os
import glob
import ast

import numpy as np
import pandas as pd

def parse_point(s):
    try:
        x, y = ast.literal_eval(s)
        return float(x), float(y)
    except Exception:
        return np.nan, np.nan

def process_file(file_path, out_dir):
    df = pd.read_csv(file_path)
    df['millisecond'] = (df['system_time_stamp'] - df['system_time_stamp'].iloc[0]) / 1000

    # 1) Erst in numeric casten, dann auf plausiblen Bereich maskieren
    df['left_pupil_diameter']  = pd.to_numeric(df['left_pupil_diameter'],  errors='coerce')
    df['right_pupil_diameter'] = pd.to_numeric(df['right_pupil_diameter'], errors='coerce')
    df['left_pupil_diameter']  = df['left_pupil_diameter'].mask(lambda x: (x < 1.5) | (x > 8), np.nan)
    df['right_pupil_diameter'] = df['right_pupil_diameter'].mask(lambda x: (x < 1.5) | (x > 8), np.nan)

    # 2) Gaze‑Parsing
    left_pts  = df['left_gaze_point_on_display_area'] .apply(parse_point)
    right_pts = df['right_gaze_point_on_display_area'].apply(parse_point)
    df[['left_x','left_y']]   = pd.DataFrame(left_pts.tolist(),  index=df.index)
    df[['right_x','right_y']] = pd.DataFrame(right_pts.tolist(), index=df.index)

    # 3) Validity‑Flags (1 = gültig)
    lv = df['left_gaze_point_validity']  != 0
    rv = df['right_gaze_point_validity'] != 0

    df['x'] = np.where(lv & rv,
                       (df['left_x'] + df['right_x']) / 2,
                       np.where(lv, df['left_x'],
                                np.where(rv, df['right_x'], np.nan)))
    df['y'] = np.where(lv & rv,
                       (df['left_y'] + df['right_y']) / 2,
                       np.where(lv, df['left_y'],
                                np.where(rv, df['right_y'], np.nan)))

    # 4) Skalierung auf 800×800 und Clamping
    df['x'] = (df['x'] * 800).clip(0, 800)
    df['y'] = (df['y'] * 800).clip(0, 800)

    # 5) Pupil-Size kombinieren und erneut plausibelkeitsprüfen
    lv_p = df['left_pupil_diameter'].notna()
    rv_p = df['right_pupil_diameter'].notna()
    df['pupil_size'] = np.where(lv_p & rv_p,
                                (df['left_pupil_diameter'] + df['right_pupil_diameter']) / 2,
                                np.where(lv_p, df['left_pupil_diameter'],
                                         np.where(rv_p, df['right_pupil_diameter'], np.nan)))
    # Optional: noch einmal maskieren, falls Mittelwert aus zwei Außenseitern entsteht
    df['pupil_size'] = df['pupil_size'].mask(lambda x: (x < 1.5) | (x > 8), np.nan)

    # 6) Interpolation und Drop
    df[['x','y','pupil_size']] = df[['x','y','pupil_size']].interpolate()
    df_clean = df.dropna(subset=['x','y','pupil_size'])

    # 7) Speichern
    base = os.path.splitext(os.path.basename(file_path))[0]
    out_path = os.path.join(out_dir, f"{base}_processed.csv")
    df_clean[['millisecond','x','y','pupil_size']].to_csv(out_path, index=False)
    print(f"→ {os.path.basename(out_path)}")

def run_processing(folder):
    processed_dir = os.path.join(folder, "processed")
    os.makedirs(processed_dir, exist_ok=True)
    for fp in glob.glob(os.path.join(folder, "*.csv")):
        process_file(fp, processed_dir)

# === Notebook-Aufruf ===
folder = "raw"  # Pfad zu deinen Roh-CSV-Dateien
run_processing(folder)
# Out:
# → P000_id001_meme_ncc_processed.csv
# → P000_id002_meme_ncc_processed.csv
# → P000_id003_meme_ncc_processed.csv
# → P000_id004_meme_ncc_processed.csv
# → P000_id005_meme_ncc_processed.csv
# → P000_id006_meme_ncc_processed.csv
# → P000_id007_meme_ncc_processed.csv
# → P000_id008_meme_ncc_processed.csv
# → P000_id009_meme_ncc_processed.csv
# → P000_id010_meme_ncc_processed.csv
# → P000_id011_ort_processed.csv
# → P000_id012_ort_processed.csv
# → P000_id013_ort_processed.csv
# → P000_id014_ort_processed.csv
# → P000_id015_ort_processed.csv
# → P000_id016_ort_processed.csv
# → P000_id017_ort_processed.csv
# → P000_id018_ort_processed.csv
# → P000_id019_ort_processed.csv
# → P000_id020_ort_processed.csv
# → P000_id021_ort_processed.csv
# → P000_id022_ort_processed.csv
# → P000_id023_ort_processed.csv
# → P000_id024_ort_processed.csv
# → P000_id025_ort_processed.csv
# → P000_id026_ort_processed.csv
# → P000_id027_ort_processed.csv
# → P000_id028_ort_processed.csv
# → P000_id029_ort_processed.csv
# → P000_id030_ort_processed.csv
# → P000_id031_ort_processed.csv
# → P000_id032_ort_processed.csv
# → P000_id033_person_processed.csv
# → P000_id034_person_processed.csv
# → P000_id035_person_processed.csv
# → P000_id036_person_processed.csv
# → P000_id037_person_processed.csv
# → P000_id038_person_processed.csv
# → P000_id039_person_processed.csv
# → P000_id040_person_processed.csv
# → P000_id041_person_processed.csv
# → P000_id042_person_processed.csv
# → P000_id043_person_processed.csv
# → P000_id044_person_processed.csv
# → P000_id045_person_processed.csv
# → P000_id046_person_processed.csv
# → P000_id047_person_processed.csv
# → P000_id048_person_processed.csv
# → P000_id049_person_processed.csv
# → P000_id050_person_processed.csv
# → P000_id051_person_processed.csv
# → P000_id052_person_processed.csv
# → P000_id053_person_processed.csv
# → P000_id054_person_processed.csv
# → P000_id055_person_processed.csv
# → P000_id056_person_processed.csv
# → P000_id057_person_processed.csv
# → P000_id058_person_processed.csv
# → P000_id059_person_processed.csv
# → P000_id060_person_processed.csv
# → P000_id061_person_processed.csv
# → P000_id062_person_processed.csv
# → P000_id063_person_processed.csv
# → P000_id064_person_processed.csv
# → P000_id065_person_processed.csv
# → P000_id066_person_processed.csv
# → P000_id067_person_processed.csv
# → P000_id068_person_processed.csv
# → P000_id069_person_processed.csv
# → P000_id070_person_processed.csv
# → P000_id071_person_processed.csv
# → P000_id072_person_processed.csv
# → P000_id073_person_processed.csv
# → P000_id074_person_processed.csv
# → P000_id075_person_processed.csv
# → P000_id076_person_processed.csv
# → P000_id077_person_processed.csv
# → P000_id078_person_processed.csv
# → P000_id079_person_processed.csv
# → P000_id080_person_processed.csv
# → P000_id081_person_processed.csv
# → P000_id082_person_processed.csv
# → P000_id083_person_processed.csv
# → P000_id084_person_processed.csv
# → P000_id085_person_processed.csv
# → P000_id086_person_processed.csv
# → P000_id087_person_processed.csv
# → P000_id088_politik_processed.csv
# → P000_id089_politik_processed.csv
# → P000_id090_politik_ncc_processed.csv
# → P000_id091_politik_ncc_processed.csv
# → P000_id092_politik_processed.csv
# → P000_id093_politik_processed.csv
# → P000_id094_politik_processed.csv
# → P000_id095_politik_processed.csv
# → P000_id096_politik_processed.csv
# → P000_id097_politik_processed.csv
# → P000_id098_politik_processed.csv
# → P000_id099_politik_processed.csv
# → P000_id100_politik_processed.csv
# → P000_id101_politik_processed.csv
# → P000_id102_politik_processed.csv
# → P000_id103_politik_processed.csv
# → P000_id104_politik_processed.csv
# → P000_id105_politik_processed.csv
# → P000_id106_textigm_meme_ncc_processed.csv
# → P000_id107_textimg_meme_ncc_processed.csv
# → P000_id108_textimg_meme_ncc_processed.csv
# → P000_id109_textimg_meme_ncc_processed.csv
# → P000_id110_textimg_meme_ncc_processed.csv
# → P000_id111_textimg_meme_ncc_processed.csv
# → P000_id112_textimg_meme_ncc_processed.csv
# → P000_id113_textimg_meme_ncc_processed.csv
# → P000_id114_textimg_meme_ncc_processed.csv
# → P000_id115_textimg_meme_ncc_processed.csv
# → P000_id116_textimg_meme_ncc_processed.csv
# → P000_id117_textimg_meme_ncc_processed.csv
# → P000_id118_textimg_meme_ncc_processed.csv
# → P000_id119_textimg_meme_ncc_processed.csv
# → P000_id120_textimg_meme_ncc_processed.csv
# → P000_id121_textimg_meme_ncc_processed.csv
# → P000_id122_textimg_meme_ncc_processed.csv
# → P000_id123_textimg_meme_ncc_processed.csv
# → P000_id124_textimg_meme_ncc_processed.csv
# → P000_id125_textimg_meme_ncc_processed.csv
# → P000_id126_text_politik_processed.csv
# → P000_id127_textimg_ncc_processed.csv
# → P000_id128_textimg_processed.csv
# → P000_id129_textimg_ort_processed.csv
# → P000_id130_textimg_ort_processed.csv
# → P000_id131_textimg_person_processed.csv
# → P000_id132_textimg_person_ncc_processed.csv
# → P000_id133_textimg_person_ncc_processed.csv
# → P000_id134_textimg_person_politik_ncc_processed.csv
# → P000_id135_textimg_politik_processed.csv
# → P000_id136_textimg_politik_processed.csv
# → P000_id137_textimg_politik_processed.csv
# → P000_id138_textimg_politik_processed.csv
# → P000_id139_textimg_politik_processed.csv
# → P000_id140_textimg_politik_processed.csv
# → P000_id141_textimg_politik_ncc_processed.csv
# → P000_id142_text_processed.csv
# → P000_id143_text_processed.csv
# → P000_id144_text_processed.csv
# → P000_id146_processed.csv
# → P000_id147_text_ncc_processed.csv
# → P000_id148_text_ncc_processed.csv
# → P000_id149_text_ncc_processed.csv
# → P000_id150_text_ncc_processed.csv
# → P000_id151_text_ncc_processed.csv
# → P000_id152_text_ncc_processed.csv
# → P000_id153_text_ncc_processed.csv
# → P001_id001_meme_ncc_processed.csv
# → P001_id001_meme_ncc__processed.csv
# → P001_id002_meme_ncc_processed.csv
# → P001_id002_meme_ncc__processed.csv
# → P001_id003_meme_ncc_processed.csv
# → P001_id003_meme_ncc__processed.csv
# → P001_id004_meme_ncc_processed.csv
# → P001_id004_meme_ncc__processed.csv
# → P001_id005_meme_ncc_processed.csv
# → P001_id005_meme_ncc__processed.csv
# → P001_id006_meme_ncc_processed.csv
# → P001_id006_meme_ncc__processed.csv
# → P001_id007_meme_ncc_processed.csv
# → P001_id007_meme_ncc__processed.csv
# → P001_id008_meme_ncc_processed.csv
# → P001_id008_meme_ncc__processed.csv
# → P001_id009_meme_ncc_processed.csv
# → P001_id009_meme_ncc__processed.csv
# → P001_id010_meme_ncc_processed.csv
# → P001_id010_meme_ncc__processed.csv
# → P001_id011_ort_processed.csv
# → P001_id011_ort__processed.csv
# → P001_id012_ort_processed.csv
# → P001_id012_ort__processed.csv
# → P001_id013_ort_processed.csv
# → P001_id013_ort__processed.csv
# → P001_id014_ort_processed.csv
# → P001_id014_ort__processed.csv
# → P001_id015_ort_processed.csv
# → P001_id015_ort__processed.csv
# → P001_id016_ort_processed.csv
# → P001_id016_ort__processed.csv
# → P001_id017_ort_processed.csv
# → P001_id017_ort__processed.csv
# → P001_id018_ort_processed.csv
# → P001_id018_ort__processed.csv
# → P001_id019_ort_processed.csv
# → P001_id019_ort__processed.csv
# → P001_id020_ort_processed.csv
# → P001_id020_ort__processed.csv
# → P001_id021_ort_processed.csv
# → P001_id021_ort__processed.csv
# → P001_id022_ort_processed.csv
# → P001_id022_ort__processed.csv
# → P001_id023_ort_processed.csv
# → P001_id023_ort__processed.csv
# → P001_id024_ort_processed.csv
# → P001_id024_ort__processed.csv
# → P001_id025_ort_processed.csv
# → P001_id025_ort__processed.csv
# → P001_id026_ort_processed.csv
# → P001_id026_ort__processed.csv
# → P001_id027_ort_processed.csv
# → P001_id027_ort__processed.csv
# → P001_id028_ort_processed.csv
# → P001_id028_ort__processed.csv
# → P001_id029_ort_processed.csv
# → P001_id029_ort__processed.csv
# → P001_id030_ort_processed.csv
# → P001_id030_ort__processed.csv
# → P001_id031_ort_processed.csv
# → P001_id031_ort__processed.csv
# → P001_id032_ort_processed.csv
# → P001_id032_ort__processed.csv
# → P001_id033_person_processed.csv
# → P001_id033_person__processed.csv
# → P001_id034_person_processed.csv
# → P001_id034_person__processed.csv
# → P001_id035_person_processed.csv
# → P001_id035_person__processed.csv
# → P001_id036_person_processed.csv
# → P001_id036_person__processed.csv
# → P001_id037_person_processed.csv
# → P001_id037_person__processed.csv
# → P001_id038_person_processed.csv
# → P001_id038_person__processed.csv
# → P001_id039_person_processed.csv
# → P001_id039_person__processed.csv
# → P001_id040_person_processed.csv
# → P001_id040_person__processed.csv
# → P001_id041_person_processed.csv
# → P001_id041_person__processed.csv
# → P001_id042_person_processed.csv
# → P001_id042_person__processed.csv
# → P001_id043_person_processed.csv
# → P001_id043_person__processed.csv
# → P001_id044_person_processed.csv
# → P001_id044_person__processed.csv
# → P001_id045_person__processed.csv
# → P001_id046_person_processed.csv
# → P001_id046_person__processed.csv
# → P001_id047_person_processed.csv
# → P001_id047_person__processed.csv
# → P001_id048_person_processed.csv
# → P001_id048_person__processed.csv
# → P001_id049_person_processed.csv
# → P001_id049_person__processed.csv
# → P001_id050_person_processed.csv
# → P001_id050_person__processed.csv
# → P001_id051_person_processed.csv
# → P001_id051_person__processed.csv
# → P001_id052_person_processed.csv
# → P001_id052_person__processed.csv
# → P001_id053_person_processed.csv
# → P001_id053_person__processed.csv
# → P001_id054_person_processed.csv
# → P001_id054_person__processed.csv
# → P001_id055_person_processed.csv
# → P001_id055_person__processed.csv
# → P001_id056_person_processed.csv
# → P001_id056_person__processed.csv
# → P001_id057_person_processed.csv
# → P001_id057_person__processed.csv
# → P001_id058_person_processed.csv
# → P001_id058_person__processed.csv
# → P001_id059_person_processed.csv
# → P001_id059_person__processed.csv
# → P001_id060_person_processed.csv
# → P001_id060_person__processed.csv
# → P001_id061_person_processed.csv
# → P001_id061_person__processed.csv
# → P001_id062_person_processed.csv
# → P001_id062_person__processed.csv
# → P001_id063_person_processed.csv
# → P001_id063_person__processed.csv
# → P001_id064_person_processed.csv
# → P001_id064_person__processed.csv
# → P001_id065_person_processed.csv
# → P001_id065_person__processed.csv
# → P001_id066_person_processed.csv
# → P001_id066_person__processed.csv
# → P001_id067_person_processed.csv
# → P001_id067_person__processed.csv
# → P001_id068_person_processed.csv
# → P001_id068_person__processed.csv
# → P001_id069_person_processed.csv
# → P001_id069_person__processed.csv
# → P001_id070_person_processed.csv
# → P001_id070_person__processed.csv
# → P001_id071_person_processed.csv
# → P001_id071_person__processed.csv
# → P001_id072_person_processed.csv
# → P001_id072_person__processed.csv
# → P001_id073_person_processed.csv
# → P001_id073_person__processed.csv
# → P001_id074_person_processed.csv
# → P001_id074_person__processed.csv
# → P001_id075_person_processed.csv
# → P001_id075_person__processed.csv
# → P001_id076_person_processed.csv
# → P001_id076_person__processed.csv
# → P001_id077_person_processed.csv
# → P001_id077_person__processed.csv
# → P001_id078_person_processed.csv
# → P001_id078_person__processed.csv
# → P001_id079_person_processed.csv
# → P001_id079_person__processed.csv
# → P001_id080_person_processed.csv
# → P001_id080_person__processed.csv
# → P001_id081_person_processed.csv
# → P001_id081_person__processed.csv
# → P001_id082_person_processed.csv
# → P001_id082_person__processed.csv
# → P001_id083_person_processed.csv
# → P001_id083_person__processed.csv
# → P001_id084_person_processed.csv
# → P001_id084_person__processed.csv
# → P001_id085_person_processed.csv
# → P001_id085_person__processed.csv
# → P001_id086_person_processed.csv
# → P001_id086_person__processed.csv
# → P001_id087_person_processed.csv
# → P001_id087_person__processed.csv
# → P001_id088_politik_processed.csv
# → P001_id088_politik__processed.csv
# → P001_id089_politik_processed.csv
# → P001_id089_politik__processed.csv
# → P001_id090_politik_ncc_processed.csv
# → P001_id090_politik_ncc__processed.csv
# → P001_id091_politik_ncc_processed.csv
# → P001_id091_politik_ncc__processed.csv
# → P001_id092_politik_processed.csv
# → P001_id092_politik__processed.csv
# → P001_id093_politik_processed.csv
# → P001_id093_politik__processed.csv
# → P001_id094_politik_processed.csv
# → P001_id094_politik__processed.csv
# → P001_id095_politik_processed.csv
# → P001_id095_politik__processed.csv
# → P001_id096_politik_processed.csv
# → P001_id096_politik__processed.csv
# → P001_id097_politik_processed.csv
# → P001_id097_politik__processed.csv
# → P001_id098_politik_processed.csv
# → P001_id098_politik__processed.csv
# → P001_id099_politik_processed.csv
# → P001_id099_politik__processed.csv
# → P001_id100_politik_processed.csv
# → P001_id100_politik__processed.csv
# → P001_id101_politik_processed.csv
# → P001_id101_politik__processed.csv
# → P001_id102_politik_processed.csv
# → P001_id102_politik__processed.csv
# → P001_id103_politik_processed.csv
# → P001_id103_politik__processed.csv
# → P001_id104_politik_processed.csv
# → P001_id104_politik__processed.csv
# → P001_id105_politik_processed.csv
# → P001_id105_politik__processed.csv
# → P001_id106_textigm_meme_ncc_processed.csv
# → P001_id106_textigm_meme_ncc__processed.csv
# → P001_id107_textimg_meme_ncc_processed.csv
# → P001_id107_textimg_meme_ncc__processed.csv
# → P001_id108_textimg_meme_ncc_processed.csv
# → P001_id108_textimg_meme_ncc__processed.csv
# → P001_id109_textimg_meme_ncc_processed.csv
# → P001_id109_textimg_meme_ncc__processed.csv
# → P001_id110_textimg_meme_ncc_processed.csv
# → P001_id110_textimg_meme_ncc__processed.csv
# → P001_id111_textimg_meme_ncc_processed.csv
# → P001_id111_textimg_meme_ncc__processed.csv
# → P001_id112_textimg_meme_ncc_processed.csv
# → P001_id112_textimg_meme_ncc__processed.csv
# → P001_id113_textimg_meme_ncc_processed.csv
# → P001_id113_textimg_meme_ncc__processed.csv
# → P001_id114_textimg_meme_ncc_processed.csv
# → P001_id114_textimg_meme_ncc__processed.csv
# → P001_id115_textimg_meme_ncc_processed.csv
# → P001_id115_textimg_meme_ncc__processed.csv
# → P001_id116_textimg_meme_ncc_processed.csv
# → P001_id116_textimg_meme_ncc__processed.csv
# → P001_id117_textimg_meme_ncc_processed.csv
# → P001_id117_textimg_meme_ncc__processed.csv
# → P001_id118_textimg_meme_ncc_processed.csv
# → P001_id118_textimg_meme_ncc__processed.csv
# → P001_id119_textimg_meme_ncc_processed.csv
# → P001_id119_textimg_meme_ncc__processed.csv
# → P001_id120_textimg_meme_ncc_processed.csv
# → P001_id120_textimg_meme_ncc__processed.csv
# → P001_id121_textimg_meme_ncc_processed.csv
# → P001_id121_textimg_meme_ncc__processed.csv
# → P001_id122_textimg_meme_ncc_processed.csv
# → P001_id122_textimg_meme_ncc__processed.csv
# → P001_id123_textimg_meme_ncc_processed.csv
# → P001_id123_textimg_meme_ncc__processed.csv
# → P001_id124_textimg_meme_ncc_processed.csv
# → P001_id124_textimg_meme_ncc__processed.csv
# → P001_id125_textimg_meme_ncc_processed.csv
# → P001_id125_textimg_meme_ncc__processed.csv
# → P001_id126_text_politik_processed.csv
# → P001_id126_text_politik__processed.csv
# → P001_id127_textimg_ncc_processed.csv
# → P001_id127_textimg_ncc__processed.csv
# → P001_id128_textimg_processed.csv
# → P001_id128_textimg__processed.csv
# → P001_id129_textimg_ort_processed.csv
# → P001_id129_textimg_ort__processed.csv
# → P001_id130_textimg_ort_processed.csv
# → P001_id130_textimg_ort__processed.csv
# → P001_id131_textimg_person_processed.csv
# → P001_id131_textimg_person__processed.csv
# → P001_id132_textimg_person_ncc_processed.csv
# → P001_id132_textimg_person_ncc__processed.csv
# → P001_id133_textimg_person_ncc_processed.csv
# → P001_id133_textimg_person_ncc__processed.csv
# → P001_id134_textimg_person_politik_ncc_processed.csv
# → P001_id134_textimg_person_politik_ncc__processed.csv
# → P001_id135_textimg_politik_processed.csv
# → P001_id135_textimg_politik__processed.csv
# → P001_id136_textimg_politik_processed.csv
# → P001_id136_textimg_politik__processed.csv
# → P001_id137_textimg_politik_processed.csv
# → P001_id137_textimg_politik__processed.csv
# → P001_id138_textimg_politik_processed.csv
# → P001_id138_textimg_politik__processed.csv
# → P001_id139_textimg_politik_processed.csv
# → P001_id139_textimg_politik__processed.csv
# → P001_id140_textimg_politik_processed.csv
# → P001_id140_textimg_politik__processed.csv
# → P001_id141_textimg_politik_ncc_processed.csv
# → P001_id141_textimg_politik_ncc__processed.csv
# → P001_id142_text_processed.csv
# → P001_id142_text__processed.csv
# → P001_id143_text_processed.csv
# → P001_id143_text__processed.csv
# → P001_id144_text_processed.csv
# → P001_id144_text__processed.csv
# → P001_id146_processed.csv
# → P001_id147_text_ncc_processed.csv
# → P001_id147_text_ncc__processed.csv
# → P001_id148_text_ncc_processed.csv
# → P001_id148_text_ncc__processed.csv
# → P001_id149_text_ncc_processed.csv
# → P001_id149_text_ncc__processed.csv
# → P001_id150_text_ncc_processed.csv
# → P001_id150_text_ncc__processed.csv
# → P001_id151_text_ncc_processed.csv
# → P001_id151_text_ncc__processed.csv
# → P001_id152_text_ncc_processed.csv
# → P001_id152_text_ncc__processed.csv
# → P001_id153_text_ncc_processed.csv
# → P001_id153_text_ncc__processed.csv
# → P002_id001_meme_ncc_processed.csv
# → P002_id001_meme_ncc__processed.csv
# → P002_id002_meme_ncc_processed.csv
# → P002_id002_meme_ncc__processed.csv
# → P002_id003_meme_ncc_processed.csv
# → P002_id003_meme_ncc__processed.csv
# → P002_id004_meme_ncc_processed.csv
# → P002_id004_meme_ncc__processed.csv
# → P002_id005_meme_ncc_processed.csv
# → P002_id005_meme_ncc__processed.csv
# → P002_id006_meme_ncc_processed.csv
# → P002_id006_meme_ncc__processed.csv
# → P002_id007_meme_ncc_processed.csv
# → P002_id007_meme_ncc__processed.csv
# → P002_id008_meme_ncc_processed.csv
# → P002_id008_meme_ncc__processed.csv
# → P002_id009_meme_ncc_processed.csv
# → P002_id009_meme_ncc__processed.csv
# → P002_id010_meme_ncc_processed.csv
# → P002_id010_meme_ncc__processed.csv
# → P002_id011_ort_processed.csv
# → P002_id011_ort__processed.csv
# → P002_id012_ort_processed.csv
# → P002_id012_ort__processed.csv
# → P002_id013_ort_processed.csv
# → P002_id013_ort__processed.csv
# → P002_id014_ort_processed.csv
# → P002_id014_ort__processed.csv
# → P002_id015_ort_processed.csv
# → P002_id015_ort__processed.csv
# → P002_id016_ort_processed.csv
# → P002_id016_ort__processed.csv
# → P002_id017_ort_processed.csv
# → P002_id017_ort__processed.csv
# → P002_id018_ort_processed.csv
# → P002_id018_ort__processed.csv
# → P002_id019_ort_processed.csv
# → P002_id019_ort__processed.csv
# → P002_id020_ort_processed.csv
# → P002_id020_ort__processed.csv
# → P002_id021_ort_processed.csv
# → P002_id021_ort__processed.csv
# → P002_id022_ort_processed.csv
# → P002_id022_ort__processed.csv
# → P002_id023_ort_processed.csv
# → P002_id023_ort__processed.csv
# → P002_id024_ort_processed.csv
# → P002_id024_ort__processed.csv
# → P002_id025_ort_processed.csv
# → P002_id025_ort__processed.csv
# → P002_id026_ort_processed.csv
# → P002_id026_ort__processed.csv
# → P002_id027_ort_processed.csv
# → P002_id027_ort__processed.csv
# → P002_id028_ort_processed.csv
# → P002_id028_ort__processed.csv
# → P002_id029_ort_processed.csv
# → P002_id029_ort__processed.csv
# → P002_id030_ort_processed.csv
# → P002_id030_ort__processed.csv
# → P002_id031_ort_processed.csv
# → P002_id031_ort__processed.csv
# → P002_id032_ort_processed.csv
# → P002_id032_ort__processed.csv
# → P002_id033_person_processed.csv
# → P002_id033_person__processed.csv
# → P002_id034_person_processed.csv
# → P002_id034_person__processed.csv
# → P002_id035_person_processed.csv
# → P002_id035_person__processed.csv
# → P002_id036_person_processed.csv
# → P002_id036_person__processed.csv
# → P002_id037_person_processed.csv
# → P002_id037_person__processed.csv
# → P002_id038_person_processed.csv
# → P002_id038_person__processed.csv
# → P002_id039_person_processed.csv
# → P002_id039_person__processed.csv
# → P002_id040_person_processed.csv
# → P002_id040_person__processed.csv
# → P002_id041_person_processed.csv
# → P002_id041_person__processed.csv
# → P002_id042_person_processed.csv
# → P002_id042_person__processed.csv
# → P002_id043_person_processed.csv
# → P002_id043_person__processed.csv
# → P002_id044_person_processed.csv
# → P002_id044_person__processed.csv
# → P002_id045_person_processed.csv
# → P002_id045_person__processed.csv
# → P002_id046_person_processed.csv
# → P002_id046_person__processed.csv
# → P002_id047_person_processed.csv
# → P002_id047_person__processed.csv
# → P002_id048_person_processed.csv
# → P002_id048_person__processed.csv
# → P002_id049_person_processed.csv
# → P002_id049_person__processed.csv
# → P002_id050_person_processed.csv
# → P002_id050_person__processed.csv
# → P002_id051_person_processed.csv
# → P002_id051_person__processed.csv
# → P002_id052_person_processed.csv
# → P002_id052_person__processed.csv
# → P002_id053_person_processed.csv
# → P002_id053_person__processed.csv
# → P002_id054_person_processed.csv
# → P002_id054_person__processed.csv
# → P002_id055_person_processed.csv
# → P002_id055_person__processed.csv
# → P002_id056_person_processed.csv
# → P002_id056_person__processed.csv
# → P002_id057_person_processed.csv
# → P002_id057_person__processed.csv
# → P002_id058_person_processed.csv
# → P002_id058_person__processed.csv
# → P002_id059_person_processed.csv
# → P002_id059_person__processed.csv
# → P002_id060_person_processed.csv
# → P002_id060_person__processed.csv
# → P002_id061_person_processed.csv
# → P002_id061_person__processed.csv
# → P002_id062_person_processed.csv
# → P002_id062_person__processed.csv
# → P002_id063_person_processed.csv
# → P002_id063_person__processed.csv
# → P002_id064_person_processed.csv
# → P002_id064_person__processed.csv
# → P002_id065_person_processed.csv
# → P002_id065_person__processed.csv
# → P002_id066_person_processed.csv
# → P002_id066_person__processed.csv
# → P002_id067_person_processed.csv
# → P002_id067_person__processed.csv
# → P002_id068_person_processed.csv
# → P002_id068_person__processed.csv
# → P002_id069_person_processed.csv
# → P002_id069_person__processed.csv
# → P002_id070_person_processed.csv
# → P002_id070_person__processed.csv
# → P002_id071_person_processed.csv
# → P002_id071_person__processed.csv
# → P002_id072_person_processed.csv
# → P002_id072_person__processed.csv
# → P002_id073_person_processed.csv
# → P002_id073_person__processed.csv
# → P002_id074_person_processed.csv
# → P002_id074_person__processed.csv
# → P002_id075_person_processed.csv
# → P002_id075_person__processed.csv
# → P002_id076_person_processed.csv
# → P002_id076_person__processed.csv
# → P002_id077_person_processed.csv
# → P002_id077_person__processed.csv
# → P002_id078_person_processed.csv
# → P002_id078_person__processed.csv
# → P002_id079_person_processed.csv
# → P002_id079_person__processed.csv
# → P002_id080_person_processed.csv
# → P002_id080_person__processed.csv
# → P002_id081_person_processed.csv
# → P002_id081_person__processed.csv
# → P002_id082_person_processed.csv
# → P002_id082_person__processed.csv
# → P002_id083_person_processed.csv
# → P002_id083_person__processed.csv
# → P002_id084_person_processed.csv
# → P002_id084_person__processed.csv
# → P002_id085_person_processed.csv
# → P002_id085_person__processed.csv
# → P002_id086_person_processed.csv
# → P002_id086_person__processed.csv
# → P002_id087_person_processed.csv
# → P002_id087_person__processed.csv
# → P002_id088_politik__processed.csv
# → P002_id089_politik_processed.csv
# → P002_id089_politik__processed.csv
# → P004_id018_ort__processed.csv
# → P004_id019_ort_processed.csv
# → P004_id019_ort__processed.csv
# → P004_id020_ort_processed.csv
# → P004_id020_ort__processed.csv
# → P004_id021_ort_processed.csv
# → P004_id021_ort__processed.csv
# → P004_id022_ort_processed.csv
# → P004_id022_ort__processed.csv
# → P004_id023_ort_processed.csv
# → P004_id023_ort__processed.csv
# → P004_id024_ort_processed.csv
# → P004_id024_ort__processed.csv
# → P004_id025_ort_processed.csv
# → P004_id025_ort__processed.csv
# → P004_id026_ort_processed.csv
# → P004_id026_ort__processed.csv
# → P004_id027_ort_processed.csv
# → P004_id027_ort__processed.csv
# → P004_id028_ort_processed.csv
# → P004_id028_ort__processed.csv
# → P004_id029_ort_processed.csv
# → P004_id029_ort__processed.csv
# → P004_id030_ort_processed.csv
# → P004_id030_ort__processed.csv
# → P004_id031_ort_processed.csv
# → P004_id031_ort__processed.csv
# → P004_id032_ort_processed.csv
# → P004_id032_ort__processed.csv
# → P004_id033_person_processed.csv
# → P004_id033_person__processed.csv
# → P004_id034_person_processed.csv
# → P004_id034_person__processed.csv
# → P004_id035_person_processed.csv
# → P004_id035_person__processed.csv
# → P004_id036_person_processed.csv
# → P004_id036_person__processed.csv
# → P004_id037_person_processed.csv
# → P004_id037_person__processed.csv
# → P004_id038_person_processed.csv
# → P004_id038_person__processed.csv
# → P004_id039_person_processed.csv
# → P004_id039_person__processed.csv
# → P004_id040_person_processed.csv
# → P004_id040_person__processed.csv
# → P004_id041_person_processed.csv
# → P004_id041_person__processed.csv
# → P004_id042_person_processed.csv
# → P004_id042_person__processed.csv
# → P004_id043_person_processed.csv
# → P004_id043_person__processed.csv
# → P004_id044_person_processed.csv
# → P004_id044_person__processed.csv
# → P004_id045_person_processed.csv
# → P004_id045_person__processed.csv
# → P004_id046_person_processed.csv
# → P004_id046_person__processed.csv
# → P004_id047_person_processed.csv
# → P004_id047_person__processed.csv
# → P004_id048_person_processed.csv
# → P004_id048_person__processed.csv
# → P004_id049_person_processed.csv
# → P004_id049_person__processed.csv
# → P004_id050_person_processed.csv
# → P004_id050_person__processed.csv
# → P004_id051_person_processed.csv
# → P004_id051_person__processed.csv
# → P004_id052_person_processed.csv
# → P004_id052_person__processed.csv
# → P004_id053_person_processed.csv
# → P004_id053_person__processed.csv
# → P004_id054_person_processed.csv
# → P004_id054_person__processed.csv
# → P004_id055_person_processed.csv
# → P004_id055_person__processed.csv
# → P004_id056_person_processed.csv
# → P004_id056_person__processed.csv
# → P004_id057_person_processed.csv
# → P004_id057_person__processed.csv
# → P004_id058_person_processed.csv
# → P004_id058_person__processed.csv
# → P004_id059_person_processed.csv
# → P004_id059_person__processed.csv
# → P004_id060_person_processed.csv
# → P004_id060_person__processed.csv
# → P004_id061_person_processed.csv
# → P004_id061_person__processed.csv
# → P004_id062_person_processed.csv
# → P004_id062_person__processed.csv
# → P004_id063_person_processed.csv
# → P004_id063_person__processed.csv
# → P004_id064_person_processed.csv
# → P004_id064_person__processed.csv
# → P004_id065_person_processed.csv
# → P004_id065_person__processed.csv
# → P004_id066_person_processed.csv
# → P004_id066_person__processed.csv
# → P004_id067_person_processed.csv
# → P004_id067_person__processed.csv
# → P004_id068_person_processed.csv
# → P004_id068_person__processed.csv
# → P004_id069_person_processed.csv
# → P004_id069_person__processed.csv
# → P004_id070_person_processed.csv
# → P004_id070_person__processed.csv
# → P004_id071_person_processed.csv
# → P004_id071_person__processed.csv
# → P004_id072_person_processed.csv
# → P004_id072_person__processed.csv
# → P004_id073_person_processed.csv
# → P004_id073_person__processed.csv
# → P004_id074_person_processed.csv
# → P004_id074_person__processed.csv
# → P004_id075_person_processed.csv
# → P004_id075_person__processed.csv
# → P004_id076_person_processed.csv
# → P004_id076_person__processed.csv
# → P004_id077_person_processed.csv
# → P004_id077_person__processed.csv
# → P004_id078_person_processed.csv
# → P004_id078_person__processed.csv
# → P004_id079_person_processed.csv
# → P004_id079_person__processed.csv
# → P004_id080_person_processed.csv
# → P004_id080_person__processed.csv
# → P004_id081_person_processed.csv
# → P004_id081_person__processed.csv
# → P004_id082_person_processed.csv
# → P004_id082_person__processed.csv
# → P004_id083_person_processed.csv
# → P004_id083_person__processed.csv
# → P004_id084_person_processed.csv
# → P004_id084_person__processed.csv
# → P004_id085_person_processed.csv
# → P004_id085_person__processed.csv
# → P004_id086_person_processed.csv
# → P004_id086_person__processed.csv
# → P004_id087_person_processed.csv
# → P004_id087_person__processed.csv
# → P004_id088_politik_processed.csv
# → P004_id088_politik__processed.csv
# → P004_id089_politik_processed.csv
# → P004_id089_politik__processed.csv
# → P004_id090_politik_ncc_processed.csv
# → P004_id090_politik_ncc__processed.csv
# → P004_id091_politik_ncc_processed.csv
# → P004_id091_politik_ncc__processed.csv
# → P004_id092_politik_processed.csv
# → P004_id092_politik__processed.csv
# → P004_id093_politik_processed.csv
# → P004_id093_politik__processed.csv
# → P004_id094_politik_processed.csv
# → P004_id094_politik__processed.csv
# → P004_id095_politik_processed.csv
# → P004_id095_politik__processed.csv
# → P004_id096_politik_processed.csv
# → P004_id096_politik__processed.csv
# → P004_id097_politik_processed.csv
# → P004_id097_politik__processed.csv
# → P004_id098_politik_processed.csv
# → P004_id098_politik__processed.csv
# → P004_id099_politik_processed.csv
# → P004_id099_politik__processed.csv
# → P004_id100_politik_processed.csv
# → P004_id100_politik__processed.csv
# → P004_id101_politik_processed.csv
# → P004_id101_politik__processed.csv
# → P004_id102_politik_processed.csv
# → P004_id102_politik__processed.csv
# → P004_id103_politik_processed.csv
# → P004_id103_politik__processed.csv
# → P004_id104_politik_processed.csv
# → P004_id104_politik__processed.csv
# → P004_id105_politik_processed.csv
# → P004_id105_politik__processed.csv
# → P004_id106_textigm_meme_ncc_processed.csv
# → P004_id106_textigm_meme_ncc__processed.csv
# → P004_id107_textimg_meme_ncc_processed.csv
# → P004_id107_textimg_meme_ncc__processed.csv
# → P004_id108_textimg_meme_ncc_processed.csv
# → P004_id108_textimg_meme_ncc__processed.csv
# → P004_id109_textimg_meme_ncc_processed.csv
# → P004_id109_textimg_meme_ncc__processed.csv
# → P004_id110_textimg_meme_ncc_processed.csv
# → P004_id110_textimg_meme_ncc__processed.csv
# → P004_id111_textimg_meme_ncc_processed.csv
# → P004_id111_textimg_meme_ncc__processed.csv
# → P004_id112_textimg_meme_ncc_processed.csv
# → P004_id112_textimg_meme_ncc__processed.csv
# → P004_id113_textimg_meme_ncc_processed.csv
# → P004_id113_textimg_meme_ncc__processed.csv
# → P004_id114_textimg_meme_ncc_processed.csv
# → P004_id114_textimg_meme_ncc__processed.csv
# → P004_id115_textimg_meme_ncc_processed.csv
# → P004_id115_textimg_meme_ncc__processed.csv
# → P004_id116_textimg_meme_ncc_processed.csv
# → P004_id116_textimg_meme_ncc__processed.csv
# → P004_id117_textimg_meme_ncc_processed.csv
# → P004_id117_textimg_meme_ncc__processed.csv
# → P004_id118_textimg_meme_ncc_processed.csv
# → P004_id118_textimg_meme_ncc__processed.csv
# → P004_id119_textimg_meme_ncc_processed.csv
# → P004_id119_textimg_meme_ncc__processed.csv
# → P004_id120_textimg_meme_ncc_processed.csv
# → P004_id120_textimg_meme_ncc__processed.csv
# → P004_id121_textimg_meme_ncc_processed.csv
# → P004_id121_textimg_meme_ncc__processed.csv
# → P004_id122_textimg_meme_ncc_processed.csv
# → P004_id122_textimg_meme_ncc__processed.csv
# → P004_id123_textimg_meme_ncc_processed.csv
# → P004_id123_textimg_meme_ncc__processed.csv
# → P004_id124_textimg_meme_ncc_processed.csv
# → P004_id124_textimg_meme_ncc__processed.csv
# → P004_id125_textimg_meme_ncc_processed.csv
# → P004_id125_textimg_meme_ncc__processed.csv
# → P004_id126_text_politik_processed.csv
# → P004_id126_text_politik__processed.csv
# → P004_id127_textimg_ncc_processed.csv
# → P004_id127_textimg_ncc__processed.csv
# → P004_id128_textimg_processed.csv
# → P004_id128_textimg__processed.csv
# → P004_id129_textimg_ort_processed.csv
# → P004_id129_textimg_ort__processed.csv
# → P004_id130_textimg_ort_processed.csv
# → P004_id130_textimg_ort__processed.csv
# → P004_id131_textimg_person_processed.csv
# → P004_id131_textimg_person__processed.csv
# → P004_id132_textimg_person_ncc_processed.csv
# → P004_id132_textimg_person_ncc__processed.csv
# → P004_id133_textimg_person_ncc_processed.csv
# → P004_id133_textimg_person_ncc__processed.csv
# → P004_id134_textimg_person_politik_ncc_processed.csv
# → P004_id134_textimg_person_politik_ncc__processed.csv
# → P004_id135_textimg_politik_processed.csv
# → P004_id135_textimg_politik__processed.csv
# → P004_id136_textimg_politik_processed.csv
# → P004_id136_textimg_politik__processed.csv
# → P004_id137_textimg_politik_processed.csv
# → P004_id137_textimg_politik__processed.csv
# → P004_id138_textimg_politik_processed.csv
# → P004_id138_textimg_politik__processed.csv
# → P004_id139_textimg_politik_processed.csv
# → P004_id139_textimg_politik__processed.csv
# → P004_id140_textimg_politik_processed.csv
# → P004_id140_textimg_politik__processed.csv
# → P004_id141_textimg_politik_ncc_processed.csv
# → P004_id141_textimg_politik_ncc__processed.csv
# → P004_id142_text_processed.csv
# → P004_id142_text__processed.csv
# → P004_id143_text_processed.csv
# → P004_id143_text__processed.csv
# → P004_id144_text_processed.csv
# → P004_id144_text__processed.csv
# → P004_id146_processed.csv
# → P004_id147_text_ncc_processed.csv
# → P004_id147_text_ncc__processed.csv
# → P004_id148_text_ncc_processed.csv
# → P004_id148_text_ncc__processed.csv
# → P004_id149_text_ncc_processed.csv
# → P004_id149_text_ncc__processed.csv
# → P004_id150_text_ncc_processed.csv
# → P004_id150_text_ncc__processed.csv
# → P004_id151_text_ncc_processed.csv
# → P004_id151_text_ncc__processed.csv
# → P004_id152_text_ncc_processed.csv
# → P004_id152_text_ncc__processed.csv
# → P004_id153_text_ncc_processed.csv
# → P004_id153_text_ncc__processed.csv
# → P005_id001_meme_ncc_processed.csv
# → P005_id001_meme_ncc__processed.csv
# → P005_id002_meme_ncc_processed.csv
# → P005_id002_meme_ncc__processed.csv
# → P005_id003_meme_ncc_processed.csv
# → P005_id003_meme_ncc__processed.csv
# → P005_id004_meme_ncc_processed.csv
# → P005_id004_meme_ncc__processed.csv
# → P005_id005_meme_ncc_processed.csv
# → P005_id005_meme_ncc__processed.csv
# → P005_id006_meme_ncc_processed.csv
# → P005_id006_meme_ncc__processed.csv
# → P005_id007_meme_ncc_processed.csv
# → P005_id007_meme_ncc__processed.csv
# → P005_id008_meme_ncc_processed.csv
# → P005_id008_meme_ncc__processed.csv
# → P005_id009_meme_ncc_processed.csv
# → P005_id009_meme_ncc__processed.csv
# → P005_id010_meme_ncc_processed.csv
# → P005_id010_meme_ncc__processed.csv
# → P005_id011_ort_processed.csv
# → P005_id011_ort__processed.csv
# → P005_id012_ort_processed.csv
# → P005_id012_ort__processed.csv
# → P005_id013_ort_processed.csv
# → P005_id013_ort__processed.csv
# → P005_id014_ort_processed.csv
# → P005_id014_ort__processed.csv
# → P005_id015_ort_processed.csv
# → P005_id015_ort__processed.csv
# → P005_id016_ort_processed.csv
# → P005_id016_ort__processed.csv
# → P005_id017_ort_processed.csv
# → P005_id017_ort__processed.csv
# → P005_id018_ort_processed.csv
# → P005_id018_ort__processed.csv
# → P005_id019_ort_processed.csv
# → P005_id019_ort__processed.csv
# → P005_id020_ort_processed.csv
# → P005_id020_ort__processed.csv
# → P005_id021_ort_processed.csv
# → P005_id021_ort__processed.csv
# → P005_id022_ort_processed.csv
# → P005_id022_ort__processed.csv
# → P005_id023_ort_processed.csv
# → P005_id023_ort__processed.csv
# → P005_id024_ort_processed.csv
# → P005_id024_ort__processed.csv
# → P005_id025_ort_processed.csv
# → P005_id025_ort__processed.csv
# → P005_id026_ort_processed.csv
# → P005_id026_ort__processed.csv
# → P005_id027_ort_processed.csv
# → P005_id027_ort__processed.csv
# → P005_id028_ort_processed.csv
# → P005_id028_ort__processed.csv
# → P005_id029_ort_processed.csv
# → P005_id029_ort__processed.csv
# → P005_id030_ort_processed.csv
# → P005_id030_ort__processed.csv
# → P005_id031_ort_processed.csv
# → P005_id031_ort__processed.csv
# → P005_id032_ort_processed.csv
# → P005_id032_ort__processed.csv
# → P005_id033_person_processed.csv
# → P005_id033_person__processed.csv
# → P005_id034_person_processed.csv
# → P005_id034_person__processed.csv
# → P005_id035_person_processed.csv
# → P005_id035_person__processed.csv
# → P005_id036_person_processed.csv
# → P005_id036_person__processed.csv
# → P005_id037_person_processed.csv
# → P005_id037_person__processed.csv
# → P005_id038_person_processed.csv
# → P005_id038_person__processed.csv
# → P005_id039_person_processed.csv
# → P005_id039_person__processed.csv
# → P005_id040_person_processed.csv
# → P005_id040_person__processed.csv
# → P005_id041_person_processed.csv
# → P005_id041_person__processed.csv
# → P005_id042_person_processed.csv
# → P005_id042_person__processed.csv
# → P005_id043_person_processed.csv
# → P005_id043_person__processed.csv
# → P005_id044_person_processed.csv
# → P005_id044_person__processed.csv
# → P005_id045_person_processed.csv
# → P005_id045_person__processed.csv
# → P005_id046_person_processed.csv
# → P005_id046_person__processed.csv
# → P005_id047_person_processed.csv
# → P005_id047_person__processed.csv
# → P005_id048_person_processed.csv
# → P005_id048_person__processed.csv
# → P005_id049_person_processed.csv
# → P005_id049_person__processed.csv
# → P005_id050_person_processed.csv
# → P005_id050_person__processed.csv
# → P005_id051_person_processed.csv
# → P005_id051_person__processed.csv
# → P005_id052_person_processed.csv
# → P005_id052_person__processed.csv
# → P005_id053_person_processed.csv
# → P005_id053_person__processed.csv
# → P005_id054_person_processed.csv
# → P005_id054_person__processed.csv
# → P005_id055_person_processed.csv
# ...
# → P052_id095_politik_processed.csv
# → P052_id096_politik_processed.csv
# → P052_id097_politik_processed.csv
# → P052_id098_politik_processed.csv
# → P052_id099_politik_processed.csv
# → P052_id100_politik_processed.csv
# → P052_id101_politik_processed.csv
# → P052_id102_politik_processed.csv
# → P052_id103_politik_processed.csv
# → P052_id104_politik_processed.csv
# → P052_id105_politik_processed.csv
# → P052_id106_textigm_meme_ncc_processed.csv
# → P052_id107_textimg_meme_ncc_processed.csv
# → P052_id108_textimg_meme_ncc_processed.csv
# → P052_id109_textimg_meme_ncc_processed.csv
# → P052_id110_textimg_meme_ncc_processed.csv
# → P052_id111_textimg_meme_ncc_processed.csv
# → P052_id112_textimg_meme_ncc_processed.csv
# → P052_id113_textimg_meme_ncc_processed.csv
# → P052_id114_textimg_meme_ncc_processed.csv
# → P052_id115_textimg_meme_ncc_processed.csv
# → P052_id116_textimg_meme_ncc_processed.csv
# → P052_id117_textimg_meme_ncc_processed.csv
# → P052_id118_textimg_meme_ncc_processed.csv
# → P052_id119_textimg_meme_ncc_processed.csv
# → P052_id120_textimg_meme_ncc_processed.csv
# → P052_id121_textimg_meme_ncc_processed.csv
# → P052_id122_textimg_meme_ncc_processed.csv
# → P052_id123_textimg_meme_ncc_processed.csv
# → P052_id124_textimg_meme_ncc_processed.csv
# → P052_id125_textimg_meme_ncc_processed.csv
# → P052_id126_text_politik_processed.csv
# → P052_id127_textimg_ncc_processed.csv
# → P052_id128_textimg_processed.csv
# → P052_id129_textimg_ort_processed.csv
# → P052_id130_textimg_ort_processed.csv
# → P052_id131_textimg_person_processed.csv
# → P052_id132_textimg_person_ncc_processed.csv
# → P052_id133_textimg_person_ncc_processed.csv
# → P052_id134_textimg_person_politik_ncc_processed.csv
# → P052_id135_textimg_politik_processed.csv
# → P052_id136_textimg_politik_processed.csv
# → P052_id137_textimg_politik_processed.csv
# → P052_id138_textimg_politik_processed.csv
# → P052_id139_textimg_politik_processed.csv
# → P052_id140_textimg_politik_processed.csv
# → P052_id141_textimg_politik_ncc_processed.csv
# → P052_id142_text_processed.csv
# → P052_id143_text_processed.csv
# → P052_id144_text_processed.csv
# → P052_id146_processed.csv
# → P052_id147_text_ncc_processed.csv
# → P052_id148_text_ncc_processed.csv
# → P052_id149_text_ncc_processed.csv
# → P052_id150_text_ncc_processed.csv
# → P052_id151_text_ncc_processed.csv
# → P052_id152_text_ncc_processed.csv
# → P052_id153_text_ncc_processed.csv
# → P053_id001_meme_ncc_processed.csv
# → P053_id002_meme_ncc_processed.csv
# → P053_id003_meme_ncc_processed.csv
# → P053_id004_meme_ncc_processed.csv
# → P053_id005_meme_ncc_processed.csv
# → P053_id006_meme_ncc_processed.csv
# → P053_id007_meme_ncc_processed.csv
# → P053_id008_meme_ncc_processed.csv
# → P053_id009_meme_ncc_processed.csv
# → P053_id010_meme_ncc_processed.csv
# → P053_id011_ort_processed.csv
# → P053_id012_ort_processed.csv
# → P053_id013_ort_processed.csv
# → P053_id014_ort_processed.csv
# → P053_id015_ort_processed.csv
# → P053_id016_ort_processed.csv
# → P053_id017_ort_processed.csv
# → P053_id018_ort_processed.csv
# → P053_id019_ort_processed.csv
# → P053_id020_ort_processed.csv
# → P053_id021_ort_processed.csv
# → P053_id022_ort_processed.csv
# → P053_id023_ort_processed.csv
# → P053_id024_ort_processed.csv
# → P053_id025_ort_processed.csv
# → P053_id026_ort_processed.csv
# → P053_id027_ort_processed.csv
# → P053_id028_ort_processed.csv
# → P053_id029_ort_processed.csv
# → P053_id030_ort_processed.csv
# → P053_id031_ort_processed.csv
# → P053_id032_ort_processed.csv
# → P053_id033_person_processed.csv
# → P053_id034_person_processed.csv
# → P053_id035_person_processed.csv
# → P053_id036_person_processed.csv
# → P053_id037_person_processed.csv
# → P053_id038_person_processed.csv
# → P053_id039_person_processed.csv
# → P053_id040_person_processed.csv
# → P053_id041_person_processed.csv
# → P053_id042_person_processed.csv
# → P053_id043_person_processed.csv
# → P053_id044_person_processed.csv
# → P053_id045_person_processed.csv
# → P053_id046_person_processed.csv
# → P053_id047_person_processed.csv
# → P053_id048_person_processed.csv
# → P053_id049_person_processed.csv
# → P053_id050_person_processed.csv
# → P053_id051_person_processed.csv
# → P053_id052_person_processed.csv
# → P053_id053_person_processed.csv
# → P053_id054_person_processed.csv
# → P053_id055_person_processed.csv
# → P053_id056_person_processed.csv
# → P053_id057_person_processed.csv
# → P053_id058_person_processed.csv
# → P053_id059_person_processed.csv
# → P053_id060_person_processed.csv
# → P053_id061_person_processed.csv
# → P053_id062_person_processed.csv
# → P053_id063_person_processed.csv
# → P053_id064_person_processed.csv
# → P053_id065_person_processed.csv
# → P053_id066_person_processed.csv
# → P053_id067_person_processed.csv
# → P053_id068_person_processed.csv
# → P053_id069_person_processed.csv
# → P053_id070_person_processed.csv
# → P053_id071_person_processed.csv
# → P053_id072_person_processed.csv
# → P053_id073_person_processed.csv
# → P053_id074_person_processed.csv
# → P053_id075_person_processed.csv
# → P053_id076_person_processed.csv
# → P053_id077_person_processed.csv
# → P053_id078_person_processed.csv
# → P053_id079_person_processed.csv
# → P053_id080_person_processed.csv
# → P053_id081_person_processed.csv
# → P053_id082_person_processed.csv
# → P053_id083_person_processed.csv
# → P053_id084_person_processed.csv
# → P053_id085_person_processed.csv
# → P053_id086_person_processed.csv
# → P053_id087_person_processed.csv
# → P053_id088_politik_processed.csv
# → P053_id089_politik_processed.csv
# → P053_id090_politik_ncc_processed.csv
# → P053_id091_politik_ncc_processed.csv
# → P053_id092_politik_processed.csv
# → P053_id093_politik_processed.csv
# → P053_id094_politik_processed.csv
# → P053_id095_politik_processed.csv
# → P053_id096_politik_processed.csv
# → P053_id097_politik_processed.csv
# → P053_id098_politik_processed.csv
# → P053_id099_politik_processed.csv
# → P053_id100_politik_processed.csv
# → P053_id101_politik_processed.csv
# → P053_id102_politik_processed.csv
# → P053_id103_politik_processed.csv
# → P053_id104_politik_processed.csv
# → P053_id105_politik_processed.csv
# → P053_id106_textigm_meme_ncc_processed.csv
# → P053_id107_textimg_meme_ncc_processed.csv
# → P053_id108_textimg_meme_ncc_processed.csv
# → P053_id109_textimg_meme_ncc_processed.csv
# → P053_id110_textimg_meme_ncc_processed.csv
# → P053_id111_textimg_meme_ncc_processed.csv
# → P053_id112_textimg_meme_ncc_processed.csv
# → P053_id113_textimg_meme_ncc_processed.csv
# → P053_id114_textimg_meme_ncc_processed.csv
# → P053_id115_textimg_meme_ncc_processed.csv
# → P053_id116_textimg_meme_ncc_processed.csv
# → P053_id117_textimg_meme_ncc_processed.csv
# → P053_id118_textimg_meme_ncc_processed.csv
# → P053_id119_textimg_meme_ncc_processed.csv
# → P053_id120_textimg_meme_ncc_processed.csv
# → P053_id121_textimg_meme_ncc_processed.csv
# → P053_id122_textimg_meme_ncc_processed.csv
# → P053_id123_textimg_meme_ncc_processed.csv
# → P053_id124_textimg_meme_ncc_processed.csv
# → P053_id125_textimg_meme_ncc_processed.csv
# → P053_id126_text_politik_processed.csv
# → P053_id127_textimg_ncc_processed.csv
# → P053_id128_textimg_processed.csv
# → P053_id129_textimg_ort_processed.csv
# → P053_id130_textimg_ort_processed.csv
# → P053_id131_textimg_person_processed.csv
# → P053_id132_textimg_person_ncc_processed.csv
# → P053_id133_textimg_person_ncc_processed.csv
# → P053_id134_textimg_person_politik_ncc_processed.csv
# → P053_id135_textimg_politik_processed.csv
# → P053_id136_textimg_politik_processed.csv
# → P053_id137_textimg_politik_processed.csv
# → P053_id138_textimg_politik_processed.csv
# → P053_id139_textimg_politik_processed.csv
# → P053_id140_textimg_politik_processed.csv
# → P053_id141_textimg_politik_ncc_processed.csv
# → P053_id142_text_processed.csv
# → P053_id143_text_processed.csv
# → P053_id144_text_processed.csv
# → P053_id146_processed.csv
# → P053_id147_text_ncc_processed.csv
# → P053_id148_text_ncc_processed.csv
# → P053_id149_text_ncc_processed.csv
# → P053_id150_text_ncc_processed.csv
# → P053_id151_text_ncc_processed.csv
# → P053_id152_text_ncc_processed.csv
# → P053_id153_text_ncc_processed.csv
# → P054_id001_meme_ncc_processed.csv
# → P054_id002_meme_ncc_processed.csv
# → P054_id003_meme_ncc_processed.csv
# → P054_id004_meme_ncc_processed.csv
# → P054_id005_meme_ncc_processed.csv
# → P054_id006_meme_ncc_processed.csv
# → P054_id007_meme_ncc_processed.csv
# → P054_id008_meme_ncc_processed.csv
# → P054_id009_meme_ncc_processed.csv
# → P054_id010_meme_ncc_processed.csv
# → P054_id011_ort_processed.csv
# → P054_id012_ort_processed.csv
# → P054_id013_ort_processed.csv
# → P054_id014_ort_processed.csv
# → P054_id015_ort_processed.csv
# → P054_id016_ort_processed.csv
# → P054_id017_ort_processed.csv
# → P054_id018_ort_processed.csv
# → P054_id019_ort_processed.csv
# → P054_id020_ort_processed.csv
# → P054_id021_ort_processed.csv
# → P054_id022_ort_processed.csv
# → P054_id023_ort_processed.csv
# → P054_id024_ort_processed.csv
# → P054_id025_ort_processed.csv
# → P054_id026_ort_processed.csv
# → P054_id027_ort_processed.csv
# → P054_id028_ort_processed.csv
# → P054_id029_ort_processed.csv
# → P054_id030_ort_processed.csv
# → P054_id031_ort_processed.csv
# → P054_id032_ort_processed.csv
# → P054_id033_person_processed.csv
# → P054_id034_person_processed.csv
# → P054_id035_person_processed.csv
# → P054_id036_person_processed.csv
# → P054_id037_person_processed.csv
# → P054_id038_person_processed.csv
# → P054_id039_person_processed.csv
# → P054_id040_person_processed.csv
# → P054_id041_person_processed.csv
# → P054_id042_person_processed.csv
# → P054_id043_person_processed.csv
# → P054_id044_person_processed.csv
# → P054_id045_person_processed.csv
# → P054_id046_person_processed.csv
# → P054_id047_person_processed.csv
# → P054_id048_person_processed.csv
# → P054_id049_person_processed.csv
# → P054_id050_person_processed.csv
# → P054_id051_person_processed.csv
# → P054_id052_person_processed.csv
# → P054_id053_person_processed.csv
# → P054_id054_person_processed.csv
# → P054_id055_person_processed.csv
# → P054_id056_person_processed.csv
# → P054_id057_person_processed.csv
# → P054_id058_person_processed.csv
# → P054_id059_person_processed.csv
# → P054_id060_person_processed.csv
# → P054_id061_person_processed.csv
# → P054_id062_person_processed.csv
# → P054_id063_person_processed.csv
# → P054_id064_person_processed.csv
# → P054_id065_person_processed.csv
# → P054_id066_person_processed.csv
# → P054_id067_person_processed.csv
# → P054_id068_person_processed.csv
# → P054_id069_person_processed.csv
# → P054_id070_person_processed.csv
# → P054_id071_person_processed.csv
# → P054_id072_person_processed.csv
# → P054_id073_person_processed.csv
# → P054_id074_person_processed.csv
# → P054_id075_person_processed.csv
# → P054_id076_person_processed.csv
# → P054_id077_person_processed.csv
# → P054_id078_person_processed.csv
# → P054_id079_person_processed.csv
# → P054_id080_person_processed.csv
# → P054_id081_person_processed.csv
# → P054_id082_person_processed.csv
# → P054_id083_person_processed.csv
# → P054_id084_person_processed.csv
# → P054_id085_person_processed.csv
# → P054_id086_person_processed.csv
# → P054_id087_person_processed.csv
# → P054_id088_politik_processed.csv
# → P054_id089_politik_processed.csv
# → P054_id090_politik_ncc_processed.csv
# → P054_id091_politik_ncc_processed.csv
# → P054_id092_politik_processed.csv
# → P054_id093_politik_processed.csv
# → P054_id094_politik_processed.csv
# → P054_id095_politik_processed.csv
# → P054_id096_politik_processed.csv
# → P054_id097_politik_processed.csv
# → P054_id098_politik_processed.csv
# → P054_id099_politik_processed.csv
# → P054_id100_politik_processed.csv
# → P054_id101_politik_processed.csv
# → P054_id102_politik_processed.csv
# → P054_id103_politik_processed.csv
# → P054_id104_politik_processed.csv
# → P054_id105_politik_processed.csv
# → P054_id106_textigm_meme_ncc_processed.csv
# → P054_id107_textimg_meme_ncc_processed.csv
# → P054_id108_textimg_meme_ncc_processed.csv
# → P054_id109_textimg_meme_ncc_processed.csv
# → P054_id110_textimg_meme_ncc_processed.csv
# → P054_id111_textimg_meme_ncc_processed.csv
# → P054_id112_textimg_meme_ncc_processed.csv
# → P054_id113_textimg_meme_ncc_processed.csv
# → P054_id114_textimg_meme_ncc_processed.csv
# → P054_id115_textimg_meme_ncc_processed.csv
# → P054_id116_textimg_meme_ncc_processed.csv
# → P054_id117_textimg_meme_ncc_processed.csv
# → P054_id118_textimg_meme_ncc_processed.csv
# → P054_id119_textimg_meme_ncc_processed.csv
# → P054_id120_textimg_meme_ncc_processed.csv
# → P054_id121_textimg_meme_ncc_processed.csv
# → P054_id122_textimg_meme_ncc_processed.csv
# → P054_id123_textimg_meme_ncc_processed.csv
# → P054_id124_textimg_meme_ncc_processed.csv
# → P054_id125_textimg_meme_ncc_processed.csv
# → P054_id126_text_politik_processed.csv
# → P054_id127_textimg_ncc_processed.csv
# → P054_id128_textimg_processed.csv
# → P054_id129_textimg_ort_processed.csv
# → P054_id130_textimg_ort_processed.csv
# → P054_id131_textimg_person_processed.csv
# → P054_id132_textimg_person_ncc_processed.csv
# → P054_id133_textimg_person_ncc_processed.csv
# → P054_id134_textimg_person_politik_ncc_processed.csv
# → P054_id135_textimg_politik_processed.csv
# → P054_id136_textimg_politik_processed.csv
# → P054_id137_textimg_politik_processed.csv
# → P054_id138_textimg_politik_processed.csv
# → P054_id139_textimg_politik_processed.csv
# → P054_id140_textimg_politik_processed.csv
# → P054_id141_textimg_politik_ncc_processed.csv
# → P054_id142_text_processed.csv
# → P054_id143_text_processed.csv
# → P054_id144_text_processed.csv
# → P054_id146_processed.csv
# → P054_id147_text_ncc_processed.csv
# → P054_id148_text_ncc_processed.csv
# → P054_id149_text_ncc_processed.csv
# → P054_id150_text_ncc_processed.csv
# → P054_id151_text_ncc_processed.csv
# → P054_id152_text_ncc_processed.csv
# → P054_id153_text_ncc_processed.csv
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'system_time_stamp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 76
#      74 # === Notebook-Aufruf ===
#      75 folder = "raw"  # Pfad zu deinen Roh-CSV-Dateien
# ---> 76 run_processing(folder)
#
# Cell In[3], line 72, in run_processing(folder)
#      70 os.makedirs(processed_dir, exist_ok=True)
#      71 for fp in glob.glob(os.path.join(folder, "*.csv")):
# ---> 72     process_file(fp, processed_dir)
#
# Cell In[3], line 17, in process_file(file_path, out_dir)
#      15 def process_file(file_path, out_dir):
#      16     df = pd.read_csv(file_path)
# ---> 17     df['millisecond'] = (df['system_time_stamp'] - df['system_time_stamp'].iloc[0]) / 1000
#      19     # 1) Erst in numeric casten, dann auf plausiblen Bereich maskieren
#      20     df['left_pupil_diameter']  = pd.to_numeric(df['left_pupil_diameter'],  errors='coerce')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'system_time_stamp'

# %%
import os
import glob

import numpy as np
import pandas as pd
from pandas.errors import EmptyDataError

def detect_fixations_with_pupil(df, dispersion_threshold=25, duration_threshold=100):
    """
    I-DT Algorithmus zur Fixationsdetektion mit mittlerer Pupillengröße.
    Erwartet Spalten: 'millisecond', 'x', 'y', 'pupil_size' (bereits plausibilisiert).
    Gibt DataFrame mit Spalten:
      ['start_time','end_time','duration','x','y','avg_pupil_size']
    """
    fixations = []
    x = df['x'].values
    y = df['y'].values
    p = df['pupil_size'].values
    t = df['millisecond'].values

    n = len(df)
    start = 0
    while start < n:
        end = start + 1
        # Fenster erweitern solange Dispersion ≤ threshold
        while end < n:
            win_x = x[start:end+1]
            win_y = y[start:end+1]
            if (win_x.max() - win_x.min() <= dispersion_threshold and
                win_y.max() - win_y.min() <= dispersion_threshold):
                end += 1
            else:
                break
        duration = t[end-1] - t[start]
        if duration >= duration_threshold:
            avg_pupil = np.nanmean(p[start:end])
            fixations.append({
                'start_time':     t[start],
                'end_time':       t[end-1],
                'duration':       duration,
                'x':              win_x.mean(),
                'y':              win_y.mean(),
                'avg_pupil_size': avg_pupil
            })
            start = end
        else:
            start += 1

    return pd.DataFrame(fixations)

def process_fixations_with_normalized_pupil(processed_folder, output_folder,
                                            dispersion_threshold=25, duration_threshold=100):
    """
    Liest alle *_processed.csv (mit plausibilisierter pupil_size) aus processed_folder ein,
    berechnet Fixationen inkl. avg_pupil_size, normalisiert avg_pupil_size pro Datei,
    und speichert als *_fixations.csv in output_folder.
    """
    os.makedirs(output_folder, exist_ok=True)
    pattern = os.path.join(processed_folder, "*_processed.csv")
    for path in glob.glob(pattern):
        subj = os.path.splitext(os.path.basename(path))[0].replace("_processed", "")
        try:
            df = pd.read_csv(path)
        except EmptyDataError:
            print(f"Skipping {subj}: empty or invalid processed file")
            continue
        if df.empty:
            print(f"Skipping {subj}: no data")
            continue

        # Fixation detection
        fix_df = detect_fixations_with_pupil(df, dispersion_threshold, duration_threshold)
        if fix_df.empty:
            print(f"No fixations for {subj}")
            continue

        # Normalisierung der avg_pupil_size (Z-Score pro Proband)
        mean_p = fix_df['avg_pupil_size'].mean()
        std_p = fix_df['avg_pupil_size'].std()
        fix_df['pupil_size_norm'] = (fix_df['avg_pupil_size'] - mean_p) / std_p

        # Speichern
        out_csv = os.path.join(output_folder, f"{subj}_fixations.csv")
        fix_df.to_csv(out_csv, index=False)
        print(f"Saved fixations with normalized pupil size: {os.path.basename(out_csv)}")

# ==== Notebook-Aufruf ====
processed_folder   = "processed"                # Ordner mit *_processed.csv
fixations_folder   = "processed/fixations"      # Zielordner für *_fixations.csv
process_fixations_with_normalized_pupil(processed_folder, fixations_folder)
# Out:
# Saved fixations with normalized pupil size: P000_id001_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id002_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id003_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id004_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id005_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id006_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id007_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id008_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id009_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id010_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id011_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id012_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id013_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id014_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id015_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id016_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id017_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id018_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id019_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id020_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id021_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id022_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id023_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id024_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id025_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id026_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id027_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id028_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id029_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id030_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id031_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id032_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id033_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id034_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id035_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id036_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id037_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id038_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id039_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id040_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id041_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id042_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id043_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id044_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id045_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id046_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id047_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id048_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id049_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id050_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id051_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id052_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id053_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id054_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id055_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id056_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id057_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id058_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id059_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id060_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id061_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id062_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id063_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id064_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id065_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id066_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id067_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id068_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id069_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id070_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id071_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id072_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id073_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id074_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id075_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id076_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id077_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id078_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id079_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id080_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id081_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id082_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id083_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id084_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id085_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id086_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id087_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id088_politik_fixations.csv
# Saved fixations with normalized pupil size: P000_id089_politik_fixations.csv
# Saved fixations with normalized pupil size: P000_id090_politik_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id091_politik_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id092_politik_fixations.csv
# Saved fixations with normalized pupil size: P000_id093_politik_fixations.csv
# Saved fixations with normalized pupil size: P000_id094_politik_fixations.csv
# Saved fixations with normalized pupil size: P000_id095_politik_fixations.csv
# Saved fixations with normalized pupil size: P000_id096_politik_fixations.csv
# Saved fixations with normalized pupil size: P000_id097_politik_fixations.csv
# Saved fixations with normalized pupil size: P000_id098_politik_fixations.csv
# Saved fixations with normalized pupil size: P000_id099_politik_fixations.csv
# Saved fixations with normalized pupil size: P000_id100_politik_fixations.csv
# Saved fixations with normalized pupil size: P000_id101_politik_fixations.csv
# Saved fixations with normalized pupil size: P000_id102_politik_fixations.csv
# Saved fixations with normalized pupil size: P000_id103_politik_fixations.csv
# Saved fixations with normalized pupil size: P000_id104_politik_fixations.csv
# Saved fixations with normalized pupil size: P000_id105_politik_fixations.csv
# Saved fixations with normalized pupil size: P000_id106_textigm_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id107_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id108_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id109_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id110_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id111_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id112_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id113_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id114_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id115_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id116_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id117_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id118_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id119_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id120_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id121_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id122_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id123_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id124_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id125_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id126_text_politik_fixations.csv
# Saved fixations with normalized pupil size: P000_id127_textimg_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id128_textimg_fixations.csv
# Saved fixations with normalized pupil size: P000_id129_textimg_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id130_textimg_ort_fixations.csv
# Saved fixations with normalized pupil size: P000_id131_textimg_person_fixations.csv
# Saved fixations with normalized pupil size: P000_id132_textimg_person_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id133_textimg_person_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id134_textimg_person_politik_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id135_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P000_id136_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P000_id137_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P000_id138_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P000_id139_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P000_id140_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P000_id141_textimg_politik_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id142_text_fixations.csv
# Saved fixations with normalized pupil size: P000_id143_text_fixations.csv
# Saved fixations with normalized pupil size: P000_id144_text_fixations.csv
# Saved fixations with normalized pupil size: P000_id146_fixations.csv
# Saved fixations with normalized pupil size: P000_id147_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id148_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id149_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id150_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id151_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id152_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P000_id153_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id001_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id002_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id003_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id004_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id005_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id006_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id007_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id008_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id009_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id010_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id011_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id012_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id013_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id014_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id015_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id016_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id017_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id018_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id019_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id020_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id021_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id022_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id023_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id024_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id025_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id026_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id027_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id028_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id029_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id030_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id031_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id032_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id033_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id034_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id035_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id036_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id037_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id038_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id039_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id040_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id041_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id042_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id043_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id044_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id046_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id047_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id048_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id049_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id050_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id051_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id052_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id053_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id054_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id055_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id056_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id057_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id058_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id059_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id060_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id061_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id062_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id063_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id064_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id065_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id066_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id067_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id068_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id069_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id070_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id071_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id072_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id073_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id074_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id075_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id076_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id077_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id078_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id079_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id080_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id081_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id082_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id083_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id084_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id085_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id086_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id087_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id088_politik_fixations.csv
# Saved fixations with normalized pupil size: P001_id089_politik_fixations.csv
# Saved fixations with normalized pupil size: P001_id090_politik_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id091_politik_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id092_politik_fixations.csv
# Saved fixations with normalized pupil size: P001_id093_politik_fixations.csv
# Saved fixations with normalized pupil size: P001_id094_politik_fixations.csv
# Saved fixations with normalized pupil size: P001_id095_politik_fixations.csv
# Saved fixations with normalized pupil size: P001_id096_politik_fixations.csv
# Saved fixations with normalized pupil size: P001_id097_politik_fixations.csv
# Saved fixations with normalized pupil size: P001_id098_politik_fixations.csv
# Saved fixations with normalized pupil size: P001_id099_politik_fixations.csv
# Saved fixations with normalized pupil size: P001_id100_politik_fixations.csv
# Saved fixations with normalized pupil size: P001_id101_politik_fixations.csv
# Saved fixations with normalized pupil size: P001_id102_politik_fixations.csv
# Saved fixations with normalized pupil size: P001_id103_politik_fixations.csv
# Saved fixations with normalized pupil size: P001_id104_politik_fixations.csv
# Saved fixations with normalized pupil size: P001_id105_politik_fixations.csv
# Saved fixations with normalized pupil size: P001_id106_textigm_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id107_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id108_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id109_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id110_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id111_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id112_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id113_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id114_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id115_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id116_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id117_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id118_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id119_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id120_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id121_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id122_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id123_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id124_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id125_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id126_text_politik_fixations.csv
# Saved fixations with normalized pupil size: P001_id127_textimg_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id128_textimg_fixations.csv
# Saved fixations with normalized pupil size: P001_id129_textimg_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id130_textimg_ort_fixations.csv
# Saved fixations with normalized pupil size: P001_id131_textimg_person_fixations.csv
# Saved fixations with normalized pupil size: P001_id132_textimg_person_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id133_textimg_person_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id134_textimg_person_politik_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id135_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P001_id136_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P001_id137_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P001_id138_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P001_id139_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P001_id140_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P001_id141_textimg_politik_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id142_text_fixations.csv
# Saved fixations with normalized pupil size: P001_id143_text_fixations.csv
# Saved fixations with normalized pupil size: P001_id144_text_fixations.csv
# Saved fixations with normalized pupil size: P001_id146_fixations.csv
# Saved fixations with normalized pupil size: P001_id147_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id148_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id149_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id150_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id151_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id152_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P001_id153_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id001_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id002_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id003_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id004_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id005_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id006_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id007_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id008_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id009_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id010_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id011_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id012_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id013_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id014_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id015_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id016_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id017_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id018_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id019_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id020_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id021_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id022_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id023_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id024_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id025_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id026_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id027_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id028_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id029_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id030_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id031_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id032_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id033_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id034_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id035_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id036_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id037_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id038_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id039_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id040_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id041_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id042_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id043_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id044_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id045_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id046_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id047_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id048_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id049_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id050_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id051_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id052_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id053_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id054_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id055_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id056_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id057_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id058_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id059_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id060_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id061_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id062_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id063_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id064_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id065_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id066_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id067_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id068_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id069_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id070_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id071_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id072_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id073_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id074_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id075_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id076_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id077_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id078_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id079_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id080_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id081_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id082_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id083_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id084_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id085_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id086_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id087_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id089_politik_fixations.csv
# Saved fixations with normalized pupil size: P002_id090_politik_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id091_politik_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id092_politik_fixations.csv
# Saved fixations with normalized pupil size: P002_id093_politik_fixations.csv
# Saved fixations with normalized pupil size: P002_id094_politik_fixations.csv
# Saved fixations with normalized pupil size: P002_id095_politik_fixations.csv
# Saved fixations with normalized pupil size: P002_id096_politik_fixations.csv
# Saved fixations with normalized pupil size: P002_id097_politik_fixations.csv
# Saved fixations with normalized pupil size: P002_id098_politik_fixations.csv
# Saved fixations with normalized pupil size: P002_id099_politik_fixations.csv
# Saved fixations with normalized pupil size: P002_id100_politik_fixations.csv
# Saved fixations with normalized pupil size: P002_id101_politik_fixations.csv
# Saved fixations with normalized pupil size: P002_id102_politik_fixations.csv
# Saved fixations with normalized pupil size: P002_id103_politik_fixations.csv
# Saved fixations with normalized pupil size: P002_id104_politik_fixations.csv
# Saved fixations with normalized pupil size: P002_id105_politik_fixations.csv
# Saved fixations with normalized pupil size: P002_id106_textigm_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id107_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id108_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id109_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id110_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id111_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id112_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id113_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id114_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id115_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id116_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id117_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id118_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id119_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id120_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id121_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id122_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id123_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id124_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id125_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id126_text_politik_fixations.csv
# Saved fixations with normalized pupil size: P002_id127_textimg_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id128_textimg_fixations.csv
# Saved fixations with normalized pupil size: P002_id129_textimg_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id130_textimg_ort_fixations.csv
# Saved fixations with normalized pupil size: P002_id131_textimg_person_fixations.csv
# Saved fixations with normalized pupil size: P002_id132_textimg_person_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id133_textimg_person_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id134_textimg_person_politik_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id135_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P002_id136_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P002_id137_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P002_id138_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P002_id139_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P002_id140_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P002_id141_textimg_politik_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id142_text_fixations.csv
# Saved fixations with normalized pupil size: P002_id143_text_fixations.csv
# Saved fixations with normalized pupil size: P002_id144_text_fixations.csv
# Saved fixations with normalized pupil size: P002_id146_fixations.csv
# Saved fixations with normalized pupil size: P002_id147_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id148_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id149_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id150_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id151_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id152_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P002_id153_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id001_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id002_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id003_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id004_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id005_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id006_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id007_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id009_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id010_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id011_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id012_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id013_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id014_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id015_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id016_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id017_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id018_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id019_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id020_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id021_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id022_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id023_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id024_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id025_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id026_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id027_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id028_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id029_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id030_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id031_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id032_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id033_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id034_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id035_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id036_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id037_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id038_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id039_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id040_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id041_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id042_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id043_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id044_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id045_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id046_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id047_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id048_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id049_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id050_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id051_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id052_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id053_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id054_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id055_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id056_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id057_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id058_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id059_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id060_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id061_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id062_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id063_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id064_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id065_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id066_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id067_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id068_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id069_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id070_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id071_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id072_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id073_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id074_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id075_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id076_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id077_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id078_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id079_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id080_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id081_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id082_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id083_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id084_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id085_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id086_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id087_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id088_politik_fixations.csv
# Saved fixations with normalized pupil size: P004_id089_politik_fixations.csv
# Saved fixations with normalized pupil size: P004_id090_politik_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id091_politik_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id092_politik_fixations.csv
# Saved fixations with normalized pupil size: P004_id093_politik_fixations.csv
# Saved fixations with normalized pupil size: P004_id094_politik_fixations.csv
# Saved fixations with normalized pupil size: P004_id095_politik_fixations.csv
# Saved fixations with normalized pupil size: P004_id096_politik_fixations.csv
# Saved fixations with normalized pupil size: P004_id097_politik_fixations.csv
# Saved fixations with normalized pupil size: P004_id098_politik_fixations.csv
# Saved fixations with normalized pupil size: P004_id099_politik_fixations.csv
# Saved fixations with normalized pupil size: P004_id100_politik_fixations.csv
# Saved fixations with normalized pupil size: P004_id101_politik_fixations.csv
# Saved fixations with normalized pupil size: P004_id102_politik_fixations.csv
# Saved fixations with normalized pupil size: P004_id103_politik_fixations.csv
# Saved fixations with normalized pupil size: P004_id104_politik_fixations.csv
# Saved fixations with normalized pupil size: P004_id105_politik_fixations.csv
# Saved fixations with normalized pupil size: P004_id106_textigm_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id107_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id108_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id109_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id110_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id111_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id112_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id113_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id114_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id115_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id116_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id117_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id118_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id119_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id120_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id121_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id122_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id123_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id124_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id125_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id126_text_politik_fixations.csv
# Saved fixations with normalized pupil size: P004_id127_textimg_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id128_textimg_fixations.csv
# Saved fixations with normalized pupil size: P004_id129_textimg_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id130_textimg_ort_fixations.csv
# Saved fixations with normalized pupil size: P004_id131_textimg_person_fixations.csv
# Saved fixations with normalized pupil size: P004_id132_textimg_person_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id133_textimg_person_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id134_textimg_person_politik_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id135_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P004_id136_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P004_id137_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P004_id138_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P004_id139_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P004_id140_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P004_id141_textimg_politik_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id142_text_fixations.csv
# Saved fixations with normalized pupil size: P004_id143_text_fixations.csv
# Saved fixations with normalized pupil size: P004_id144_text_fixations.csv
# Saved fixations with normalized pupil size: P004_id146_fixations.csv
# Saved fixations with normalized pupil size: P004_id147_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id148_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id149_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id150_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id151_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id152_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P004_id153_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P005_id001_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P005_id002_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P005_id003_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P005_id004_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P005_id005_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P005_id006_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P005_id007_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P005_id008_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P005_id009_meme_ncc_fixations.csv
# ...
# Saved fixations with normalized pupil size: P053_id101_politik_fixations.csv
# Saved fixations with normalized pupil size: P053_id102_politik_fixations.csv
# Saved fixations with normalized pupil size: P053_id103_politik_fixations.csv
# Saved fixations with normalized pupil size: P053_id104_politik_fixations.csv
# Saved fixations with normalized pupil size: P053_id105_politik_fixations.csv
# Saved fixations with normalized pupil size: P053_id106_textigm_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id107_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id108_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id109_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id110_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id111_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id112_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id113_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id114_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id115_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id116_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id117_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id118_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id119_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id120_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id121_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id122_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id123_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id124_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id125_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id126_text_politik_fixations.csv
# Saved fixations with normalized pupil size: P053_id127_textimg_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id128_textimg_fixations.csv
# Saved fixations with normalized pupil size: P053_id129_textimg_ort_fixations.csv
# Saved fixations with normalized pupil size: P053_id130_textimg_ort_fixations.csv
# Saved fixations with normalized pupil size: P053_id131_textimg_person_fixations.csv
# Saved fixations with normalized pupil size: P053_id132_textimg_person_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id133_textimg_person_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id134_textimg_person_politik_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id135_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P053_id136_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P053_id137_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P053_id138_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P053_id139_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P053_id140_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P053_id141_textimg_politik_ncc_fixations.csv
# No fixations for P053_id142_text
# Saved fixations with normalized pupil size: P053_id143_text_fixations.csv
# Saved fixations with normalized pupil size: P053_id144_text_fixations.csv
# Saved fixations with normalized pupil size: P053_id146_fixations.csv
# Saved fixations with normalized pupil size: P053_id147_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id148_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id149_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id150_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id151_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id152_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P053_id153_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id001_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id002_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id003_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id004_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id005_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id006_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id007_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id008_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id009_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id010_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id011_ort_fixations.csv
# Saved fixations with normalized pupil size: P054_id012_ort_fixations.csv
# Saved fixations with normalized pupil size: P054_id013_ort_fixations.csv
# Saved fixations with normalized pupil size: P054_id014_ort_fixations.csv
# Saved fixations with normalized pupil size: P054_id015_ort_fixations.csv
# Saved fixations with normalized pupil size: P054_id016_ort_fixations.csv
# Saved fixations with normalized pupil size: P054_id017_ort_fixations.csv
# Saved fixations with normalized pupil size: P054_id018_ort_fixations.csv
# Skipping P054_id019_ort: no data
# Saved fixations with normalized pupil size: P054_id020_ort_fixations.csv
# Saved fixations with normalized pupil size: P054_id021_ort_fixations.csv
# Saved fixations with normalized pupil size: P054_id022_ort_fixations.csv
# Saved fixations with normalized pupil size: P054_id023_ort_fixations.csv
# Saved fixations with normalized pupil size: P054_id024_ort_fixations.csv
# Saved fixations with normalized pupil size: P054_id025_ort_fixations.csv
# Saved fixations with normalized pupil size: P054_id026_ort_fixations.csv
# Saved fixations with normalized pupil size: P054_id027_ort_fixations.csv
# Saved fixations with normalized pupil size: P054_id028_ort_fixations.csv
# Saved fixations with normalized pupil size: P054_id029_ort_fixations.csv
# Saved fixations with normalized pupil size: P054_id030_ort_fixations.csv
# Saved fixations with normalized pupil size: P054_id031_ort_fixations.csv
# Saved fixations with normalized pupil size: P054_id032_ort_fixations.csv
# Saved fixations with normalized pupil size: P054_id033_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id034_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id035_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id036_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id037_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id038_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id039_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id040_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id041_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id042_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id043_person_fixations.csv
# Skipping P054_id044_person: no data
# Saved fixations with normalized pupil size: P054_id045_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id046_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id047_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id048_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id049_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id050_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id051_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id052_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id053_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id054_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id055_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id056_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id057_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id058_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id059_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id060_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id061_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id062_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id063_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id064_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id065_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id066_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id067_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id068_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id069_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id070_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id071_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id072_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id073_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id074_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id075_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id076_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id077_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id078_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id079_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id080_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id081_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id082_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id083_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id084_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id085_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id086_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id087_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id088_politik_fixations.csv
# Saved fixations with normalized pupil size: P054_id089_politik_fixations.csv
# Saved fixations with normalized pupil size: P054_id090_politik_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id091_politik_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id092_politik_fixations.csv
# Saved fixations with normalized pupil size: P054_id093_politik_fixations.csv
# Saved fixations with normalized pupil size: P054_id094_politik_fixations.csv
# Saved fixations with normalized pupil size: P054_id095_politik_fixations.csv
# Saved fixations with normalized pupil size: P054_id096_politik_fixations.csv
# Saved fixations with normalized pupil size: P054_id097_politik_fixations.csv
# Saved fixations with normalized pupil size: P054_id098_politik_fixations.csv
# Saved fixations with normalized pupil size: P054_id099_politik_fixations.csv
# Saved fixations with normalized pupil size: P054_id100_politik_fixations.csv
# Saved fixations with normalized pupil size: P054_id101_politik_fixations.csv
# Saved fixations with normalized pupil size: P054_id102_politik_fixations.csv
# Saved fixations with normalized pupil size: P054_id103_politik_fixations.csv
# Saved fixations with normalized pupil size: P054_id104_politik_fixations.csv
# Saved fixations with normalized pupil size: P054_id105_politik_fixations.csv
# Saved fixations with normalized pupil size: P054_id106_textigm_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id107_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id108_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id109_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id110_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id111_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id112_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id113_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id114_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id115_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id116_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id117_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id118_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id119_textimg_meme_ncc_fixations.csv
# Skipping P054_id120_textimg_meme_ncc: no data
# Saved fixations with normalized pupil size: P054_id121_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id122_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id123_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id124_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id125_textimg_meme_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id126_text_politik_fixations.csv
# Saved fixations with normalized pupil size: P054_id127_textimg_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id128_textimg_fixations.csv
# Saved fixations with normalized pupil size: P054_id129_textimg_ort_fixations.csv
# Saved fixations with normalized pupil size: P054_id130_textimg_ort_fixations.csv
# Saved fixations with normalized pupil size: P054_id131_textimg_person_fixations.csv
# Saved fixations with normalized pupil size: P054_id132_textimg_person_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id133_textimg_person_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id134_textimg_person_politik_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id135_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P054_id136_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P054_id137_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P054_id138_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P054_id139_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P054_id140_textimg_politik_fixations.csv
# Saved fixations with normalized pupil size: P054_id141_textimg_politik_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id142_text_fixations.csv
# Saved fixations with normalized pupil size: P054_id143_text_fixations.csv
# Saved fixations with normalized pupil size: P054_id144_text_fixations.csv
# Skipping P054_id146: no data
# Saved fixations with normalized pupil size: P054_id147_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id148_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id149_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id150_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id151_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id152_text_ncc_fixations.csv
# Saved fixations with normalized pupil size: P054_id153_text_ncc_fixations.csv

# %%
import os
import glob

def delete_double_processed(folder_path):
    """
    Löscht alle Dateien im Ordner, deren Name vor 'processed' zwei Unterstriche enthält,
    z. B. 'P025_id057_person__processed.csv' oder '…__processed.txt'.
    """
    pattern = os.path.join(folder_path, "*__processed*")
    for file_path in glob.glob(pattern):
        try:
            os.remove(file_path)
            print(f"Deleted: {os.path.basename(file_path)}")
        except OSError as e:
            print(f"Error deleting {os.path.basename(file_path)}: {e}")

# === Anwendung im Notebook ===
folder = "raw/processed"  # <-- anpassen!
delete_double_processed(folder)
# Out:
# Deleted: P001_id001_meme_ncc__processed.csv
# Deleted: P001_id002_meme_ncc__processed.csv
# Deleted: P001_id003_meme_ncc__processed.csv
# Deleted: P001_id004_meme_ncc__processed.csv
# Deleted: P001_id005_meme_ncc__processed.csv
# Deleted: P001_id006_meme_ncc__processed.csv
# Deleted: P001_id007_meme_ncc__processed.csv
# Deleted: P001_id008_meme_ncc__processed.csv
# Deleted: P001_id009_meme_ncc__processed.csv
# Deleted: P001_id010_meme_ncc__processed.csv
# Deleted: P001_id011_ort__processed.csv
# Deleted: P001_id012_ort__processed.csv
# Deleted: P001_id013_ort__processed.csv
# Deleted: P001_id014_ort__processed.csv
# Deleted: P001_id015_ort__processed.csv
# Deleted: P001_id016_ort__processed.csv
# Deleted: P001_id017_ort__processed.csv
# Deleted: P001_id018_ort__processed.csv
# Deleted: P001_id019_ort__processed.csv
# Deleted: P001_id020_ort__processed.csv
# Deleted: P001_id021_ort__processed.csv
# Deleted: P001_id022_ort__processed.csv
# Deleted: P001_id023_ort__processed.csv
# Deleted: P001_id024_ort__processed.csv
# Deleted: P001_id025_ort__processed.csv
# Deleted: P001_id026_ort__processed.csv
# Deleted: P001_id027_ort__processed.csv
# Deleted: P001_id028_ort__processed.csv
# Deleted: P001_id029_ort__processed.csv
# Deleted: P001_id030_ort__processed.csv
# Deleted: P001_id031_ort__processed.csv
# Deleted: P001_id032_ort__processed.csv
# Deleted: P001_id033_person__processed.csv
# Deleted: P001_id034_person__processed.csv
# Deleted: P001_id035_person__processed.csv
# Deleted: P001_id036_person__processed.csv
# Deleted: P001_id037_person__processed.csv
# Deleted: P003_id140_textimg_politik__processed.csv
# Deleted: P003_id141_textimg_politik_ncc__processed.csv
# Deleted: P003_id142_text__processed.csv
# Deleted: P003_id143_text__processed.csv
# Deleted: P003_id144_text__processed.csv
# Deleted: P003_id147_text_ncc__processed.csv
# Deleted: P003_id148_text_ncc__processed.csv
# Deleted: P003_id149_text_ncc__processed.csv
# Deleted: P003_id150_text_ncc__processed.csv
# Deleted: P003_id151_text_ncc__processed.csv
# Deleted: P003_id152_text_ncc__processed.csv
# Deleted: P003_id153_text_ncc__processed.csv
# Deleted: P004_id001_meme_ncc__processed.csv
# Deleted: P004_id002_meme_ncc__processed.csv
# Deleted: P004_id003_meme_ncc__processed.csv
# Deleted: P004_id004_meme_ncc__processed.csv
# Deleted: P004_id005_meme_ncc__processed.csv
# Deleted: P004_id006_meme_ncc__processed.csv
# Deleted: P004_id007_meme_ncc__processed.csv
# Deleted: P004_id008_meme_ncc__processed.csv
# Deleted: P004_id009_meme_ncc__processed.csv
# Deleted: P004_id010_meme_ncc__processed.csv
# Deleted: P004_id011_ort__processed.csv
# Deleted: P004_id012_ort__processed.csv
# Deleted: P004_id013_ort__processed.csv
# Deleted: P004_id014_ort__processed.csv
# Deleted: P004_id015_ort__processed.csv
# Deleted: P004_id016_ort__processed.csv
# Deleted: P004_id017_ort__processed.csv
# Deleted: P004_id018_ort__processed.csv
# Deleted: P004_id019_ort__processed.csv
# Deleted: P004_id020_ort__processed.csv
# Deleted: P004_id021_ort__processed.csv
# Deleted: P004_id022_ort__processed.csv
# Deleted: P004_id023_ort__processed.csv
# Deleted: P004_id024_ort__processed.csv
# Deleted: P004_id025_ort__processed.csv
# Deleted: P004_id026_ort__processed.csv
# Deleted: P004_id027_ort__processed.csv
# Deleted: P004_id028_ort__processed.csv
# Deleted: P004_id029_ort__processed.csv
# Deleted: P004_id030_ort__processed.csv
# Deleted: P004_id031_ort__processed.csv
# Deleted: P004_id032_ort__processed.csv
# Deleted: P004_id033_person__processed.csv
# Deleted: P004_id034_person__processed.csv
# Deleted: P004_id035_person__processed.csv
# Deleted: P004_id036_person__processed.csv
# Deleted: P004_id037_person__processed.csv
# Deleted: P004_id038_person__processed.csv
# Deleted: P004_id039_person__processed.csv
# Deleted: P004_id040_person__processed.csv
# Deleted: P004_id041_person__processed.csv
# Deleted: P004_id042_person__processed.csv
# Deleted: P004_id043_person__processed.csv
# Deleted: P004_id044_person__processed.csv
# Deleted: P004_id045_person__processed.csv
# Deleted: P004_id046_person__processed.csv
# Deleted: P004_id047_person__processed.csv
# Deleted: P004_id048_person__processed.csv
# Deleted: P004_id049_person__processed.csv
# Deleted: P004_id050_person__processed.csv
# Deleted: P004_id051_person__processed.csv
# Deleted: P004_id052_person__processed.csv
# Deleted: P004_id053_person__processed.csv
# Deleted: P004_id054_person__processed.csv
# Deleted: P004_id055_person__processed.csv
# Deleted: P004_id056_person__processed.csv
# Deleted: P004_id057_person__processed.csv
# Deleted: P004_id058_person__processed.csv
# Deleted: P004_id059_person__processed.csv
# Deleted: P004_id060_person__processed.csv
# Deleted: P004_id061_person__processed.csv
# Deleted: P004_id062_person__processed.csv
# Deleted: P004_id063_person__processed.csv
# Deleted: P004_id064_person__processed.csv
# Deleted: P004_id065_person__processed.csv
# Deleted: P004_id066_person__processed.csv
# Deleted: P004_id067_person__processed.csv
# Deleted: P004_id068_person__processed.csv
# Deleted: P004_id069_person__processed.csv
# Deleted: P004_id070_person__processed.csv
# Deleted: P004_id071_person__processed.csv
# Deleted: P004_id072_person__processed.csv
# Deleted: P004_id073_person__processed.csv
# Deleted: P004_id074_person__processed.csv
# Deleted: P004_id075_person__processed.csv
# Deleted: P004_id076_person__processed.csv
# Deleted: P004_id077_person__processed.csv
# Deleted: P004_id078_person__processed.csv
# Deleted: P004_id079_person__processed.csv
# Deleted: P004_id080_person__processed.csv
# Deleted: P004_id081_person__processed.csv
# Deleted: P004_id082_person__processed.csv
# Deleted: P004_id083_person__processed.csv
# Deleted: P004_id084_person__processed.csv
# Deleted: P004_id085_person__processed.csv
# Deleted: P004_id086_person__processed.csv
# Deleted: P004_id087_person__processed.csv
# Deleted: P004_id088_politik__processed.csv
# Deleted: P004_id089_politik__processed.csv
# Deleted: P004_id090_politik_ncc__processed.csv
# Deleted: P004_id091_politik_ncc__processed.csv
# Deleted: P004_id092_politik__processed.csv
# Deleted: P004_id093_politik__processed.csv
# Deleted: P004_id094_politik__processed.csv
# Deleted: P004_id095_politik__processed.csv
# Deleted: P004_id096_politik__processed.csv
# Deleted: P004_id097_politik__processed.csv
# Deleted: P004_id098_politik__processed.csv
# Deleted: P004_id099_politik__processed.csv
# Deleted: P004_id100_politik__processed.csv
# Deleted: P004_id101_politik__processed.csv
# Deleted: P004_id102_politik__processed.csv
# Deleted: P004_id103_politik__processed.csv
# Deleted: P004_id104_politik__processed.csv
# Deleted: P004_id105_politik__processed.csv
# Deleted: P004_id106_textigm_meme_ncc__processed.csv
# Deleted: P004_id107_textimg_meme_ncc__processed.csv
# Deleted: P004_id108_textimg_meme_ncc__processed.csv
# Deleted: P004_id109_textimg_meme_ncc__processed.csv
# Deleted: P004_id110_textimg_meme_ncc__processed.csv
# Deleted: P004_id111_textimg_meme_ncc__processed.csv
# Deleted: P004_id112_textimg_meme_ncc__processed.csv
# Deleted: P004_id113_textimg_meme_ncc__processed.csv
# Deleted: P004_id114_textimg_meme_ncc__processed.csv
# Deleted: P004_id115_textimg_meme_ncc__processed.csv
# Deleted: P004_id116_textimg_meme_ncc__processed.csv
# Deleted: P004_id117_textimg_meme_ncc__processed.csv
# Deleted: P004_id118_textimg_meme_ncc__processed.csv
# Deleted: P004_id119_textimg_meme_ncc__processed.csv
# Deleted: P004_id120_textimg_meme_ncc__processed.csv
# Deleted: P004_id121_textimg_meme_ncc__processed.csv
# Deleted: P004_id122_textimg_meme_ncc__processed.csv
# Deleted: P004_id123_textimg_meme_ncc__processed.csv
# Deleted: P004_id124_textimg_meme_ncc__processed.csv
# Deleted: P004_id125_textimg_meme_ncc__processed.csv
# Deleted: P004_id126_text_politik__processed.csv
# Deleted: P004_id127_textimg_ncc__processed.csv
# Deleted: P004_id128_textimg__processed.csv
# Deleted: P004_id129_textimg_ort__processed.csv
# Deleted: P004_id130_textimg_ort__processed.csv
# Deleted: P004_id131_textimg_person__processed.csv
# Deleted: P004_id132_textimg_person_ncc__processed.csv
# Deleted: P004_id133_textimg_person_ncc__processed.csv
# Deleted: P004_id134_textimg_person_politik_ncc__processed.csv
# Deleted: P004_id135_textimg_politik__processed.csv
# Deleted: P004_id136_textimg_politik__processed.csv
# Deleted: P004_id137_textimg_politik__processed.csv
# Deleted: P004_id138_textimg_politik__processed.csv
# Deleted: P004_id139_textimg_politik__processed.csv
# Deleted: P004_id140_textimg_politik__processed.csv
# Deleted: P004_id141_textimg_politik_ncc__processed.csv
# Deleted: P004_id142_text__processed.csv
# Deleted: P004_id143_text__processed.csv
# Deleted: P004_id144_text__processed.csv
# Deleted: P004_id147_text_ncc__processed.csv
# Deleted: P004_id148_text_ncc__processed.csv
# Deleted: P004_id149_text_ncc__processed.csv
# Deleted: P004_id150_text_ncc__processed.csv
# Deleted: P004_id151_text_ncc__processed.csv
# Deleted: P004_id152_text_ncc__processed.csv
# Deleted: P004_id153_text_ncc__processed.csv
# Deleted: P005_id001_meme_ncc__processed.csv
# Deleted: P005_id002_meme_ncc__processed.csv
# Deleted: P005_id003_meme_ncc__processed.csv
# Deleted: P005_id004_meme_ncc__processed.csv
# Deleted: P005_id005_meme_ncc__processed.csv
# Deleted: P005_id006_meme_ncc__processed.csv
# Deleted: P005_id007_meme_ncc__processed.csv
# Deleted: P005_id008_meme_ncc__processed.csv
# Deleted: P005_id009_meme_ncc__processed.csv
# Deleted: P005_id010_meme_ncc__processed.csv
# Deleted: P005_id011_ort__processed.csv
# Deleted: P005_id012_ort__processed.csv
# Deleted: P005_id013_ort__processed.csv
# Deleted: P005_id014_ort__processed.csv
# Deleted: P005_id015_ort__processed.csv
# Deleted: P005_id016_ort__processed.csv
# Deleted: P005_id017_ort__processed.csv
# Deleted: P005_id018_ort__processed.csv
# Deleted: P005_id019_ort__processed.csv
# Deleted: P005_id020_ort__processed.csv
# Deleted: P005_id021_ort__processed.csv
# Deleted: P005_id022_ort__processed.csv
# Deleted: P005_id023_ort__processed.csv
# Deleted: P005_id024_ort__processed.csv
# Deleted: P005_id025_ort__processed.csv
# Deleted: P005_id026_ort__processed.csv
# Deleted: P005_id027_ort__processed.csv
# Deleted: P005_id028_ort__processed.csv
# Deleted: P005_id029_ort__processed.csv
# Deleted: P005_id030_ort__processed.csv
# Deleted: P005_id031_ort__processed.csv
# Deleted: P005_id032_ort__processed.csv
# Deleted: P005_id033_person__processed.csv
# Deleted: P005_id034_person__processed.csv
# Deleted: P005_id035_person__processed.csv
# Deleted: P005_id036_person__processed.csv
# Deleted: P005_id037_person__processed.csv
# Deleted: P005_id038_person__processed.csv
# Deleted: P005_id039_person__processed.csv
# Deleted: P005_id040_person__processed.csv
# Deleted: P005_id041_person__processed.csv
# Deleted: P005_id042_person__processed.csv
# Deleted: P005_id043_person__processed.csv
# Deleted: P005_id044_person__processed.csv
# Deleted: P005_id045_person__processed.csv
# Deleted: P005_id046_person__processed.csv
# Deleted: P005_id047_person__processed.csv
# Deleted: P005_id048_person__processed.csv
# Deleted: P005_id049_person__processed.csv
# Deleted: P005_id050_person__processed.csv
# Deleted: P005_id051_person__processed.csv
# Deleted: P005_id052_person__processed.csv
# Deleted: P005_id053_person__processed.csv
# Deleted: P005_id054_person__processed.csv
# Deleted: P005_id055_person__processed.csv
# Deleted: P005_id056_person__processed.csv
# Deleted: P005_id057_person__processed.csv
# Deleted: P005_id058_person__processed.csv
# Deleted: P005_id059_person__processed.csv
# Deleted: P005_id060_person__processed.csv
# Deleted: P005_id061_person__processed.csv
# Deleted: P005_id062_person__processed.csv
# Deleted: P005_id063_person__processed.csv
# Deleted: P005_id064_person__processed.csv
# Deleted: P005_id065_person__processed.csv
# Deleted: P005_id066_person__processed.csv
# Deleted: P005_id067_person__processed.csv
# Deleted: P005_id068_person__processed.csv
# Deleted: P005_id069_person__processed.csv
# Deleted: P005_id070_person__processed.csv
# Deleted: P005_id071_person__processed.csv
# Deleted: P005_id072_person__processed.csv
# Deleted: P005_id073_person__processed.csv
# Deleted: P005_id074_person__processed.csv
# Deleted: P005_id075_person__processed.csv
# Deleted: P005_id076_person__processed.csv
# Deleted: P005_id077_person__processed.csv
# Deleted: P005_id078_person__processed.csv
# Deleted: P005_id079_person__processed.csv
# Deleted: P005_id080_person__processed.csv
# Deleted: P005_id081_person__processed.csv
# Deleted: P005_id082_person__processed.csv
# Deleted: P005_id083_person__processed.csv
# Deleted: P005_id084_person__processed.csv
# Deleted: P005_id085_person__processed.csv
# Deleted: P005_id086_person__processed.csv
# Deleted: P005_id087_person__processed.csv
# Deleted: P005_id088_politik__processed.csv
# Deleted: P005_id089_politik__processed.csv
# Deleted: P005_id090_politik_ncc__processed.csv
# Deleted: P005_id091_politik_ncc__processed.csv
# Deleted: P005_id092_politik__processed.csv
# Deleted: P005_id093_politik__processed.csv
# Deleted: P005_id094_politik__processed.csv
# Deleted: P005_id095_politik__processed.csv
# Deleted: P005_id096_politik__processed.csv
# Deleted: P005_id097_politik__processed.csv
# Deleted: P005_id098_politik__processed.csv
# Deleted: P005_id099_politik__processed.csv
# Deleted: P005_id100_politik__processed.csv
# Deleted: P005_id101_politik__processed.csv
# Deleted: P005_id102_politik__processed.csv
# Deleted: P005_id103_politik__processed.csv
# Deleted: P005_id104_politik__processed.csv
# Deleted: P005_id105_politik__processed.csv
# Deleted: P005_id106_textigm_meme_ncc__processed.csv
# Deleted: P005_id107_textimg_meme_ncc__processed.csv
# Deleted: P005_id108_textimg_meme_ncc__processed.csv
# Deleted: P005_id109_textimg_meme_ncc__processed.csv
# Deleted: P005_id110_textimg_meme_ncc__processed.csv
# Deleted: P005_id111_textimg_meme_ncc__processed.csv
# Deleted: P005_id112_textimg_meme_ncc__processed.csv
# Deleted: P006_id023_ort__processed.csv
# Deleted: P006_id024_ort__processed.csv
# Deleted: P006_id025_ort__processed.csv
# Deleted: P006_id026_ort__processed.csv
# Deleted: P006_id027_ort__processed.csv
# Deleted: P006_id028_ort__processed.csv
# Deleted: P006_id029_ort__processed.csv
# Deleted: P006_id030_ort__processed.csv
# Deleted: P006_id031_ort__processed.csv
# Deleted: P006_id032_ort__processed.csv
# Deleted: P006_id033_person__processed.csv
# Deleted: P006_id034_person__processed.csv
# Deleted: P006_id035_person__processed.csv
# Deleted: P006_id036_person__processed.csv
# Deleted: P006_id037_person__processed.csv
# Deleted: P006_id038_person__processed.csv
# Deleted: P006_id039_person__processed.csv
# Deleted: P006_id040_person__processed.csv
# Deleted: P006_id041_person__processed.csv
# Deleted: P006_id042_person__processed.csv
# Deleted: P006_id043_person__processed.csv
# Deleted: P006_id044_person__processed.csv
# Deleted: P006_id045_person__processed.csv
# Deleted: P006_id046_person__processed.csv
# Deleted: P006_id047_person__processed.csv
# Deleted: P006_id048_person__processed.csv
# Deleted: P006_id049_person__processed.csv
# Deleted: P006_id050_person__processed.csv
# Deleted: P006_id051_person__processed.csv
# Deleted: P006_id052_person__processed.csv
# Deleted: P006_id053_person__processed.csv
# Deleted: P006_id054_person__processed.csv
# Deleted: P006_id055_person__processed.csv
# Deleted: P006_id056_person__processed.csv
# Deleted: P006_id057_person__processed.csv
# Deleted: P006_id058_person__processed.csv
# Deleted: P006_id059_person__processed.csv
# Deleted: P006_id060_person__processed.csv
# Deleted: P006_id061_person__processed.csv
# Deleted: P006_id062_person__processed.csv
# Deleted: P006_id063_person__processed.csv
# Deleted: P006_id064_person__processed.csv
# Deleted: P006_id065_person__processed.csv
# Deleted: P006_id066_person__processed.csv
# Deleted: P006_id067_person__processed.csv
# Deleted: P006_id068_person__processed.csv
# Deleted: P006_id069_person__processed.csv
# Deleted: P006_id070_person__processed.csv
# Deleted: P006_id071_person__processed.csv
# Deleted: P006_id072_person__processed.csv
# Deleted: P006_id073_person__processed.csv
# Deleted: P006_id074_person__processed.csv
# Deleted: P006_id075_person__processed.csv
# Deleted: P006_id076_person__processed.csv
# Deleted: P006_id077_person__processed.csv
# Deleted: P006_id078_person__processed.csv
# Deleted: P006_id079_person__processed.csv
# Deleted: P006_id080_person__processed.csv
# Deleted: P006_id081_person__processed.csv
# Deleted: P006_id082_person__processed.csv
# Deleted: P006_id083_person__processed.csv
# Deleted: P006_id084_person__processed.csv
# Deleted: P006_id085_person__processed.csv
# Deleted: P006_id086_person__processed.csv
# Deleted: P006_id087_person__processed.csv
# Deleted: P006_id088_politik__processed.csv
# Deleted: P006_id089_politik__processed.csv
# Deleted: P006_id090_politik_ncc__processed.csv
# Deleted: P006_id091_politik_ncc__processed.csv
# Deleted: P006_id092_politik__processed.csv
# Deleted: P006_id093_politik__processed.csv
# Deleted: P006_id094_politik__processed.csv
# Deleted: P006_id095_politik__processed.csv
# Deleted: P006_id096_politik__processed.csv
# Deleted: P006_id097_politik__processed.csv
# Deleted: P047_id034_person__processed.csv
# Deleted: P047_id035_person__processed.csv
# Deleted: P047_id036_person__processed.csv
# Deleted: P047_id037_person__processed.csv
# Deleted: P047_id038_person__processed.csv
# Deleted: P047_id039_person__processed.csv
# Deleted: P047_id040_person__processed.csv
# Deleted: P047_id041_person__processed.csv
# Deleted: P047_id042_person__processed.csv
# Deleted: P047_id043_person__processed.csv
# Deleted: P047_id044_person__processed.csv
# Deleted: P047_id045_person__processed.csv
# Deleted: P047_id046_person__processed.csv
# Deleted: P047_id047_person__processed.csv
# Deleted: P047_id048_person__processed.csv
# Deleted: P047_id049_person__processed.csv
# Deleted: P047_id050_person__processed.csv
# Deleted: P047_id051_person__processed.csv
# Deleted: P047_id052_person__processed.csv
# Deleted: P047_id053_person__processed.csv
# Deleted: P047_id054_person__processed.csv
# Deleted: P047_id055_person__processed.csv
# Deleted: P047_id056_person__processed.csv
# Deleted: P047_id057_person__processed.csv
# Deleted: P047_id058_person__processed.csv
# Deleted: P047_id059_person__processed.csv
# Deleted: P047_id060_person__processed.csv
# Deleted: P047_id061_person__processed.csv
# Deleted: P047_id062_person__processed.csv
# Deleted: P047_id063_person__processed.csv
# Deleted: P047_id064_person__processed.csv
# Deleted: P047_id065_person__processed.csv
# Deleted: P047_id066_person__processed.csv
# Deleted: P047_id067_person__processed.csv
# Deleted: P047_id068_person__processed.csv
# Deleted: P047_id069_person__processed.csv
# Deleted: P047_id070_person__processed.csv
# Deleted: P047_id071_person__processed.csv
# Deleted: P047_id072_person__processed.csv
# Deleted: P047_id073_person__processed.csv
# Deleted: P047_id074_person__processed.csv
# Deleted: P047_id075_person__processed.csv
# Deleted: P047_id076_person__processed.csv
# Deleted: P047_id077_person__processed.csv
# Deleted: P047_id078_person__processed.csv
# Deleted: P047_id079_person__processed.csv
# Deleted: P047_id080_person__processed.csv
# Deleted: P047_id081_person__processed.csv
# Deleted: P047_id082_person__processed.csv
# Deleted: P047_id083_person__processed.csv
# Deleted: P047_id084_person__processed.csv
# Deleted: P047_id085_person__processed.csv
# Deleted: P047_id086_person__processed.csv
# Deleted: P047_id087_person__processed.csv
# Deleted: P047_id088_politik__processed.csv
# Deleted: P047_id089_politik__processed.csv
# Deleted: P047_id090_politik_ncc__processed.csv
# Deleted: P047_id091_politik_ncc__processed.csv
# Deleted: P047_id092_politik__processed.csv
# Deleted: P047_id093_politik__processed.csv
# Deleted: P047_id094_politik__processed.csv
# Deleted: P047_id095_politik__processed.csv
# Deleted: P047_id096_politik__processed.csv
# Deleted: P047_id097_politik__processed.csv
# Deleted: P047_id098_politik__processed.csv
# Deleted: P047_id099_politik__processed.csv
# Deleted: P047_id100_politik__processed.csv
# Deleted: P047_id101_politik__processed.csv
# Deleted: P047_id102_politik__processed.csv
# Deleted: P047_id103_politik__processed.csv
# Deleted: P047_id104_politik__processed.csv
# Deleted: P047_id105_politik__processed.csv
# Deleted: P047_id106_textigm_meme_ncc__processed.csv
# Deleted: P047_id107_textimg_meme_ncc__processed.csv
