# %%
import os
import re
import pandas as pd
from pathlib import Path
from typing import List, Dict

# --- Pfade anpassen ---
BASE = Path(".")  # aktueller Ordner
labels_path = BASE / "labels_per_id.csv"
search_dir = BASE / "fixations"  # Ordner mit den Fixations-CSV-Dateien

# --- Feste Kategorien und Bitreihenfolge ---
CATEGORIES = ["meme", "ort", "person", "politik", "text"]

# --- Hilfsfunktionen ---
fname_re = re.compile(r"^(P\d{3})_id(\d{3})_([a-zA-Z0-9\-]+)\.csv$")

def parse_filename(name: str):
    m = fname_re.match(name)
    if not m:
        return None
    participant, id_str, cat = m.groups()
    return participant, id_str, cat

def detect_label_columns(df: pd.DataFrame, categories: List[str]) -> List[str]:
    return [c for c in categories if c in df.columns]

def detect_weight_columns(df: pd.DataFrame, categories: List[str]) -> Dict[str, str]:
    lower_cols = {c.lower(): c for c in df.columns}
    mapping = {}
    for cat in categories:
        best = None
        for lc, orig in lower_cols.items():
            if "weight" in lc and cat in lc:
                best = orig
                break
            if re.search(rf"(^w[_\-]*{cat}|{cat}[_\-]*w$)", lc):
                best = orig
                break
        if best:
            mapping[cat] = best
    return mapping

def to_bitstring(row: pd.Series, label_cols: List[str], categories: List[str]) -> str:
    bits = []
    for cat in categories:
        if cat in label_cols:
            val = row[cat]
            bit = 1 if pd.notna(val) and (bool(val) and str(val) not in ("0", "False", "false")) else 0
        else:
            bit = 0
        bits.append(str(int(bit)))
    return "".join(bits)

def normalize_id(v):
    s = str(v)
    m = re.search(r"(\d{1,3})(?!.*\d)", s)
    if m:
        return f"{int(m.group(1)):03d}"
    return None

# --- Labels laden ---
labels_df = pd.read_csv(labels_path)

# ID-Spalte finden
id_col_candidates = ["id", "image_id", "img_id", "stim_id", "stimulus_id", "stimulus", "file_id"]
id_col = next((c for c in id_col_candidates if c in labels_df.columns), None)
if id_col is None:
    for c in labels_df.columns:
        if labels_df[c].astype(str).str.match(r"^P\d{3}_id\d{3}").any():
            id_col = c
            break
if id_col is None:
    raise ValueError("Keine ID-Spalte in labels_per_id.csv gefunden.")

labels_df["id3"] = labels_df[id_col].apply(normalize_id)

# Label- und Gewichtsspalten erkennen
label_cols = detect_label_columns(labels_df, CATEGORIES)
weight_cols_map = detect_weight_columns(labels_df, CATEGORIES)

# Bits erzeugen
labels_df["bits"] = labels_df.apply(lambda r: to_bitstring(r, label_cols, CATEGORIES), axis=1)

merge_cols = ["id3", "bits"] + list(set(weight_cols_map.values()))
labels_small = labels_df[merge_cols].copy()

# --- Fixations-Dateien verarbeiten (in-place) ---
processed = []
for csv_path in search_dir.glob("P*_id*_[a-zA-Z0-9-]*.csv"):
    name = csv_path.name
    parsed = parse_filename(name)
    if not parsed:
        continue
    participant, id3, cat = parsed

    row = labels_small[labels_small["id3"] == id3]
    if row.empty:
        processed.append({"original": name, "status": "SKIPPED"})
        continue

    r = row.iloc[0]
    bits = r["bits"]

    # CSV laden und Gewichte hinzufügen
    df_fix = pd.read_csv(csv_path)
    for cat_name, w_col in weight_cols_map.items():
        if w_col in row.columns:
            df_fix[f"weight_{cat_name}"] = r[w_col]

    # Datei direkt überschreiben
    df_fix.to_csv(csv_path, index=False)

    # Datei umbenennen (mit Bits)
    new_name = f"{name[:-4]}_{bits}.csv"
    new_path = csv_path.with_name(new_name)
    csv_path.rename(new_path)

    processed.append({
        "original": name,
        "new_name": new_name,
        "status": "OK",
        "path": str(new_path)
    })

# --- Ergebnisübersicht ---
report_df = pd.DataFrame(processed)
print(report_df)
# Out:
#                  original                   new_name status  \
# 0     P000_id001_meme.csv  P000_id001_meme_10000.csv     OK
# 1     P000_id002_meme.csv  P000_id002_meme_10000.csv     OK
# 2     P000_id003_meme.csv  P000_id003_meme_10000.csv     OK
# 3     P000_id004_meme.csv  P000_id004_meme_10000.csv     OK
# 4     P000_id005_meme.csv  P000_id005_meme_10000.csv     OK
# ...                   ...                        ...    ...
# 7357  P054_id149_text.csv  P054_id149_text_10001.csv     OK
# 7358  P054_id150_text.csv  P054_id150_text_10001.csv     OK
# 7359  P054_id151_text.csv  P054_id151_text_10011.csv     OK
# 7360  P054_id152_text.csv  P054_id152_text_10011.csv     OK
# 7361  P054_id153_text.csv  P054_id153_text_10011.csv     OK
#
#                                      path
# 0     fixations\P000_id001_meme_10000.csv
# 1     fixations\P000_id002_meme_10000.csv
# 2     fixations\P000_id003_meme_10000.csv
# 3     fixations\P000_id004_meme_10000.csv
# 4     fixations\P000_id005_meme_10000.csv
# ...                                   ...
# 7357  fixations\P054_id149_text_10001.csv
# 7358  fixations\P054_id150_text_10001.csv
# 7359  fixations\P054_id151_text_10011.csv
# 7360  fixations\P054_id152_text_10011.csv
# 7361  fixations\P054_id153_text_10011.csv
#
# [7362 rows x 4 columns]

# %%
import pandas as pd
from pathlib import Path

# Ordner mit deinen CSVs
fixations_dir = Path("fixations")

for csv_path in fixations_dir.glob("*.csv"):
    df = pd.read_csv(csv_path)

    # Alle Spalten finden, die mit "weight_" beginnen
    weight_cols = [col for col in df.columns if col.startswith("weight_")]

    if weight_cols:
        for col in weight_cols:
            if not df.empty:
                value = df.loc[0, col]  # ursprünglicher Wert aus erster Zeile
                df[col] = None          # alle Zellen leeren
                df.loc[0, col] = value  # nur erste Zeile setzen

        # Datei überschreiben
        df.to_csv(csv_path, index=False)
        print(f"angepasst: {csv_path.name}")
    else:
        print(f"keine weight-Spalten in: {csv_path.name}")
# Out:
# angepasst: P000_id001_meme_10000.csv
# angepasst: P000_id002_meme_10000.csv
# angepasst: P000_id003_meme_10000.csv
# angepasst: P000_id004_meme_10000.csv
# angepasst: P000_id005_meme_10000.csv
# angepasst: P000_id006_meme_10000.csv
# angepasst: P000_id007_meme_10000.csv
# angepasst: P000_id008_meme_10000.csv
# angepasst: P000_id009_meme_10000.csv
# angepasst: P000_id010_meme_10000.csv
# angepasst: P000_id011_ort_01001.csv
# angepasst: P000_id012_ort_01001.csv
# angepasst: P000_id013_ort_01001.csv
# angepasst: P000_id014_ort_01000.csv
# angepasst: P000_id015_ort_01001.csv
# angepasst: P000_id016_ort_01001.csv
# angepasst: P000_id017_ort_01001.csv
# angepasst: P000_id018_ort_01000.csv
# angepasst: P000_id019_ort_01000.csv
# angepasst: P000_id020_ort_01000.csv
# angepasst: P000_id021_ort_01000.csv
# angepasst: P000_id022_ort_01000.csv
# angepasst: P000_id023_ort_01000.csv
# angepasst: P000_id024_ort_01000.csv
# angepasst: P000_id025_ort_01000.csv
# angepasst: P000_id026_ort_01000.csv
# angepasst: P000_id027_ort_01000.csv
# angepasst: P000_id028_ort_01000.csv
# angepasst: P000_id029_ort_01000.csv
# angepasst: P000_id030_ort_01000.csv
# angepasst: P000_id031_ort_01000.csv
# angepasst: P000_id032_ort_01000.csv
# angepasst: P000_id033_person_00101.csv
# angepasst: P000_id034_person_00101.csv
# angepasst: P000_id035_person_00100.csv
# angepasst: P000_id036_person_00100.csv
# angepasst: P000_id037_person_00100.csv
# angepasst: P000_id038_person_00100.csv
# angepasst: P000_id039_person_00100.csv
# angepasst: P000_id040_person_00100.csv
# angepasst: P000_id041_person_00100.csv
# angepasst: P000_id042_person_00100.csv
# angepasst: P000_id043_person_00100.csv
# angepasst: P000_id044_person_00100.csv
# angepasst: P000_id045_person_00100.csv
# angepasst: P000_id046_person_00100.csv
# angepasst: P000_id047_person_00100.csv
# angepasst: P000_id048_person_00100.csv
# angepasst: P000_id049_person_00100.csv
# angepasst: P000_id050_person_00100.csv
# angepasst: P000_id051_person_00100.csv
# angepasst: P000_id052_person_00100.csv
# angepasst: P000_id053_person_00100.csv
# angepasst: P000_id054_person_00100.csv
# angepasst: P000_id055_person_00100.csv
# angepasst: P000_id056_person_00100.csv
# angepasst: P000_id057_person_00100.csv
# angepasst: P000_id058_person_00100.csv
# angepasst: P000_id059_person_00100.csv
# angepasst: P000_id060_person_00100.csv
# angepasst: P000_id061_person_00100.csv
# angepasst: P000_id062_person_00100.csv
# angepasst: P000_id063_person_00100.csv
# angepasst: P000_id064_person_00100.csv
# angepasst: P000_id065_person_00100.csv
# angepasst: P000_id066_person_00100.csv
# angepasst: P000_id067_person_00100.csv
# angepasst: P000_id068_person_00100.csv
# angepasst: P000_id069_person_00100.csv
# angepasst: P000_id070_person_00100.csv
# angepasst: P000_id071_person_00100.csv
# angepasst: P000_id072_person_00100.csv
# angepasst: P000_id073_person_00100.csv
# angepasst: P000_id074_person_00101.csv
# angepasst: P000_id075_person_00100.csv
# angepasst: P000_id076_person_00101.csv
# angepasst: P000_id077_person_00100.csv
# angepasst: P000_id078_person_00100.csv
# angepasst: P000_id079_person_00100.csv
# angepasst: P000_id080_person_00100.csv
# angepasst: P000_id081_person_00100.csv
# angepasst: P000_id082_person_00101.csv
# angepasst: P000_id083_person_00100.csv
# angepasst: P000_id084_person_00101.csv
# angepasst: P000_id085_person_00101.csv
# angepasst: P000_id086_person_00100.csv
# angepasst: P000_id087_person_00101.csv
# angepasst: P000_id088_politik_00111.csv
# angepasst: P000_id089_politik_00110.csv
# angepasst: P000_id090_politik_00110.csv
# angepasst: P000_id091_politik_00110.csv
# angepasst: P000_id092_politik_00111.csv
# angepasst: P000_id093_politik_00110.csv
# angepasst: P000_id094_politik_00110.csv
# angepasst: P000_id095_politik_00110.csv
# angepasst: P000_id096_politik_00110.csv
# angepasst: P000_id097_politik_00110.csv
# angepasst: P000_id098_politik_00110.csv
# angepasst: P000_id099_politik_00111.csv
# angepasst: P000_id100_politik_00111.csv
# angepasst: P000_id101_politik_00110.csv
# angepasst: P000_id102_politik_00111.csv
# angepasst: P000_id103_politik_00110.csv
# angepasst: P000_id104_politik_00110.csv
# angepasst: P000_id105_politik_00110.csv
# angepasst: P000_id106_meme_10011.csv
# angepasst: P000_id107_meme_10111.csv
# angepasst: P000_id108_meme_10001.csv
# angepasst: P000_id109_meme_10011.csv
# angepasst: P000_id110_meme_10001.csv
# angepasst: P000_id111_meme_10001.csv
# angepasst: P000_id112_meme_10001.csv
# angepasst: P000_id113_meme_10001.csv
# angepasst: P000_id114_meme_10001.csv
# angepasst: P000_id115_meme_10001.csv
# angepasst: P000_id116_meme_10011.csv
# angepasst: P000_id117_meme_10011.csv
# angepasst: P000_id118_meme_10001.csv
# angepasst: P000_id119_meme_10001.csv
# angepasst: P000_id120_meme_10001.csv
# angepasst: P000_id121_meme_10001.csv
# angepasst: P000_id122_meme_10011.csv
# angepasst: P000_id123_meme_10011.csv
# angepasst: P000_id124_meme_10011.csv
# angepasst: P000_id125_meme_10001.csv
# angepasst: P000_id126_politik_00011.csv
# angepasst: P000_id127_text_00011.csv
# angepasst: P000_id128_text_01001.csv
# angepasst: P000_id129_ort_01001.csv
# angepasst: P000_id130_ort_01001.csv
# angepasst: P000_id131_person_00111.csv
# angepasst: P000_id132_person_00101.csv
# angepasst: P000_id133_person_00101.csv
# angepasst: P000_id134_politik_00111.csv
# angepasst: P000_id135_politik_10111.csv
# angepasst: P000_id136_politik_00111.csv
# angepasst: P000_id137_politik_00111.csv
# angepasst: P000_id138_politik_00111.csv
# angepasst: P000_id139_politik_00111.csv
# angepasst: P000_id140_politik_00111.csv
# angepasst: P000_id141_politik_10011.csv
# angepasst: P000_id142_text_00001.csv
# angepasst: P000_id143_text_00001.csv
# angepasst: P000_id144_text_00001.csv
# angepasst: P000_id146_text_00011.csv
# angepasst: P000_id147_text_10001.csv
# angepasst: P000_id148_text_10001.csv
# angepasst: P000_id149_text_10001.csv
# angepasst: P000_id150_text_10001.csv
# angepasst: P000_id151_text_10011.csv
# angepasst: P000_id152_text_10011.csv
# angepasst: P000_id153_text_10011.csv
# angepasst: P001_id001_meme_10000.csv
# angepasst: P001_id002_meme_10000.csv
# angepasst: P001_id003_meme_10000.csv
# angepasst: P001_id004_meme_10000.csv
# angepasst: P001_id005_meme_10000.csv
# angepasst: P001_id006_meme_10000.csv
# angepasst: P001_id007_meme_10000.csv
# angepasst: P001_id008_meme_10000.csv
# angepasst: P001_id009_meme_10000.csv
# angepasst: P001_id010_meme_10000.csv
# angepasst: P001_id011_ort_01001.csv
# angepasst: P001_id012_ort_01001.csv
# angepasst: P001_id013_ort_01001.csv
# angepasst: P001_id014_ort_01000.csv
# angepasst: P001_id015_ort_01001.csv
# angepasst: P001_id016_ort_01001.csv
# angepasst: P001_id017_ort_01001.csv
# angepasst: P001_id018_ort_01000.csv
# angepasst: P001_id019_ort_01000.csv
# angepasst: P001_id020_ort_01000.csv
# angepasst: P001_id021_ort_01000.csv
# angepasst: P001_id022_ort_01000.csv
# angepasst: P001_id023_ort_01000.csv
# angepasst: P001_id024_ort_01000.csv
# angepasst: P001_id025_ort_01000.csv
# angepasst: P001_id026_ort_01000.csv
# angepasst: P001_id027_ort_01000.csv
# angepasst: P001_id028_ort_01000.csv
# angepasst: P001_id029_ort_01000.csv
# angepasst: P001_id030_ort_01000.csv
# angepasst: P001_id031_ort_01000.csv
# angepasst: P001_id032_ort_01000.csv
# angepasst: P001_id033_person_00101.csv
# angepasst: P001_id034_person_00101.csv
# angepasst: P001_id035_person_00100.csv
# angepasst: P001_id036_person_00100.csv
# angepasst: P001_id037_person_00100.csv
# angepasst: P001_id038_person_00100.csv
# angepasst: P001_id039_person_00100.csv
# angepasst: P001_id040_person_00100.csv
# angepasst: P001_id041_person_00100.csv
# angepasst: P001_id042_person_00100.csv
# angepasst: P001_id043_person_00100.csv
# angepasst: P001_id044_person_00100.csv
# angepasst: P001_id046_person_00100.csv
# angepasst: P001_id047_person_00100.csv
# angepasst: P001_id048_person_00100.csv
# angepasst: P001_id049_person_00100.csv
# angepasst: P001_id050_person_00100.csv
# angepasst: P001_id051_person_00100.csv
# angepasst: P001_id052_person_00100.csv
# angepasst: P001_id053_person_00100.csv
# angepasst: P001_id054_person_00100.csv
# angepasst: P001_id055_person_00100.csv
# angepasst: P001_id056_person_00100.csv
# angepasst: P001_id057_person_00100.csv
# angepasst: P001_id058_person_00100.csv
# angepasst: P001_id059_person_00100.csv
# angepasst: P001_id060_person_00100.csv
# angepasst: P001_id061_person_00100.csv
# angepasst: P001_id062_person_00100.csv
# angepasst: P001_id063_person_00100.csv
# angepasst: P001_id064_person_00100.csv
# angepasst: P001_id065_person_00100.csv
# angepasst: P001_id066_person_00100.csv
# angepasst: P001_id067_person_00100.csv
# angepasst: P001_id068_person_00100.csv
# angepasst: P001_id069_person_00100.csv
# angepasst: P001_id070_person_00100.csv
# angepasst: P001_id071_person_00100.csv
# angepasst: P001_id072_person_00100.csv
# angepasst: P001_id073_person_00100.csv
# angepasst: P001_id074_person_00101.csv
# angepasst: P001_id075_person_00100.csv
# angepasst: P001_id076_person_00101.csv
# angepasst: P001_id077_person_00100.csv
# angepasst: P001_id078_person_00100.csv
# angepasst: P001_id079_person_00100.csv
# angepasst: P001_id080_person_00100.csv
# angepasst: P001_id081_person_00100.csv
# angepasst: P001_id082_person_00101.csv
# angepasst: P001_id083_person_00100.csv
# angepasst: P001_id084_person_00101.csv
# angepasst: P001_id085_person_00101.csv
# angepasst: P001_id086_person_00100.csv
# angepasst: P001_id087_person_00101.csv
# angepasst: P001_id088_politik_00111.csv
# angepasst: P001_id089_politik_00110.csv
# angepasst: P001_id090_politik_00110.csv
# angepasst: P001_id091_politik_00110.csv
# angepasst: P001_id092_politik_00111.csv
# angepasst: P001_id093_politik_00110.csv
# angepasst: P001_id094_politik_00110.csv
# angepasst: P001_id095_politik_00110.csv
# angepasst: P001_id096_politik_00110.csv
# angepasst: P001_id097_politik_00110.csv
# angepasst: P001_id098_politik_00110.csv
# angepasst: P001_id099_politik_00111.csv
# angepasst: P001_id100_politik_00111.csv
# angepasst: P001_id101_politik_00110.csv
# angepasst: P001_id102_politik_00111.csv
# angepasst: P001_id103_politik_00110.csv
# angepasst: P001_id104_politik_00110.csv
# angepasst: P001_id105_politik_00110.csv
# angepasst: P001_id106_meme_10011.csv
# angepasst: P001_id107_meme_10111.csv
# angepasst: P001_id108_meme_10001.csv
# angepasst: P001_id109_meme_10011.csv
# angepasst: P001_id110_meme_10001.csv
# angepasst: P001_id111_meme_10001.csv
# angepasst: P001_id112_meme_10001.csv
# angepasst: P001_id113_meme_10001.csv
# angepasst: P001_id114_meme_10001.csv
# angepasst: P001_id115_meme_10001.csv
# angepasst: P001_id116_meme_10011.csv
# angepasst: P001_id117_meme_10011.csv
# angepasst: P001_id118_meme_10001.csv
# angepasst: P001_id119_meme_10001.csv
# angepasst: P001_id120_meme_10001.csv
# angepasst: P001_id121_meme_10001.csv
# angepasst: P001_id122_meme_10011.csv
# angepasst: P001_id123_meme_10011.csv
# angepasst: P001_id124_meme_10011.csv
# angepasst: P001_id125_meme_10001.csv
# angepasst: P001_id126_politik_00011.csv
# angepasst: P001_id127_text_00011.csv
# angepasst: P001_id128_text_01001.csv
# angepasst: P001_id129_ort_01001.csv
# angepasst: P001_id130_ort_01001.csv
# angepasst: P001_id131_person_00111.csv
# angepasst: P001_id132_person_00101.csv
# angepasst: P001_id133_person_00101.csv
# angepasst: P001_id134_politik_00111.csv
# angepasst: P001_id135_politik_10111.csv
# angepasst: P001_id136_politik_00111.csv
# angepasst: P001_id137_politik_00111.csv
# angepasst: P001_id138_politik_00111.csv
# angepasst: P001_id139_politik_00111.csv
# angepasst: P001_id140_politik_00111.csv
# angepasst: P001_id141_politik_10011.csv
# angepasst: P001_id142_text_00001.csv
# angepasst: P001_id143_text_00001.csv
# angepasst: P001_id144_text_00001.csv
# angepasst: P001_id146_text_00011.csv
# angepasst: P001_id147_text_10001.csv
# angepasst: P001_id148_text_10001.csv
# angepasst: P001_id149_text_10001.csv
# angepasst: P001_id150_text_10001.csv
# angepasst: P001_id151_text_10011.csv
# angepasst: P001_id152_text_10011.csv
# angepasst: P001_id153_text_10011.csv
# angepasst: P002_id001_meme_10000.csv
# angepasst: P002_id002_meme_10000.csv
# angepasst: P002_id003_meme_10000.csv
# angepasst: P002_id004_meme_10000.csv
# angepasst: P002_id005_meme_10000.csv
# angepasst: P002_id006_meme_10000.csv
# angepasst: P002_id007_meme_10000.csv
# angepasst: P002_id008_meme_10000.csv
# angepasst: P002_id009_meme_10000.csv
# angepasst: P002_id010_meme_10000.csv
# angepasst: P002_id011_ort_01001.csv
# angepasst: P002_id012_ort_01001.csv
# angepasst: P002_id013_ort_01001.csv
# angepasst: P002_id014_ort_01000.csv
# angepasst: P002_id015_ort_01001.csv
# angepasst: P002_id016_ort_01001.csv
# angepasst: P002_id017_ort_01001.csv
# angepasst: P002_id018_ort_01000.csv
# angepasst: P002_id019_ort_01000.csv
# angepasst: P002_id020_ort_01000.csv
# angepasst: P002_id021_ort_01000.csv
# angepasst: P002_id022_ort_01000.csv
# angepasst: P002_id023_ort_01000.csv
# angepasst: P002_id024_ort_01000.csv
# angepasst: P002_id025_ort_01000.csv
# angepasst: P002_id026_ort_01000.csv
# angepasst: P002_id027_ort_01000.csv
# angepasst: P002_id028_ort_01000.csv
# angepasst: P002_id029_ort_01000.csv
# angepasst: P002_id030_ort_01000.csv
# angepasst: P002_id031_ort_01000.csv
# angepasst: P002_id032_ort_01000.csv
# angepasst: P002_id033_person_00101.csv
# angepasst: P002_id034_person_00101.csv
# angepasst: P002_id035_person_00100.csv
# angepasst: P002_id036_person_00100.csv
# angepasst: P002_id037_person_00100.csv
# angepasst: P002_id038_person_00100.csv
# angepasst: P002_id039_person_00100.csv
# angepasst: P002_id040_person_00100.csv
# angepasst: P002_id041_person_00100.csv
# angepasst: P002_id042_person_00100.csv
# angepasst: P002_id043_person_00100.csv
# angepasst: P002_id044_person_00100.csv
# angepasst: P002_id045_person_00100.csv
# angepasst: P002_id046_person_00100.csv
# angepasst: P002_id047_person_00100.csv
# angepasst: P002_id048_person_00100.csv
# angepasst: P002_id049_person_00100.csv
# angepasst: P002_id050_person_00100.csv
# angepasst: P002_id051_person_00100.csv
# angepasst: P002_id052_person_00100.csv
# angepasst: P002_id053_person_00100.csv
# angepasst: P002_id054_person_00100.csv
# angepasst: P002_id055_person_00100.csv
# angepasst: P002_id056_person_00100.csv
# angepasst: P002_id057_person_00100.csv
# angepasst: P002_id058_person_00100.csv
# angepasst: P002_id059_person_00100.csv
# angepasst: P002_id060_person_00100.csv
# angepasst: P002_id061_person_00100.csv
# angepasst: P002_id062_person_00100.csv
# angepasst: P002_id063_person_00100.csv
# angepasst: P002_id064_person_00100.csv
# angepasst: P002_id065_person_00100.csv
# angepasst: P002_id066_person_00100.csv
# angepasst: P002_id067_person_00100.csv
# angepasst: P002_id068_person_00100.csv
# angepasst: P002_id069_person_00100.csv
# angepasst: P002_id070_person_00100.csv
# angepasst: P002_id071_person_00100.csv
# angepasst: P002_id072_person_00100.csv
# angepasst: P002_id073_person_00100.csv
# angepasst: P002_id074_person_00101.csv
# angepasst: P002_id075_person_00100.csv
# angepasst: P002_id076_person_00101.csv
# angepasst: P002_id077_person_00100.csv
# angepasst: P002_id078_person_00100.csv
# angepasst: P002_id079_person_00100.csv
# angepasst: P002_id080_person_00100.csv
# angepasst: P002_id081_person_00100.csv
# angepasst: P002_id082_person_00101.csv
# angepasst: P002_id083_person_00100.csv
# angepasst: P002_id084_person_00101.csv
# angepasst: P002_id085_person_00101.csv
# angepasst: P002_id086_person_00100.csv
# angepasst: P002_id087_person_00101.csv
# angepasst: P002_id089_politik_00110.csv
# angepasst: P002_id090_politik_00110.csv
# angepasst: P002_id091_politik_00110.csv
# angepasst: P002_id092_politik_00111.csv
# angepasst: P002_id093_politik_00110.csv
# angepasst: P002_id094_politik_00110.csv
# angepasst: P002_id095_politik_00110.csv
# angepasst: P002_id096_politik_00110.csv
# angepasst: P002_id097_politik_00110.csv
# angepasst: P002_id098_politik_00110.csv
# angepasst: P002_id099_politik_00111.csv
# angepasst: P002_id100_politik_00111.csv
# angepasst: P002_id101_politik_00110.csv
# angepasst: P002_id102_politik_00111.csv
# angepasst: P002_id103_politik_00110.csv
# angepasst: P002_id104_politik_00110.csv
# angepasst: P002_id105_politik_00110.csv
# angepasst: P002_id106_meme_10011.csv
# angepasst: P002_id107_meme_10111.csv
# angepasst: P002_id108_meme_10001.csv
# angepasst: P002_id109_meme_10011.csv
# angepasst: P002_id110_meme_10001.csv
# angepasst: P002_id111_meme_10001.csv
# angepasst: P002_id112_meme_10001.csv
# angepasst: P002_id113_meme_10001.csv
# angepasst: P002_id114_meme_10001.csv
# angepasst: P002_id115_meme_10001.csv
# angepasst: P002_id116_meme_10011.csv
# angepasst: P002_id117_meme_10011.csv
# angepasst: P002_id118_meme_10001.csv
# angepasst: P002_id119_meme_10001.csv
# angepasst: P002_id120_meme_10001.csv
# angepasst: P002_id121_meme_10001.csv
# angepasst: P002_id122_meme_10011.csv
# angepasst: P002_id123_meme_10011.csv
# angepasst: P002_id124_meme_10011.csv
# angepasst: P002_id125_meme_10001.csv
# angepasst: P002_id126_politik_00011.csv
# angepasst: P002_id127_text_00011.csv
# angepasst: P002_id128_text_01001.csv
# angepasst: P002_id129_ort_01001.csv
# angepasst: P002_id130_ort_01001.csv
# angepasst: P002_id131_person_00111.csv
# angepasst: P002_id132_person_00101.csv
# angepasst: P002_id133_person_00101.csv
# angepasst: P002_id134_politik_00111.csv
# angepasst: P002_id135_politik_10111.csv
# angepasst: P002_id136_politik_00111.csv
# angepasst: P002_id137_politik_00111.csv
# angepasst: P002_id138_politik_00111.csv
# angepasst: P002_id139_politik_00111.csv
# angepasst: P002_id140_politik_00111.csv
# angepasst: P002_id141_politik_10011.csv
# angepasst: P002_id142_text_00001.csv
# angepasst: P002_id143_text_00001.csv
# angepasst: P002_id144_text_00001.csv
# angepasst: P002_id146_text_00011.csv
# angepasst: P002_id147_text_10001.csv
# angepasst: P002_id148_text_10001.csv
# angepasst: P002_id149_text_10001.csv
# angepasst: P002_id150_text_10001.csv
# angepasst: P002_id151_text_10011.csv
# angepasst: P002_id152_text_10011.csv
# angepasst: P002_id153_text_10011.csv
# angepasst: P004_id001_meme_10000.csv
# angepasst: P004_id002_meme_10000.csv
# angepasst: P004_id003_meme_10000.csv
# angepasst: P004_id004_meme_10000.csv
# angepasst: P004_id005_meme_10000.csv
# angepasst: P004_id006_meme_10000.csv
# angepasst: P004_id007_meme_10000.csv
# angepasst: P004_id009_meme_10000.csv
# angepasst: P004_id010_meme_10000.csv
# angepasst: P004_id011_ort_01001.csv
# angepasst: P004_id012_ort_01001.csv
# angepasst: P004_id013_ort_01001.csv
# angepasst: P004_id014_ort_01000.csv
# angepasst: P004_id015_ort_01001.csv
# angepasst: P004_id016_ort_01001.csv
# angepasst: P004_id017_ort_01001.csv
# angepasst: P004_id018_ort_01000.csv
# angepasst: P004_id019_ort_01000.csv
# angepasst: P004_id020_ort_01000.csv
# angepasst: P004_id021_ort_01000.csv
# angepasst: P004_id022_ort_01000.csv
# angepasst: P004_id023_ort_01000.csv
# angepasst: P004_id024_ort_01000.csv
# angepasst: P004_id025_ort_01000.csv
# angepasst: P004_id026_ort_01000.csv
# angepasst: P004_id027_ort_01000.csv
# angepasst: P004_id028_ort_01000.csv
# angepasst: P004_id029_ort_01000.csv
# angepasst: P004_id030_ort_01000.csv
# angepasst: P004_id031_ort_01000.csv
# angepasst: P004_id032_ort_01000.csv
# angepasst: P004_id033_person_00101.csv
# angepasst: P004_id034_person_00101.csv
# angepasst: P004_id035_person_00100.csv
# angepasst: P004_id036_person_00100.csv
# angepasst: P004_id037_person_00100.csv
# angepasst: P004_id038_person_00100.csv
# angepasst: P004_id039_person_00100.csv
# angepasst: P004_id040_person_00100.csv
# angepasst: P004_id041_person_00100.csv
# angepasst: P004_id042_person_00100.csv
# angepasst: P004_id043_person_00100.csv
# angepasst: P004_id044_person_00100.csv
# angepasst: P004_id045_person_00100.csv
# angepasst: P004_id046_person_00100.csv
# angepasst: P004_id047_person_00100.csv
# angepasst: P004_id048_person_00100.csv
# angepasst: P004_id049_person_00100.csv
# angepasst: P004_id050_person_00100.csv
# angepasst: P004_id051_person_00100.csv
# angepasst: P004_id052_person_00100.csv
# angepasst: P004_id053_person_00100.csv
# angepasst: P004_id054_person_00100.csv
# angepasst: P004_id055_person_00100.csv
# angepasst: P004_id056_person_00100.csv
# angepasst: P004_id057_person_00100.csv
# angepasst: P004_id058_person_00100.csv
# angepasst: P004_id059_person_00100.csv
# angepasst: P004_id060_person_00100.csv
# angepasst: P004_id061_person_00100.csv
# angepasst: P004_id062_person_00100.csv
# angepasst: P004_id063_person_00100.csv
# angepasst: P004_id064_person_00100.csv
# angepasst: P004_id065_person_00100.csv
# angepasst: P004_id066_person_00100.csv
# angepasst: P004_id067_person_00100.csv
# angepasst: P004_id068_person_00100.csv
# angepasst: P004_id069_person_00100.csv
# angepasst: P004_id070_person_00100.csv
# angepasst: P004_id071_person_00100.csv
# angepasst: P004_id072_person_00100.csv
# angepasst: P004_id073_person_00100.csv
# angepasst: P004_id074_person_00101.csv
# angepasst: P004_id075_person_00100.csv
# angepasst: P004_id076_person_00101.csv
# angepasst: P004_id077_person_00100.csv
# angepasst: P004_id078_person_00100.csv
# angepasst: P004_id079_person_00100.csv
# angepasst: P004_id080_person_00100.csv
# angepasst: P004_id081_person_00100.csv
# angepasst: P004_id082_person_00101.csv
# angepasst: P004_id083_person_00100.csv
# angepasst: P004_id084_person_00101.csv
# angepasst: P004_id085_person_00101.csv
# angepasst: P004_id086_person_00100.csv
# angepasst: P004_id087_person_00101.csv
# angepasst: P004_id088_politik_00111.csv
# angepasst: P004_id089_politik_00110.csv
# angepasst: P004_id090_politik_00110.csv
# angepasst: P004_id091_politik_00110.csv
# angepasst: P004_id092_politik_00111.csv
# angepasst: P004_id093_politik_00110.csv
# angepasst: P004_id094_politik_00110.csv
# angepasst: P004_id095_politik_00110.csv
# angepasst: P004_id096_politik_00110.csv
# angepasst: P004_id097_politik_00110.csv
# angepasst: P004_id098_politik_00110.csv
# angepasst: P004_id099_politik_00111.csv
# angepasst: P004_id100_politik_00111.csv
# angepasst: P004_id101_politik_00110.csv
# angepasst: P004_id102_politik_00111.csv
# angepasst: P004_id103_politik_00110.csv
# angepasst: P004_id104_politik_00110.csv
# angepasst: P004_id105_politik_00110.csv
# angepasst: P004_id106_meme_10011.csv
# angepasst: P004_id107_meme_10111.csv
# angepasst: P004_id108_meme_10001.csv
# angepasst: P004_id109_meme_10011.csv
# angepasst: P004_id110_meme_10001.csv
# angepasst: P004_id111_meme_10001.csv
# angepasst: P004_id112_meme_10001.csv
# angepasst: P004_id113_meme_10001.csv
# angepasst: P004_id114_meme_10001.csv
# angepasst: P004_id115_meme_10001.csv
# angepasst: P004_id116_meme_10011.csv
# angepasst: P004_id117_meme_10011.csv
# angepasst: P004_id118_meme_10001.csv
# angepasst: P004_id119_meme_10001.csv
# angepasst: P004_id120_meme_10001.csv
# angepasst: P004_id121_meme_10001.csv
# angepasst: P004_id122_meme_10011.csv
# angepasst: P004_id123_meme_10011.csv
# angepasst: P004_id124_meme_10011.csv
# angepasst: P004_id125_meme_10001.csv
# angepasst: P004_id126_politik_00011.csv
# angepasst: P004_id127_text_00011.csv
# angepasst: P004_id128_text_01001.csv
# angepasst: P004_id129_ort_01001.csv
# angepasst: P004_id130_ort_01001.csv
# angepasst: P004_id131_person_00111.csv
# angepasst: P004_id132_person_00101.csv
# angepasst: P004_id133_person_00101.csv
# angepasst: P004_id134_politik_00111.csv
# angepasst: P004_id135_politik_10111.csv
# angepasst: P004_id136_politik_00111.csv
# angepasst: P004_id137_politik_00111.csv
# angepasst: P004_id138_politik_00111.csv
# angepasst: P004_id139_politik_00111.csv
# angepasst: P004_id140_politik_00111.csv
# angepasst: P004_id141_politik_10011.csv
# angepasst: P004_id142_text_00001.csv
# angepasst: P004_id143_text_00001.csv
# angepasst: P004_id144_text_00001.csv
# angepasst: P004_id146_text_00011.csv
# angepasst: P004_id147_text_10001.csv
# angepasst: P004_id148_text_10001.csv
# angepasst: P004_id149_text_10001.csv
# angepasst: P004_id150_text_10001.csv
# angepasst: P004_id151_text_10011.csv
# angepasst: P004_id152_text_10011.csv
# angepasst: P004_id153_text_10011.csv
# angepasst: P005_id001_meme_10000.csv
# angepasst: P005_id002_meme_10000.csv
# angepasst: P005_id003_meme_10000.csv
# angepasst: P005_id004_meme_10000.csv
# angepasst: P005_id005_meme_10000.csv
# angepasst: P005_id006_meme_10000.csv
# angepasst: P005_id007_meme_10000.csv
# angepasst: P005_id008_meme_10000.csv
# angepasst: P005_id009_meme_10000.csv
# angepasst: P005_id010_meme_10000.csv
# angepasst: P005_id011_ort_01001.csv
# angepasst: P005_id012_ort_01001.csv
# angepasst: P005_id013_ort_01001.csv
# angepasst: P005_id014_ort_01000.csv
# angepasst: P005_id015_ort_01001.csv
# angepasst: P005_id016_ort_01001.csv
# angepasst: P005_id017_ort_01001.csv
# angepasst: P005_id018_ort_01000.csv
# angepasst: P005_id019_ort_01000.csv
# angepasst: P005_id020_ort_01000.csv
# angepasst: P005_id021_ort_01000.csv
# angepasst: P005_id022_ort_01000.csv
# angepasst: P005_id023_ort_01000.csv
# angepasst: P005_id024_ort_01000.csv
# angepasst: P005_id025_ort_01000.csv
# angepasst: P005_id026_ort_01000.csv
# angepasst: P005_id027_ort_01000.csv
# angepasst: P005_id028_ort_01000.csv
# angepasst: P005_id029_ort_01000.csv
# angepasst: P005_id030_ort_01000.csv
# angepasst: P005_id031_ort_01000.csv
# angepasst: P005_id032_ort_01000.csv
# angepasst: P005_id033_person_00101.csv
# angepasst: P005_id034_person_00101.csv
# angepasst: P005_id035_person_00100.csv
# angepasst: P005_id036_person_00100.csv
# angepasst: P005_id037_person_00100.csv
# angepasst: P005_id038_person_00100.csv
# angepasst: P005_id039_person_00100.csv
# angepasst: P005_id040_person_00100.csv
# angepasst: P005_id041_person_00100.csv
# angepasst: P005_id042_person_00100.csv
# angepasst: P005_id043_person_00100.csv
# angepasst: P005_id044_person_00100.csv
# angepasst: P005_id045_person_00100.csv
# angepasst: P005_id046_person_00100.csv
# angepasst: P005_id047_person_00100.csv
# angepasst: P005_id048_person_00100.csv
# angepasst: P005_id049_person_00100.csv
# angepasst: P005_id050_person_00100.csv
# angepasst: P005_id051_person_00100.csv
# angepasst: P005_id052_person_00100.csv
# angepasst: P005_id053_person_00100.csv
# angepasst: P005_id054_person_00100.csv
# angepasst: P005_id055_person_00100.csv
# angepasst: P005_id056_person_00100.csv
# angepasst: P005_id057_person_00100.csv
# angepasst: P005_id058_person_00100.csv
# angepasst: P005_id059_person_00100.csv
# angepasst: P005_id060_person_00100.csv
# angepasst: P005_id061_person_00100.csv
# angepasst: P005_id062_person_00100.csv
# angepasst: P005_id063_person_00100.csv
# angepasst: P005_id064_person_00100.csv
# angepasst: P005_id065_person_00100.csv
# angepasst: P005_id066_person_00100.csv
# angepasst: P005_id067_person_00100.csv
# angepasst: P005_id068_person_00100.csv
# angepasst: P005_id069_person_00100.csv
# angepasst: P005_id070_person_00100.csv
# angepasst: P005_id071_person_00100.csv
# angepasst: P005_id073_person_00100.csv
# angepasst: P005_id074_person_00101.csv
# angepasst: P005_id075_person_00100.csv
# angepasst: P005_id076_person_00101.csv
# angepasst: P005_id077_person_00100.csv
# angepasst: P005_id078_person_00100.csv
# angepasst: P005_id079_person_00100.csv
# angepasst: P005_id080_person_00100.csv
# angepasst: P005_id081_person_00100.csv
# angepasst: P005_id082_person_00101.csv
# angepasst: P005_id083_person_00100.csv
# angepasst: P005_id084_person_00101.csv
# angepasst: P005_id085_person_00101.csv
# angepasst: P005_id086_person_00100.csv
# angepasst: P005_id087_person_00101.csv
# angepasst: P005_id088_politik_00111.csv
# angepasst: P005_id089_politik_00110.csv
# angepasst: P005_id090_politik_00110.csv
# angepasst: P005_id091_politik_00110.csv
# angepasst: P005_id092_politik_00111.csv
# angepasst: P005_id093_politik_00110.csv
# angepasst: P005_id094_politik_00110.csv
# angepasst: P005_id095_politik_00110.csv
# angepasst: P005_id096_politik_00110.csv
# angepasst: P005_id097_politik_00110.csv
# angepasst: P005_id098_politik_00110.csv
# angepasst: P005_id099_politik_00111.csv
# angepasst: P005_id100_politik_00111.csv
# angepasst: P005_id101_politik_00110.csv
# angepasst: P005_id102_politik_00111.csv
# angepasst: P005_id103_politik_00110.csv
# angepasst: P005_id104_politik_00110.csv
# angepasst: P005_id105_politik_00110.csv
# angepasst: P005_id106_meme_10011.csv
# angepasst: P005_id107_meme_10111.csv
# angepasst: P005_id108_meme_10001.csv
# angepasst: P005_id109_meme_10011.csv
# angepasst: P005_id110_meme_10001.csv
# angepasst: P005_id111_meme_10001.csv
# angepasst: P005_id112_meme_10001.csv
# angepasst: P005_id113_meme_10001.csv
# angepasst: P005_id114_meme_10001.csv
# angepasst: P005_id115_meme_10001.csv
# angepasst: P005_id116_meme_10011.csv
# angepasst: P005_id117_meme_10011.csv
# angepasst: P005_id118_meme_10001.csv
# angepasst: P005_id119_meme_10001.csv
# angepasst: P005_id120_meme_10001.csv
# angepasst: P005_id121_meme_10001.csv
# angepasst: P005_id122_meme_10011.csv
# angepasst: P005_id123_meme_10011.csv
# angepasst: P005_id124_meme_10011.csv
# angepasst: P005_id125_meme_10001.csv
# angepasst: P005_id126_politik_00011.csv
# angepasst: P005_id127_text_00011.csv
# angepasst: P005_id128_text_01001.csv
# angepasst: P005_id129_ort_01001.csv
# angepasst: P005_id130_ort_01001.csv
# angepasst: P005_id131_person_00111.csv
# angepasst: P005_id132_person_00101.csv
# angepasst: P005_id133_person_00101.csv
# angepasst: P005_id134_politik_00111.csv
# angepasst: P005_id135_politik_10111.csv
# angepasst: P005_id136_politik_00111.csv
# angepasst: P005_id137_politik_00111.csv
# angepasst: P005_id138_politik_00111.csv
# angepasst: P005_id139_politik_00111.csv
# angepasst: P005_id140_politik_00111.csv
# angepasst: P005_id141_politik_10011.csv
# angepasst: P005_id142_text_00001.csv
# angepasst: P005_id143_text_00001.csv
# angepasst: P005_id144_text_00001.csv
# angepasst: P005_id146_text_00011.csv
# angepasst: P005_id147_text_10001.csv
# angepasst: P005_id148_text_10001.csv
# angepasst: P005_id149_text_10001.csv
# angepasst: P005_id150_text_10001.csv
# angepasst: P005_id151_text_10011.csv
# angepasst: P005_id152_text_10011.csv
# angepasst: P005_id153_text_10011.csv
# angepasst: P006_id001_meme_10000.csv
# angepasst: P006_id002_meme_10000.csv
# angepasst: P006_id003_meme_10000.csv
# angepasst: P006_id004_meme_10000.csv
# angepasst: P006_id005_meme_10000.csv
# angepasst: P006_id006_meme_10000.csv
# angepasst: P006_id007_meme_10000.csv
# angepasst: P006_id008_meme_10000.csv
# angepasst: P006_id009_meme_10000.csv
# angepasst: P006_id010_meme_10000.csv
# angepasst: P006_id011_ort_01001.csv
# angepasst: P006_id012_ort_01001.csv
# angepasst: P006_id013_ort_01001.csv
# angepasst: P006_id014_ort_01000.csv
# angepasst: P006_id015_ort_01001.csv
# angepasst: P006_id016_ort_01001.csv
# angepasst: P006_id017_ort_01001.csv
# angepasst: P006_id019_ort_01000.csv
# angepasst: P006_id020_ort_01000.csv
# angepasst: P006_id021_ort_01000.csv
# angepasst: P006_id022_ort_01000.csv
# angepasst: P006_id023_ort_01000.csv
# angepasst: P006_id024_ort_01000.csv
# angepasst: P006_id025_ort_01000.csv
# angepasst: P006_id026_ort_01000.csv
# angepasst: P006_id027_ort_01000.csv
# angepasst: P006_id028_ort_01000.csv
# angepasst: P006_id029_ort_01000.csv
# angepasst: P006_id030_ort_01000.csv
# angepasst: P006_id031_ort_01000.csv
# angepasst: P006_id032_ort_01000.csv
# angepasst: P006_id033_person_00101.csv
# angepasst: P006_id034_person_00101.csv
# angepasst: P006_id035_person_00100.csv
# angepasst: P006_id036_person_00100.csv
# angepasst: P006_id037_person_00100.csv
# angepasst: P006_id038_person_00100.csv
# angepasst: P006_id039_person_00100.csv
# angepasst: P006_id040_person_00100.csv
# angepasst: P006_id041_person_00100.csv
# angepasst: P006_id042_person_00100.csv
# angepasst: P006_id043_person_00100.csv
# angepasst: P006_id044_person_00100.csv
# angepasst: P006_id045_person_00100.csv
# angepasst: P006_id046_person_00100.csv
# angepasst: P006_id047_person_00100.csv
# angepasst: P006_id048_person_00100.csv
# angepasst: P006_id049_person_00100.csv
# angepasst: P006_id050_person_00100.csv
# angepasst: P006_id051_person_00100.csv
# angepasst: P006_id052_person_00100.csv
# angepasst: P006_id053_person_00100.csv
# angepasst: P006_id054_person_00100.csv
# angepasst: P006_id055_person_00100.csv
# angepasst: P006_id056_person_00100.csv
# angepasst: P006_id057_person_00100.csv
# angepasst: P006_id058_person_00100.csv
# angepasst: P006_id059_person_00100.csv
# angepasst: P006_id060_person_00100.csv
# angepasst: P006_id061_person_00100.csv
# angepasst: P006_id062_person_00100.csv
# angepasst: P006_id063_person_00100.csv
# angepasst: P006_id064_person_00100.csv
# angepasst: P006_id065_person_00100.csv
# angepasst: P006_id066_person_00100.csv
# angepasst: P006_id067_person_00100.csv
# angepasst: P006_id068_person_00100.csv
# angepasst: P006_id069_person_00100.csv
# angepasst: P006_id070_person_00100.csv
# angepasst: P006_id071_person_00100.csv
# angepasst: P006_id072_person_00100.csv
# angepasst: P006_id073_person_00100.csv
# angepasst: P006_id074_person_00101.csv
# angepasst: P006_id075_person_00100.csv
# angepasst: P006_id076_person_00101.csv
# angepasst: P006_id077_person_00100.csv
# angepasst: P006_id078_person_00100.csv
# angepasst: P006_id079_person_00100.csv
# angepasst: P006_id080_person_00100.csv
# angepasst: P006_id081_person_00100.csv
# angepasst: P006_id082_person_00101.csv
# angepasst: P006_id083_person_00100.csv
# angepasst: P006_id084_person_00101.csv
# angepasst: P006_id085_person_00101.csv
# angepasst: P006_id086_person_00100.csv
# angepasst: P006_id087_person_00101.csv
# angepasst: P006_id088_politik_00111.csv
# angepasst: P006_id089_politik_00110.csv
# angepasst: P006_id090_politik_00110.csv
# angepasst: P006_id091_politik_00110.csv
# angepasst: P006_id092_politik_00111.csv
# angepasst: P006_id093_politik_00110.csv
# angepasst: P006_id094_politik_00110.csv
# angepasst: P006_id095_politik_00110.csv
# angepasst: P006_id096_politik_00110.csv
# angepasst: P006_id097_politik_00110.csv
# angepasst: P006_id098_politik_00110.csv
# angepasst: P006_id099_politik_00111.csv
# angepasst: P006_id100_politik_00111.csv
# angepasst: P006_id101_politik_00110.csv
# angepasst: P006_id102_politik_00111.csv
# angepasst: P006_id103_politik_00110.csv
# angepasst: P006_id104_politik_00110.csv
# angepasst: P006_id105_politik_00110.csv
# angepasst: P006_id106_meme_10011.csv
# angepasst: P006_id107_meme_10111.csv
# angepasst: P006_id108_meme_10001.csv
# angepasst: P006_id109_meme_10011.csv
# angepasst: P006_id110_meme_10001.csv
# angepasst: P006_id111_meme_10001.csv
# angepasst: P006_id112_meme_10001.csv
# angepasst: P006_id113_meme_10001.csv
# angepasst: P006_id114_meme_10001.csv
# angepasst: P006_id115_meme_10001.csv
# angepasst: P006_id116_meme_10011.csv
# angepasst: P006_id117_meme_10011.csv
# angepasst: P006_id118_meme_10001.csv
# angepasst: P006_id119_meme_10001.csv
# angepasst: P006_id120_meme_10001.csv
# angepasst: P006_id121_meme_10001.csv
# angepasst: P006_id122_meme_10011.csv
# angepasst: P006_id123_meme_10011.csv
# angepasst: P006_id124_meme_10011.csv
# angepasst: P006_id125_meme_10001.csv
# angepasst: P006_id126_politik_00011.csv
# angepasst: P006_id127_text_00011.csv
# angepasst: P006_id128_text_01001.csv
# angepasst: P006_id129_ort_01001.csv
# angepasst: P006_id130_ort_01001.csv
# angepasst: P006_id131_person_00111.csv
# angepasst: P006_id132_person_00101.csv
# angepasst: P006_id133_person_00101.csv
# angepasst: P006_id134_politik_00111.csv
# angepasst: P006_id135_politik_10111.csv
# angepasst: P006_id136_politik_00111.csv
# angepasst: P006_id137_politik_00111.csv
# angepasst: P006_id138_politik_00111.csv
# angepasst: P006_id139_politik_00111.csv
# angepasst: P006_id140_politik_00111.csv
# angepasst: P006_id141_politik_10011.csv
# angepasst: P006_id142_text_00001.csv
# angepasst: P006_id143_text_00001.csv
# angepasst: P006_id144_text_00001.csv
# angepasst: P006_id146_text_00011.csv
# angepasst: P006_id147_text_10001.csv
# angepasst: P006_id148_text_10001.csv
# angepasst: P006_id149_text_10001.csv
# angepasst: P006_id150_text_10001.csv
# angepasst: P006_id151_text_10011.csv
# angepasst: P006_id152_text_10011.csv
# angepasst: P006_id153_text_10011.csv
# angepasst: P007_id001_meme_10000.csv
# angepasst: P007_id002_meme_10000.csv
# angepasst: P007_id003_meme_10000.csv
# angepasst: P007_id004_meme_10000.csv
# angepasst: P007_id005_meme_10000.csv
# angepasst: P007_id006_meme_10000.csv
# angepasst: P007_id007_meme_10000.csv
# angepasst: P007_id008_meme_10000.csv
# angepasst: P007_id009_meme_10000.csv
# angepasst: P007_id010_meme_10000.csv
# angepasst: P007_id011_ort_01001.csv
# angepasst: P007_id012_ort_01001.csv
# angepasst: P007_id013_ort_01001.csv
# angepasst: P007_id014_ort_01000.csv
# angepasst: P007_id015_ort_01001.csv
# angepasst: P007_id016_ort_01001.csv
# angepasst: P007_id017_ort_01001.csv
# angepasst: P007_id018_ort_01000.csv
# angepasst: P007_id019_ort_01000.csv
# angepasst: P007_id020_ort_01000.csv
# angepasst: P007_id021_ort_01000.csv
# angepasst: P007_id022_ort_01000.csv
# angepasst: P007_id023_ort_01000.csv
# angepasst: P007_id024_ort_01000.csv
# angepasst: P007_id025_ort_01000.csv
# angepasst: P007_id026_ort_01000.csv
# angepasst: P007_id027_ort_01000.csv
# angepasst: P007_id028_ort_01000.csv
# angepasst: P007_id029_ort_01000.csv
# angepasst: P007_id030_ort_01000.csv
# angepasst: P007_id031_ort_01000.csv
# angepasst: P007_id032_ort_01000.csv
# angepasst: P007_id033_person_00101.csv
# angepasst: P007_id034_person_00101.csv
# angepasst: P007_id035_person_00100.csv
# angepasst: P007_id036_person_00100.csv
# angepasst: P007_id037_person_00100.csv
# angepasst: P007_id038_person_00100.csv
# angepasst: P007_id039_person_00100.csv
# angepasst: P007_id040_person_00100.csv
# angepasst: P007_id041_person_00100.csv
# angepasst: P007_id042_person_00100.csv
# angepasst: P007_id043_person_00100.csv
# angepasst: P007_id044_person_00100.csv
# angepasst: P007_id045_person_00100.csv
# angepasst: P007_id046_person_00100.csv
# angepasst: P007_id047_person_00100.csv
# angepasst: P007_id048_person_00100.csv
# angepasst: P007_id049_person_00100.csv
# angepasst: P007_id050_person_00100.csv
# angepasst: P007_id051_person_00100.csv
# angepasst: P007_id052_person_00100.csv
# angepasst: P007_id053_person_00100.csv
# angepasst: P007_id054_person_00100.csv
# angepasst: P007_id055_person_00100.csv
# angepasst: P007_id056_person_00100.csv
# angepasst: P007_id057_person_00100.csv
# angepasst: P007_id058_person_00100.csv
# angepasst: P007_id059_person_00100.csv
# angepasst: P007_id060_person_00100.csv
# angepasst: P007_id061_person_00100.csv
# angepasst: P007_id062_person_00100.csv
# angepasst: P007_id063_person_00100.csv
# angepasst: P007_id064_person_00100.csv
# angepasst: P007_id065_person_00100.csv
# angepasst: P007_id066_person_00100.csv
# angepasst: P007_id067_person_00100.csv
# angepasst: P007_id068_person_00100.csv
# angepasst: P007_id069_person_00100.csv
# angepasst: P007_id070_person_00100.csv
# angepasst: P007_id071_person_00100.csv
# angepasst: P007_id072_person_00100.csv
# angepasst: P007_id073_person_00100.csv
# angepasst: P007_id074_person_00101.csv
# angepasst: P007_id075_person_00100.csv
# angepasst: P007_id076_person_00101.csv
# angepasst: P007_id077_person_00100.csv
# angepasst: P007_id078_person_00100.csv
# angepasst: P007_id079_person_00100.csv
# angepasst: P007_id080_person_00100.csv
# angepasst: P007_id081_person_00100.csv
# angepasst: P007_id082_person_00101.csv
# angepasst: P007_id083_person_00100.csv
# angepasst: P007_id084_person_00101.csv
# angepasst: P007_id085_person_00101.csv
# angepasst: P007_id086_person_00100.csv
# angepasst: P007_id087_person_00101.csv
# angepasst: P007_id088_politik_00111.csv
# angepasst: P007_id089_politik_00110.csv
# angepasst: P007_id090_politik_00110.csv
# angepasst: P007_id091_politik_00110.csv
# angepasst: P007_id092_politik_00111.csv
# angepasst: P007_id093_politik_00110.csv
# angepasst: P007_id094_politik_00110.csv
# angepasst: P007_id095_politik_00110.csv
# angepasst: P007_id096_politik_00110.csv
# angepasst: P007_id097_politik_00110.csv
# angepasst: P007_id098_politik_00110.csv
# angepasst: P007_id099_politik_00111.csv
# angepasst: P007_id100_politik_00111.csv
# angepasst: P007_id101_politik_00110.csv
# angepasst: P007_id102_politik_00111.csv
# angepasst: P007_id103_politik_00110.csv
# angepasst: P007_id104_politik_00110.csv
# angepasst: P007_id105_politik_00110.csv
# angepasst: P007_id106_meme_10011.csv
# angepasst: P007_id107_meme_10111.csv
# angepasst: P007_id108_meme_10001.csv
# angepasst: P007_id109_meme_10011.csv
# angepasst: P007_id110_meme_10001.csv
# angepasst: P007_id111_meme_10001.csv
# angepasst: P007_id112_meme_10001.csv
# angepasst: P007_id113_meme_10001.csv
# angepasst: P007_id114_meme_10001.csv
# angepasst: P007_id115_meme_10001.csv
# angepasst: P007_id116_meme_10011.csv
# angepasst: P007_id117_meme_10011.csv
# angepasst: P007_id118_meme_10001.csv
# angepasst: P007_id119_meme_10001.csv
# angepasst: P007_id120_meme_10001.csv
# angepasst: P007_id121_meme_10001.csv
# angepasst: P007_id122_meme_10011.csv
# angepasst: P007_id123_meme_10011.csv
# angepasst: P007_id124_meme_10011.csv
# angepasst: P007_id125_meme_10001.csv
# angepasst: P007_id126_politik_00011.csv
# angepasst: P007_id127_text_00011.csv
# angepasst: P007_id128_text_01001.csv
# angepasst: P007_id129_ort_01001.csv
# angepasst: P007_id130_ort_01001.csv
# angepasst: P007_id131_person_00111.csv
# angepasst: P007_id132_person_00101.csv
# angepasst: P007_id133_person_00101.csv
# angepasst: P007_id134_politik_00111.csv
# angepasst: P007_id135_politik_10111.csv
# angepasst: P007_id136_politik_00111.csv
# angepasst: P007_id137_politik_00111.csv
# angepasst: P007_id138_politik_00111.csv
# angepasst: P007_id139_politik_00111.csv
# angepasst: P007_id140_politik_00111.csv
# angepasst: P007_id141_politik_10011.csv
# angepasst: P007_id142_text_00001.csv
# angepasst: P007_id143_text_00001.csv
# angepasst: P007_id144_text_00001.csv
# angepasst: P007_id146_text_00011.csv
# angepasst: P007_id147_text_10001.csv
# angepasst: P007_id148_text_10001.csv
# angepasst: P007_id149_text_10001.csv
# angepasst: P007_id150_text_10001.csv
# angepasst: P007_id151_text_10011.csv
# angepasst: P007_id152_text_10011.csv
# angepasst: P007_id153_text_10011.csv
# angepasst: P008_id001_meme_10000.csv
# angepasst: P008_id002_meme_10000.csv
# angepasst: P008_id003_meme_10000.csv
# angepasst: P008_id004_meme_10000.csv
# angepasst: P008_id005_meme_10000.csv
# angepasst: P008_id006_meme_10000.csv
# angepasst: P008_id007_meme_10000.csv
# angepasst: P008_id008_meme_10000.csv
# angepasst: P008_id009_meme_10000.csv
# angepasst: P008_id010_meme_10000.csv
# angepasst: P008_id011_ort_01001.csv
# angepasst: P008_id012_ort_01001.csv
# angepasst: P008_id013_ort_01001.csv
# angepasst: P008_id014_ort_01000.csv
# angepasst: P008_id015_ort_01001.csv
# angepasst: P008_id016_ort_01001.csv
# angepasst: P008_id017_ort_01001.csv
# angepasst: P008_id018_ort_01000.csv
# angepasst: P008_id019_ort_01000.csv
# angepasst: P008_id020_ort_01000.csv
# angepasst: P008_id021_ort_01000.csv
# angepasst: P008_id022_ort_01000.csv
# angepasst: P008_id023_ort_01000.csv
# angepasst: P008_id024_ort_01000.csv
# angepasst: P008_id025_ort_01000.csv
# angepasst: P008_id026_ort_01000.csv
# angepasst: P008_id027_ort_01000.csv
# angepasst: P008_id028_ort_01000.csv
# angepasst: P008_id029_ort_01000.csv
# angepasst: P008_id030_ort_01000.csv
# angepasst: P008_id031_ort_01000.csv
# angepasst: P008_id032_ort_01000.csv
# angepasst: P008_id033_person_00101.csv
# angepasst: P008_id034_person_00101.csv
# angepasst: P008_id035_person_00100.csv
# angepasst: P008_id036_person_00100.csv
# angepasst: P008_id037_person_00100.csv
# angepasst: P008_id038_person_00100.csv
# angepasst: P008_id039_person_00100.csv
# angepasst: P008_id040_person_00100.csv
# angepasst: P008_id041_person_00100.csv
# angepasst: P008_id042_person_00100.csv
# angepasst: P008_id043_person_00100.csv
# angepasst: P008_id044_person_00100.csv
# angepasst: P008_id045_person_00100.csv
# angepasst: P008_id046_person_00100.csv
# angepasst: P008_id047_person_00100.csv
# angepasst: P008_id048_person_00100.csv
# angepasst: P008_id049_person_00100.csv
# angepasst: P008_id050_person_00100.csv
# angepasst: P008_id051_person_00100.csv
# angepasst: P008_id052_person_00100.csv
# angepasst: P008_id053_person_00100.csv
# angepasst: P008_id054_person_00100.csv
# angepasst: P008_id055_person_00100.csv
# angepasst: P008_id056_person_00100.csv
# angepasst: P008_id057_person_00100.csv
# angepasst: P008_id058_person_00100.csv
# angepasst: P008_id059_person_00100.csv
# angepasst: P008_id060_person_00100.csv
# angepasst: P008_id061_person_00100.csv
# angepasst: P008_id062_person_00100.csv
# angepasst: P008_id063_person_00100.csv
# angepasst: P008_id064_person_00100.csv
# angepasst: P008_id065_person_00100.csv
# angepasst: P008_id066_person_00100.csv
# angepasst: P008_id067_person_00100.csv
# angepasst: P008_id068_person_00100.csv
# angepasst: P008_id069_person_00100.csv
# angepasst: P008_id070_person_00100.csv
# angepasst: P008_id071_person_00100.csv
# angepasst: P008_id072_person_00100.csv
# angepasst: P008_id073_person_00100.csv
# angepasst: P008_id074_person_00101.csv
# angepasst: P008_id075_person_00100.csv
# angepasst: P008_id076_person_00101.csv
# angepasst: P008_id077_person_00100.csv
# angepasst: P008_id078_person_00100.csv
# angepasst: P008_id079_person_00100.csv
# angepasst: P008_id080_person_00100.csv
# angepasst: P008_id081_person_00100.csv
# angepasst: P008_id082_person_00101.csv
# angepasst: P008_id083_person_00100.csv
# angepasst: P008_id084_person_00101.csv
# angepasst: P008_id085_person_00101.csv
# angepasst: P008_id086_person_00100.csv
# angepasst: P008_id087_person_00101.csv
# angepasst: P008_id088_politik_00111.csv
# angepasst: P008_id089_politik_00110.csv
# angepasst: P008_id090_politik_00110.csv
# angepasst: P008_id091_politik_00110.csv
# angepasst: P008_id092_politik_00111.csv
# angepasst: P008_id093_politik_00110.csv
# angepasst: P008_id094_politik_00110.csv
# angepasst: P008_id095_politik_00110.csv
# angepasst: P008_id096_politik_00110.csv
# angepasst: P008_id097_politik_00110.csv
# angepasst: P008_id098_politik_00110.csv
# angepasst: P008_id099_politik_00111.csv
# angepasst: P008_id100_politik_00111.csv
# angepasst: P008_id101_politik_00110.csv
# angepasst: P008_id102_politik_00111.csv
# angepasst: P008_id103_politik_00110.csv
# angepasst: P008_id104_politik_00110.csv
# angepasst: P008_id105_politik_00110.csv
# angepasst: P008_id106_meme_10011.csv
# angepasst: P008_id107_meme_10111.csv
# angepasst: P008_id108_meme_10001.csv
# angepasst: P008_id109_meme_10011.csv
# angepasst: P008_id110_meme_10001.csv
# angepasst: P008_id111_meme_10001.csv
# angepasst: P008_id112_meme_10001.csv
# angepasst: P008_id113_meme_10001.csv
# angepasst: P008_id114_meme_10001.csv
# angepasst: P008_id115_meme_10001.csv
# angepasst: P008_id116_meme_10011.csv
# angepasst: P008_id117_meme_10011.csv
# angepasst: P008_id118_meme_10001.csv
# angepasst: P008_id119_meme_10001.csv
# angepasst: P008_id120_meme_10001.csv
# angepasst: P008_id121_meme_10001.csv
# angepasst: P008_id122_meme_10011.csv
# angepasst: P008_id123_meme_10011.csv
# angepasst: P008_id124_meme_10011.csv
# angepasst: P008_id125_meme_10001.csv
# angepasst: P008_id126_politik_00011.csv
# angepasst: P008_id127_text_00011.csv
# angepasst: P008_id128_text_01001.csv
# angepasst: P008_id129_ort_01001.csv
# angepasst: P008_id130_ort_01001.csv
# angepasst: P008_id131_person_00111.csv
# angepasst: P008_id132_person_00101.csv
# angepasst: P008_id133_person_00101.csv
# angepasst: P008_id134_politik_00111.csv
# angepasst: P008_id135_politik_10111.csv
# angepasst: P008_id136_politik_00111.csv
# angepasst: P008_id137_politik_00111.csv
# angepasst: P008_id138_politik_00111.csv
# angepasst: P008_id139_politik_00111.csv
# angepasst: P008_id140_politik_00111.csv
# angepasst: P008_id141_politik_10011.csv
# angepasst: P008_id142_text_00001.csv
# angepasst: P008_id143_text_00001.csv
# angepasst: P008_id144_text_00001.csv
# angepasst: P008_id146_text_00011.csv
# angepasst: P008_id147_text_10001.csv
# angepasst: P008_id148_text_10001.csv
# angepasst: P008_id149_text_10001.csv
# angepasst: P008_id150_text_10001.csv
# angepasst: P008_id151_text_10011.csv
# angepasst: P008_id152_text_10011.csv
# angepasst: P008_id153_text_10011.csv
# angepasst: P009_id001_meme_10000.csv
# angepasst: P009_id002_meme_10000.csv
# angepasst: P009_id003_meme_10000.csv
# angepasst: P009_id004_meme_10000.csv
# angepasst: P009_id005_meme_10000.csv
# angepasst: P009_id006_meme_10000.csv
# angepasst: P009_id007_meme_10000.csv
# angepasst: P009_id008_meme_10000.csv
# angepasst: P009_id009_meme_10000.csv
# angepasst: P009_id010_meme_10000.csv
# angepasst: P009_id011_ort_01001.csv
# angepasst: P009_id012_ort_01001.csv
# angepasst: P009_id013_ort_01001.csv
# angepasst: P009_id014_ort_01000.csv
# angepasst: P009_id015_ort_01001.csv
# angepasst: P009_id016_ort_01001.csv
# angepasst: P009_id017_ort_01001.csv
# angepasst: P009_id018_ort_01000.csv
# angepasst: P009_id019_ort_01000.csv
# angepasst: P009_id020_ort_01000.csv
# angepasst: P009_id021_ort_01000.csv
# angepasst: P009_id022_ort_01000.csv
# angepasst: P009_id023_ort_01000.csv
# angepasst: P009_id024_ort_01000.csv
# angepasst: P009_id025_ort_01000.csv
# angepasst: P009_id026_ort_01000.csv
# angepasst: P009_id027_ort_01000.csv
# angepasst: P009_id028_ort_01000.csv
# angepasst: P009_id029_ort_01000.csv
# angepasst: P009_id030_ort_01000.csv
# angepasst: P009_id031_ort_01000.csv
# angepasst: P009_id032_ort_01000.csv
# angepasst: P009_id033_person_00101.csv
# angepasst: P009_id034_person_00101.csv
# angepasst: P009_id035_person_00100.csv
# angepasst: P009_id036_person_00100.csv
# angepasst: P009_id037_person_00100.csv
# angepasst: P009_id038_person_00100.csv
# angepasst: P009_id039_person_00100.csv
# angepasst: P009_id040_person_00100.csv
# angepasst: P009_id041_person_00100.csv
# angepasst: P009_id042_person_00100.csv
# angepasst: P009_id043_person_00100.csv
# angepasst: P009_id044_person_00100.csv
# angepasst: P009_id045_person_00100.csv
# angepasst: P009_id046_person_00100.csv
# angepasst: P009_id047_person_00100.csv
# angepasst: P009_id048_person_00100.csv
# ...
# angepasst: P052_id035_person_00100.csv
# angepasst: P052_id036_person_00100.csv
# angepasst: P052_id037_person_00100.csv
# angepasst: P052_id038_person_00100.csv
# angepasst: P052_id039_person_00100.csv
# angepasst: P052_id040_person_00100.csv
# angepasst: P052_id041_person_00100.csv
# angepasst: P052_id042_person_00100.csv
# angepasst: P052_id043_person_00100.csv
# angepasst: P052_id044_person_00100.csv
# angepasst: P052_id045_person_00100.csv
# angepasst: P052_id046_person_00100.csv
# angepasst: P052_id047_person_00100.csv
# angepasst: P052_id048_person_00100.csv
# angepasst: P052_id049_person_00100.csv
# angepasst: P052_id050_person_00100.csv
# angepasst: P052_id051_person_00100.csv
# angepasst: P052_id052_person_00100.csv
# angepasst: P052_id053_person_00100.csv
# angepasst: P052_id054_person_00100.csv
# angepasst: P052_id055_person_00100.csv
# angepasst: P052_id056_person_00100.csv
# angepasst: P052_id057_person_00100.csv
# angepasst: P052_id058_person_00100.csv
# angepasst: P052_id059_person_00100.csv
# angepasst: P052_id060_person_00100.csv
# angepasst: P052_id061_person_00100.csv
# angepasst: P052_id062_person_00100.csv
# angepasst: P052_id063_person_00100.csv
# angepasst: P052_id064_person_00100.csv
# angepasst: P052_id065_person_00100.csv
# angepasst: P052_id066_person_00100.csv
# angepasst: P052_id067_person_00100.csv
# angepasst: P052_id068_person_00100.csv
# angepasst: P052_id069_person_00100.csv
# angepasst: P052_id070_person_00100.csv
# angepasst: P052_id071_person_00100.csv
# angepasst: P052_id072_person_00100.csv
# angepasst: P052_id073_person_00100.csv
# angepasst: P052_id074_person_00101.csv
# angepasst: P052_id075_person_00100.csv
# angepasst: P052_id076_person_00101.csv
# angepasst: P052_id077_person_00100.csv
# angepasst: P052_id078_person_00100.csv
# angepasst: P052_id079_person_00100.csv
# angepasst: P052_id080_person_00100.csv
# angepasst: P052_id081_person_00100.csv
# angepasst: P052_id082_person_00101.csv
# angepasst: P052_id083_person_00100.csv
# angepasst: P052_id084_person_00101.csv
# angepasst: P052_id085_person_00101.csv
# angepasst: P052_id086_person_00100.csv
# angepasst: P052_id087_person_00101.csv
# angepasst: P052_id088_politik_00111.csv
# angepasst: P052_id089_politik_00110.csv
# angepasst: P052_id090_politik_00110.csv
# angepasst: P052_id091_politik_00110.csv
# angepasst: P052_id092_politik_00111.csv
# angepasst: P052_id093_politik_00110.csv
# angepasst: P052_id094_politik_00110.csv
# angepasst: P052_id095_politik_00110.csv
# angepasst: P052_id096_politik_00110.csv
# angepasst: P052_id097_politik_00110.csv
# angepasst: P052_id098_politik_00110.csv
# angepasst: P052_id099_politik_00111.csv
# angepasst: P052_id100_politik_00111.csv
# angepasst: P052_id101_politik_00110.csv
# angepasst: P052_id102_politik_00111.csv
# angepasst: P052_id103_politik_00110.csv
# angepasst: P052_id104_politik_00110.csv
# angepasst: P052_id105_politik_00110.csv
# angepasst: P052_id106_meme_10011.csv
# angepasst: P052_id107_meme_10111.csv
# angepasst: P052_id108_meme_10001.csv
# angepasst: P052_id109_meme_10011.csv
# angepasst: P052_id110_meme_10001.csv
# angepasst: P052_id111_meme_10001.csv
# angepasst: P052_id112_meme_10001.csv
# angepasst: P052_id113_meme_10001.csv
# angepasst: P052_id114_meme_10001.csv
# angepasst: P052_id115_meme_10001.csv
# angepasst: P052_id116_meme_10011.csv
# angepasst: P052_id117_meme_10011.csv
# angepasst: P052_id118_meme_10001.csv
# angepasst: P052_id119_meme_10001.csv
# angepasst: P052_id120_meme_10001.csv
# angepasst: P052_id121_meme_10001.csv
# angepasst: P052_id122_meme_10011.csv
# angepasst: P052_id123_meme_10011.csv
# angepasst: P052_id124_meme_10011.csv
# angepasst: P052_id125_meme_10001.csv
# angepasst: P052_id126_politik_00011.csv
# angepasst: P052_id127_text_00011.csv
# angepasst: P052_id128_text_01001.csv
# angepasst: P052_id129_ort_01001.csv
# angepasst: P052_id130_ort_01001.csv
# angepasst: P052_id131_person_00111.csv
# angepasst: P052_id132_person_00101.csv
# angepasst: P052_id133_person_00101.csv
# angepasst: P052_id134_politik_00111.csv
# angepasst: P052_id135_politik_10111.csv
# angepasst: P052_id136_politik_00111.csv
# angepasst: P052_id137_politik_00111.csv
# angepasst: P052_id138_politik_00111.csv
# angepasst: P052_id139_politik_00111.csv
# angepasst: P052_id140_politik_00111.csv
# angepasst: P052_id141_politik_10011.csv
# angepasst: P052_id142_text_00001.csv
# angepasst: P052_id143_text_00001.csv
# angepasst: P052_id144_text_00001.csv
# angepasst: P052_id146_text_00011.csv
# angepasst: P052_id147_text_10001.csv
# angepasst: P052_id148_text_10001.csv
# angepasst: P052_id149_text_10001.csv
# angepasst: P052_id150_text_10001.csv
# angepasst: P052_id151_text_10011.csv
# angepasst: P052_id152_text_10011.csv
# angepasst: P052_id153_text_10011.csv
# angepasst: P053_id001_meme_10000.csv
# angepasst: P053_id002_meme_10000.csv
# angepasst: P053_id003_meme_10000.csv
# angepasst: P053_id004_meme_10000.csv
# angepasst: P053_id005_meme_10000.csv
# angepasst: P053_id006_meme_10000.csv
# angepasst: P053_id007_meme_10000.csv
# angepasst: P053_id008_meme_10000.csv
# angepasst: P053_id009_meme_10000.csv
# angepasst: P053_id010_meme_10000.csv
# angepasst: P053_id011_ort_01001.csv
# angepasst: P053_id012_ort_01001.csv
# angepasst: P053_id013_ort_01001.csv
# angepasst: P053_id014_ort_01000.csv
# angepasst: P053_id015_ort_01001.csv
# angepasst: P053_id016_ort_01001.csv
# angepasst: P053_id017_ort_01001.csv
# angepasst: P053_id018_ort_01000.csv
# angepasst: P053_id019_ort_01000.csv
# angepasst: P053_id020_ort_01000.csv
# angepasst: P053_id021_ort_01000.csv
# angepasst: P053_id022_ort_01000.csv
# angepasst: P053_id023_ort_01000.csv
# angepasst: P053_id024_ort_01000.csv
# angepasst: P053_id025_ort_01000.csv
# angepasst: P053_id026_ort_01000.csv
# angepasst: P053_id027_ort_01000.csv
# angepasst: P053_id028_ort_01000.csv
# angepasst: P053_id029_ort_01000.csv
# angepasst: P053_id030_ort_01000.csv
# angepasst: P053_id031_ort_01000.csv
# angepasst: P053_id032_ort_01000.csv
# angepasst: P053_id033_person_00101.csv
# angepasst: P053_id034_person_00101.csv
# angepasst: P053_id035_person_00100.csv
# angepasst: P053_id036_person_00100.csv
# angepasst: P053_id037_person_00100.csv
# angepasst: P053_id038_person_00100.csv
# angepasst: P053_id039_person_00100.csv
# angepasst: P053_id040_person_00100.csv
# angepasst: P053_id041_person_00100.csv
# angepasst: P053_id042_person_00100.csv
# angepasst: P053_id043_person_00100.csv
# angepasst: P053_id044_person_00100.csv
# angepasst: P053_id045_person_00100.csv
# angepasst: P053_id046_person_00100.csv
# angepasst: P053_id047_person_00100.csv
# angepasst: P053_id048_person_00100.csv
# angepasst: P053_id049_person_00100.csv
# angepasst: P053_id050_person_00100.csv
# angepasst: P053_id051_person_00100.csv
# angepasst: P053_id052_person_00100.csv
# angepasst: P053_id053_person_00100.csv
# angepasst: P053_id054_person_00100.csv
# angepasst: P053_id055_person_00100.csv
# angepasst: P053_id056_person_00100.csv
# angepasst: P053_id057_person_00100.csv
# angepasst: P053_id058_person_00100.csv
# angepasst: P053_id059_person_00100.csv
# angepasst: P053_id060_person_00100.csv
# angepasst: P053_id061_person_00100.csv
# angepasst: P053_id062_person_00100.csv
# angepasst: P053_id063_person_00100.csv
# angepasst: P053_id064_person_00100.csv
# angepasst: P053_id065_person_00100.csv
# angepasst: P053_id066_person_00100.csv
# angepasst: P053_id067_person_00100.csv
# angepasst: P053_id068_person_00100.csv
# angepasst: P053_id069_person_00100.csv
# angepasst: P053_id070_person_00100.csv
# angepasst: P053_id071_person_00100.csv
# angepasst: P053_id072_person_00100.csv
# angepasst: P053_id073_person_00100.csv
# angepasst: P053_id074_person_00101.csv
# angepasst: P053_id075_person_00100.csv
# angepasst: P053_id076_person_00101.csv
# angepasst: P053_id077_person_00100.csv
# angepasst: P053_id078_person_00100.csv
# angepasst: P053_id079_person_00100.csv
# angepasst: P053_id080_person_00100.csv
# angepasst: P053_id081_person_00100.csv
# angepasst: P053_id082_person_00101.csv
# angepasst: P053_id083_person_00100.csv
# angepasst: P053_id084_person_00101.csv
# angepasst: P053_id085_person_00101.csv
# angepasst: P053_id086_person_00100.csv
# angepasst: P053_id087_person_00101.csv
# angepasst: P053_id088_politik_00111.csv
# angepasst: P053_id089_politik_00110.csv
# angepasst: P053_id090_politik_00110.csv
# angepasst: P053_id091_politik_00110.csv
# angepasst: P053_id092_politik_00111.csv
# angepasst: P053_id093_politik_00110.csv
# angepasst: P053_id094_politik_00110.csv
# angepasst: P053_id095_politik_00110.csv
# angepasst: P053_id096_politik_00110.csv
# angepasst: P053_id097_politik_00110.csv
# angepasst: P053_id098_politik_00110.csv
# angepasst: P053_id099_politik_00111.csv
# angepasst: P053_id100_politik_00111.csv
# angepasst: P053_id101_politik_00110.csv
# angepasst: P053_id102_politik_00111.csv
# angepasst: P053_id103_politik_00110.csv
# angepasst: P053_id104_politik_00110.csv
# angepasst: P053_id105_politik_00110.csv
# angepasst: P053_id106_meme_10011.csv
# angepasst: P053_id107_meme_10111.csv
# angepasst: P053_id108_meme_10001.csv
# angepasst: P053_id109_meme_10011.csv
# angepasst: P053_id110_meme_10001.csv
# angepasst: P053_id111_meme_10001.csv
# angepasst: P053_id112_meme_10001.csv
# angepasst: P053_id113_meme_10001.csv
# angepasst: P053_id114_meme_10001.csv
# angepasst: P053_id115_meme_10001.csv
# angepasst: P053_id116_meme_10011.csv
# angepasst: P053_id117_meme_10011.csv
# angepasst: P053_id118_meme_10001.csv
# angepasst: P053_id119_meme_10001.csv
# angepasst: P053_id120_meme_10001.csv
# angepasst: P053_id121_meme_10001.csv
# angepasst: P053_id122_meme_10011.csv
# angepasst: P053_id123_meme_10011.csv
# angepasst: P053_id124_meme_10011.csv
# angepasst: P053_id125_meme_10001.csv
# angepasst: P053_id126_politik_00011.csv
# angepasst: P053_id127_text_00011.csv
# angepasst: P053_id128_text_01001.csv
# angepasst: P053_id129_ort_01001.csv
# angepasst: P053_id130_ort_01001.csv
# angepasst: P053_id131_person_00111.csv
# angepasst: P053_id132_person_00101.csv
# angepasst: P053_id133_person_00101.csv
# angepasst: P053_id134_politik_00111.csv
# angepasst: P053_id135_politik_10111.csv
# angepasst: P053_id136_politik_00111.csv
# angepasst: P053_id137_politik_00111.csv
# angepasst: P053_id138_politik_00111.csv
# angepasst: P053_id139_politik_00111.csv
# angepasst: P053_id140_politik_00111.csv
# angepasst: P053_id141_politik_10011.csv
# angepasst: P053_id143_text_00001.csv
# angepasst: P053_id144_text_00001.csv
# angepasst: P053_id146_text_00011.csv
# angepasst: P053_id147_text_10001.csv
# angepasst: P053_id148_text_10001.csv
# angepasst: P053_id149_text_10001.csv
# angepasst: P053_id150_text_10001.csv
# angepasst: P053_id151_text_10011.csv
# angepasst: P053_id152_text_10011.csv
# angepasst: P053_id153_text_10011.csv
# angepasst: P054_id001_meme_10000.csv
# angepasst: P054_id002_meme_10000.csv
# angepasst: P054_id003_meme_10000.csv
# angepasst: P054_id004_meme_10000.csv
# angepasst: P054_id005_meme_10000.csv
# angepasst: P054_id006_meme_10000.csv
# angepasst: P054_id007_meme_10000.csv
# angepasst: P054_id008_meme_10000.csv
# angepasst: P054_id009_meme_10000.csv
# angepasst: P054_id010_meme_10000.csv
# angepasst: P054_id011_ort_01001.csv
# angepasst: P054_id012_ort_01001.csv
# angepasst: P054_id013_ort_01001.csv
# angepasst: P054_id014_ort_01000.csv
# angepasst: P054_id015_ort_01001.csv
# angepasst: P054_id016_ort_01001.csv
# angepasst: P054_id017_ort_01001.csv
# angepasst: P054_id018_ort_01000.csv
# angepasst: P054_id020_ort_01000.csv
# angepasst: P054_id021_ort_01000.csv
# angepasst: P054_id022_ort_01000.csv
# angepasst: P054_id023_ort_01000.csv
# angepasst: P054_id024_ort_01000.csv
# angepasst: P054_id025_ort_01000.csv
# angepasst: P054_id026_ort_01000.csv
# angepasst: P054_id027_ort_01000.csv
# angepasst: P054_id028_ort_01000.csv
# angepasst: P054_id029_ort_01000.csv
# angepasst: P054_id030_ort_01000.csv
# angepasst: P054_id031_ort_01000.csv
# angepasst: P054_id032_ort_01000.csv
# angepasst: P054_id033_person_00101.csv
# angepasst: P054_id034_person_00101.csv
# angepasst: P054_id035_person_00100.csv
# angepasst: P054_id036_person_00100.csv
# angepasst: P054_id037_person_00100.csv
# angepasst: P054_id038_person_00100.csv
# angepasst: P054_id039_person_00100.csv
# angepasst: P054_id040_person_00100.csv
# angepasst: P054_id041_person_00100.csv
# angepasst: P054_id042_person_00100.csv
# angepasst: P054_id043_person_00100.csv
# angepasst: P054_id045_person_00100.csv
# angepasst: P054_id046_person_00100.csv
# angepasst: P054_id047_person_00100.csv
# angepasst: P054_id048_person_00100.csv
# angepasst: P054_id049_person_00100.csv
# angepasst: P054_id050_person_00100.csv
# angepasst: P054_id051_person_00100.csv
# angepasst: P054_id052_person_00100.csv
# angepasst: P054_id053_person_00100.csv
# angepasst: P054_id054_person_00100.csv
# angepasst: P054_id055_person_00100.csv
# angepasst: P054_id056_person_00100.csv
# angepasst: P054_id057_person_00100.csv
# angepasst: P054_id058_person_00100.csv
# angepasst: P054_id059_person_00100.csv
# angepasst: P054_id060_person_00100.csv
# angepasst: P054_id061_person_00100.csv
# angepasst: P054_id062_person_00100.csv
# angepasst: P054_id063_person_00100.csv
# angepasst: P054_id064_person_00100.csv
# angepasst: P054_id065_person_00100.csv
# angepasst: P054_id066_person_00100.csv
# angepasst: P054_id067_person_00100.csv
# angepasst: P054_id068_person_00100.csv
# angepasst: P054_id069_person_00100.csv
# angepasst: P054_id070_person_00100.csv
# angepasst: P054_id071_person_00100.csv
# angepasst: P054_id072_person_00100.csv
# angepasst: P054_id073_person_00100.csv
# angepasst: P054_id074_person_00101.csv
# angepasst: P054_id075_person_00100.csv
# angepasst: P054_id076_person_00101.csv
# angepasst: P054_id077_person_00100.csv
# angepasst: P054_id078_person_00100.csv
# angepasst: P054_id079_person_00100.csv
# angepasst: P054_id080_person_00100.csv
# angepasst: P054_id081_person_00100.csv
# angepasst: P054_id082_person_00101.csv
# angepasst: P054_id083_person_00100.csv
# angepasst: P054_id084_person_00101.csv
# angepasst: P054_id085_person_00101.csv
# angepasst: P054_id086_person_00100.csv
# angepasst: P054_id087_person_00101.csv
# angepasst: P054_id088_politik_00111.csv
# angepasst: P054_id089_politik_00110.csv
# angepasst: P054_id090_politik_00110.csv
# angepasst: P054_id091_politik_00110.csv
# angepasst: P054_id092_politik_00111.csv
# angepasst: P054_id093_politik_00110.csv
# angepasst: P054_id094_politik_00110.csv
# angepasst: P054_id095_politik_00110.csv
# angepasst: P054_id096_politik_00110.csv
# angepasst: P054_id097_politik_00110.csv
# angepasst: P054_id098_politik_00110.csv
# angepasst: P054_id099_politik_00111.csv
# angepasst: P054_id100_politik_00111.csv
# angepasst: P054_id101_politik_00110.csv
# angepasst: P054_id102_politik_00111.csv
# angepasst: P054_id103_politik_00110.csv
# angepasst: P054_id104_politik_00110.csv
# angepasst: P054_id105_politik_00110.csv
# angepasst: P054_id106_meme_10011.csv
# angepasst: P054_id107_meme_10111.csv
# angepasst: P054_id108_meme_10001.csv
# angepasst: P054_id109_meme_10011.csv
# angepasst: P054_id110_meme_10001.csv
# angepasst: P054_id111_meme_10001.csv
# angepasst: P054_id112_meme_10001.csv
# angepasst: P054_id113_meme_10001.csv
# angepasst: P054_id114_meme_10001.csv
# angepasst: P054_id115_meme_10001.csv
# angepasst: P054_id116_meme_10011.csv
# angepasst: P054_id117_meme_10011.csv
# angepasst: P054_id118_meme_10001.csv
# angepasst: P054_id119_meme_10001.csv
# angepasst: P054_id121_meme_10001.csv
# angepasst: P054_id122_meme_10011.csv
# angepasst: P054_id123_meme_10011.csv
# angepasst: P054_id124_meme_10011.csv
# angepasst: P054_id125_meme_10001.csv
# angepasst: P054_id126_politik_00011.csv
# angepasst: P054_id127_text_00011.csv
# angepasst: P054_id128_text_01001.csv
# angepasst: P054_id129_ort_01001.csv
# angepasst: P054_id130_ort_01001.csv
# angepasst: P054_id131_person_00111.csv
# angepasst: P054_id132_person_00101.csv
# angepasst: P054_id133_person_00101.csv
# angepasst: P054_id134_politik_00111.csv
# angepasst: P054_id135_politik_10111.csv
# angepasst: P054_id136_politik_00111.csv
# angepasst: P054_id137_politik_00111.csv
# angepasst: P054_id138_politik_00111.csv
# angepasst: P054_id139_politik_00111.csv
# angepasst: P054_id140_politik_00111.csv
# angepasst: P054_id141_politik_10011.csv
# angepasst: P054_id142_text_00001.csv
# angepasst: P054_id143_text_00001.csv
# angepasst: P054_id144_text_00001.csv
# angepasst: P054_id147_text_10001.csv
# angepasst: P054_id148_text_10001.csv
# angepasst: P054_id149_text_10001.csv
# angepasst: P054_id150_text_10001.csv
# angepasst: P054_id151_text_10011.csv
# angepasst: P054_id152_text_10011.csv
# angepasst: P054_id153_text_10011.csv
