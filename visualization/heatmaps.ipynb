# %%
## Heatmaps Erstellung
import os
import glob

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
from pandas.errors import EmptyDataError

def make_heatmap(fix_df, size=800, bins=100, sigma=3):
    """
    Aus Fixation-DataFrame ein 2D-Histogramm erstellen, glätten und normalisieren.
    - fix_df: DataFrame mit Spalten 'x' und 'y' in Pixeln [0, size]
    - size: Pixelgröße des Stimulus (hier 800)
    - bins: Anzahl der Bins pro Achse für das Histogramm
    - sigma: Sigma für Gaussian-Glättung
    Rückgabe: 2D-Array Größe (bins, bins) mit Werten [0..1].
    """
    x = fix_df['x'].values
    y = fix_df['y'].values
    # 2D-Histogramm
    heatmap, _, _ = np.histogram2d(
        y, x,                       # y zuerst, damit image richtig orientiert
        bins=bins,
        range=[[0, size], [0, size]],
        density=False
    )
    # Glätten
    heatmap = gaussian_filter(heatmap, sigma=sigma)
    # Normieren (0..1)
    if heatmap.max() > 0:
        heatmap = heatmap / heatmap.max()
    return heatmap

def process_heatmaps(fixations_folder, heatmap_folder, size=800, bins=100, sigma=3):
    os.makedirs(heatmap_folder, exist_ok=True)
    pattern = os.path.join(fixations_folder, "*_fixations.csv")
    for path in glob.glob(pattern):
        # 1) Versuche einzulesen, skippe komplett leere oder unlesbare Dateien
        try:
            df = pd.read_csv(path)
        except EmptyDataError:
            print(f"Skipping {os.path.basename(path)}: file is empty or has no header")
            continue

        # 2) Skippe, wenn Header da, aber keine Datenzeilen
        if df.empty:
            print(f"Skipping {os.path.basename(path)}: no fixations")
            continue

        # 3) Heatmap erstellen
        heat = make_heatmap(df, size=size, bins=bins, sigma=sigma)

        # 4) Plot & speichern
        plt.figure(figsize=(4,4))
        plt.imshow(heat, origin='lower', extent=[0, size, 0, size])
        plt.axis('off')
        base = os.path.splitext(os.path.basename(path))[0].replace("_fixations", "")
        out_png = os.path.join(heatmap_folder, f"{base}_heatmap.png")
        plt.savefig(out_png, bbox_inches='tight', pad_inches=0)
        plt.close()
        print(f"Saved heatmap: {os.path.basename(out_png)}")

# ==== Notebook-Aufruf ====
fix_folder     = "processed/fixations"
heatmap_folder = "processed/heatmaps"
process_heatmaps(fix_folder, heatmap_folder, size=800, bins=100, sigma=3)
# Out:
# Saved heatmap: P000_id001_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id002_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id003_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id004_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id005_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id006_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id007_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id008_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id009_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id010_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id011_ort_processed_heatmap.png
# Saved heatmap: P000_id012_ort_processed_heatmap.png
# Saved heatmap: P000_id013_ort_processed_heatmap.png
# Saved heatmap: P000_id014_ort_processed_heatmap.png
# Saved heatmap: P000_id015_ort_processed_heatmap.png
# Saved heatmap: P000_id016_ort_processed_heatmap.png
# Saved heatmap: P000_id017_ort_processed_heatmap.png
# Saved heatmap: P000_id018_ort_processed_heatmap.png
# Saved heatmap: P000_id019_ort_processed_heatmap.png
# Saved heatmap: P000_id020_ort_processed_heatmap.png
# Saved heatmap: P000_id021_ort_processed_heatmap.png
# Saved heatmap: P000_id022_ort_processed_heatmap.png
# Saved heatmap: P000_id023_ort_processed_heatmap.png
# Saved heatmap: P000_id024_ort_processed_heatmap.png
# Saved heatmap: P000_id025_ort_processed_heatmap.png
# Saved heatmap: P000_id026_ort_processed_heatmap.png
# Saved heatmap: P000_id027_ort_processed_heatmap.png
# Saved heatmap: P000_id028_ort_processed_heatmap.png
# Saved heatmap: P000_id029_ort_processed_heatmap.png
# Saved heatmap: P000_id030_ort_processed_heatmap.png
# Saved heatmap: P000_id031_ort_processed_heatmap.png
# Saved heatmap: P000_id032_ort_processed_heatmap.png
# Saved heatmap: P000_id033_person_processed_heatmap.png
# Saved heatmap: P000_id034_person_processed_heatmap.png
# Saved heatmap: P000_id035_person_processed_heatmap.png
# Saved heatmap: P000_id036_person_processed_heatmap.png
# Saved heatmap: P000_id037_person_processed_heatmap.png
# Saved heatmap: P000_id038_person_processed_heatmap.png
# Saved heatmap: P000_id039_person_processed_heatmap.png
# Saved heatmap: P000_id040_person_processed_heatmap.png
# Saved heatmap: P000_id041_person_processed_heatmap.png
# Saved heatmap: P000_id042_person_processed_heatmap.png
# Saved heatmap: P000_id043_person_processed_heatmap.png
# Saved heatmap: P000_id044_person_processed_heatmap.png
# Saved heatmap: P000_id045_person_processed_heatmap.png
# Saved heatmap: P000_id046_person_processed_heatmap.png
# Saved heatmap: P000_id047_person_processed_heatmap.png
# Saved heatmap: P000_id048_person_processed_heatmap.png
# Saved heatmap: P000_id049_person_processed_heatmap.png
# Saved heatmap: P000_id050_person_processed_heatmap.png
# Saved heatmap: P000_id051_person_processed_heatmap.png
# Saved heatmap: P000_id052_person_processed_heatmap.png
# Saved heatmap: P000_id053_person_processed_heatmap.png
# Saved heatmap: P000_id054_person_processed_heatmap.png
# Saved heatmap: P000_id055_person_processed_heatmap.png
# Saved heatmap: P000_id056_person_processed_heatmap.png
# Saved heatmap: P000_id057_person_processed_heatmap.png
# Saved heatmap: P000_id058_person_processed_heatmap.png
# Saved heatmap: P000_id059_person_processed_heatmap.png
# Saved heatmap: P000_id060_person_processed_heatmap.png
# Saved heatmap: P000_id061_person_processed_heatmap.png
# Saved heatmap: P000_id062_person_processed_heatmap.png
# Saved heatmap: P000_id063_person_processed_heatmap.png
# Saved heatmap: P000_id064_person_processed_heatmap.png
# Saved heatmap: P000_id065_person_processed_heatmap.png
# Saved heatmap: P000_id066_person_processed_heatmap.png
# Saved heatmap: P000_id067_person_processed_heatmap.png
# Saved heatmap: P000_id068_person_processed_heatmap.png
# Saved heatmap: P000_id069_person_processed_heatmap.png
# Saved heatmap: P000_id070_person_processed_heatmap.png
# Saved heatmap: P000_id071_person_processed_heatmap.png
# Saved heatmap: P000_id072_person_processed_heatmap.png
# Saved heatmap: P000_id073_person_processed_heatmap.png
# Saved heatmap: P000_id074_person_processed_heatmap.png
# Saved heatmap: P000_id075_person_processed_heatmap.png
# Saved heatmap: P000_id076_person_processed_heatmap.png
# Saved heatmap: P000_id077_person_processed_heatmap.png
# Saved heatmap: P000_id078_person_processed_heatmap.png
# Saved heatmap: P000_id079_person_processed_heatmap.png
# Saved heatmap: P000_id080_person_processed_heatmap.png
# Saved heatmap: P000_id081_person_processed_heatmap.png
# Saved heatmap: P000_id082_person_processed_heatmap.png
# Saved heatmap: P000_id083_person_processed_heatmap.png
# Saved heatmap: P000_id084_person_processed_heatmap.png
# Saved heatmap: P000_id085_person_processed_heatmap.png
# Saved heatmap: P000_id086_person_processed_heatmap.png
# Saved heatmap: P000_id087_person_processed_heatmap.png
# Saved heatmap: P000_id088_politik_processed_heatmap.png
# Saved heatmap: P000_id089_politik_processed_heatmap.png
# Saved heatmap: P000_id090_politik_ncc_processed_heatmap.png
# Saved heatmap: P000_id091_politik_ncc_processed_heatmap.png
# Saved heatmap: P000_id092_politik_processed_heatmap.png
# Saved heatmap: P000_id093_politik_processed_heatmap.png
# Saved heatmap: P000_id094_politik_processed_heatmap.png
# Saved heatmap: P000_id095_politik_processed_heatmap.png
# Saved heatmap: P000_id096_politik_processed_heatmap.png
# Saved heatmap: P000_id097_politik_processed_heatmap.png
# Saved heatmap: P000_id098_politik_processed_heatmap.png
# Saved heatmap: P000_id099_politik_processed_heatmap.png
# Saved heatmap: P000_id100_politik_processed_heatmap.png
# Saved heatmap: P000_id101_politik_processed_heatmap.png
# Saved heatmap: P000_id102_politik_processed_heatmap.png
# Saved heatmap: P000_id103_politik_processed_heatmap.png
# Saved heatmap: P000_id104_politik_processed_heatmap.png
# Saved heatmap: P000_id105_politik_processed_heatmap.png
# Saved heatmap: P000_id106_textigm_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id107_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id108_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id109_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id110_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id111_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id112_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id113_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id114_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id115_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id116_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id117_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id118_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id119_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id120_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id121_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id122_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id123_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id124_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id125_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P000_id126_text_politik_processed_heatmap.png
# Saved heatmap: P000_id127_textimg_ncc_processed_heatmap.png
# Saved heatmap: P000_id128_textimg_processed_heatmap.png
# Saved heatmap: P000_id129_textimg_ort_processed_heatmap.png
# Saved heatmap: P000_id130_textimg_ort_processed_heatmap.png
# Saved heatmap: P000_id131_textimg_person_processed_heatmap.png
# Saved heatmap: P000_id132_textimg_person_ncc_processed_heatmap.png
# Saved heatmap: P000_id133_textimg_person_ncc_processed_heatmap.png
# Saved heatmap: P000_id134_textimg_person_politik_ncc_processed_heatmap.png
# Saved heatmap: P000_id135_textimg_politik_processed_heatmap.png
# Saved heatmap: P000_id136_textimg_politik_processed_heatmap.png
# Saved heatmap: P000_id137_textimg_politik_processed_heatmap.png
# Saved heatmap: P000_id138_textimg_politik_processed_heatmap.png
# Saved heatmap: P000_id139_textimg_politik_processed_heatmap.png
# Saved heatmap: P000_id140_textimg_politik_processed_heatmap.png
# Saved heatmap: P000_id141_textimg_politik_ncc_processed_heatmap.png
# Saved heatmap: P000_id142_text_processed_heatmap.png
# Saved heatmap: P000_id143_text_processed_heatmap.png
# Saved heatmap: P000_id144_text_processed_heatmap.png
# Saved heatmap: P000_id146_processed_heatmap.png
# Saved heatmap: P000_id147_text_ncc_processed_heatmap.png
# Saved heatmap: P000_id148_text_ncc_processed_heatmap.png
# Saved heatmap: P000_id149_text_ncc_processed_heatmap.png
# Saved heatmap: P000_id150_text_ncc_processed_heatmap.png
# Saved heatmap: P000_id151_text_ncc_processed_heatmap.png
# Saved heatmap: P000_id152_text_ncc_processed_heatmap.png
# Saved heatmap: P000_id153_text_ncc_processed_heatmap.png
# Saved heatmap: P001_id001_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id002_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id003_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id004_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id005_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id006_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id007_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id008_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id009_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id010_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id011_ort_processed_heatmap.png
# Saved heatmap: P001_id012_ort_processed_heatmap.png
# Saved heatmap: P001_id013_ort_processed_heatmap.png
# Saved heatmap: P001_id014_ort_processed_heatmap.png
# Saved heatmap: P001_id015_ort_processed_heatmap.png
# Saved heatmap: P001_id016_ort_processed_heatmap.png
# Saved heatmap: P001_id017_ort_processed_heatmap.png
# Saved heatmap: P001_id018_ort_processed_heatmap.png
# Saved heatmap: P001_id019_ort_processed_heatmap.png
# Saved heatmap: P001_id020_ort_processed_heatmap.png
# Saved heatmap: P001_id021_ort_processed_heatmap.png
# Saved heatmap: P001_id022_ort_processed_heatmap.png
# Saved heatmap: P001_id023_ort_processed_heatmap.png
# Saved heatmap: P001_id024_ort_processed_heatmap.png
# Saved heatmap: P001_id025_ort_processed_heatmap.png
# Saved heatmap: P001_id026_ort_processed_heatmap.png
# Saved heatmap: P001_id027_ort_processed_heatmap.png
# Saved heatmap: P001_id028_ort_processed_heatmap.png
# Saved heatmap: P001_id029_ort_processed_heatmap.png
# Saved heatmap: P001_id030_ort_processed_heatmap.png
# Saved heatmap: P001_id031_ort_processed_heatmap.png
# Saved heatmap: P001_id032_ort_processed_heatmap.png
# Saved heatmap: P001_id033_person_processed_heatmap.png
# Saved heatmap: P001_id034_person_processed_heatmap.png
# Saved heatmap: P001_id035_person_processed_heatmap.png
# Saved heatmap: P001_id036_person_processed_heatmap.png
# Saved heatmap: P001_id037_person_processed_heatmap.png
# Saved heatmap: P001_id038_person_processed_heatmap.png
# Saved heatmap: P001_id039_person_processed_heatmap.png
# Saved heatmap: P001_id040_person_processed_heatmap.png
# Saved heatmap: P001_id041_person_processed_heatmap.png
# Saved heatmap: P001_id042_person_processed_heatmap.png
# Saved heatmap: P001_id043_person_processed_heatmap.png
# Saved heatmap: P001_id044_person_processed_heatmap.png
# Saved heatmap: P001_id046_person_processed_heatmap.png
# Saved heatmap: P001_id047_person_processed_heatmap.png
# Saved heatmap: P001_id048_person_processed_heatmap.png
# Saved heatmap: P001_id049_person_processed_heatmap.png
# Saved heatmap: P001_id050_person_processed_heatmap.png
# Saved heatmap: P001_id051_person_processed_heatmap.png
# Saved heatmap: P001_id052_person_processed_heatmap.png
# Saved heatmap: P001_id053_person_processed_heatmap.png
# Saved heatmap: P001_id054_person_processed_heatmap.png
# Saved heatmap: P001_id055_person_processed_heatmap.png
# Saved heatmap: P001_id056_person_processed_heatmap.png
# Saved heatmap: P001_id057_person_processed_heatmap.png
# Saved heatmap: P001_id058_person_processed_heatmap.png
# Saved heatmap: P001_id059_person_processed_heatmap.png
# Saved heatmap: P001_id060_person_processed_heatmap.png
# Saved heatmap: P001_id061_person_processed_heatmap.png
# Saved heatmap: P001_id062_person_processed_heatmap.png
# Saved heatmap: P001_id063_person_processed_heatmap.png
# Saved heatmap: P001_id064_person_processed_heatmap.png
# Saved heatmap: P001_id065_person_processed_heatmap.png
# Saved heatmap: P001_id066_person_processed_heatmap.png
# Saved heatmap: P001_id067_person_processed_heatmap.png
# Saved heatmap: P001_id068_person_processed_heatmap.png
# Saved heatmap: P001_id069_person_processed_heatmap.png
# Saved heatmap: P001_id070_person_processed_heatmap.png
# Saved heatmap: P001_id071_person_processed_heatmap.png
# Saved heatmap: P001_id072_person_processed_heatmap.png
# Saved heatmap: P001_id073_person_processed_heatmap.png
# Saved heatmap: P001_id074_person_processed_heatmap.png
# Saved heatmap: P001_id075_person_processed_heatmap.png
# Saved heatmap: P001_id076_person_processed_heatmap.png
# Saved heatmap: P001_id077_person_processed_heatmap.png
# Saved heatmap: P001_id078_person_processed_heatmap.png
# Saved heatmap: P001_id079_person_processed_heatmap.png
# Saved heatmap: P001_id080_person_processed_heatmap.png
# Saved heatmap: P001_id081_person_processed_heatmap.png
# Saved heatmap: P001_id082_person_processed_heatmap.png
# Saved heatmap: P001_id083_person_processed_heatmap.png
# Saved heatmap: P001_id084_person_processed_heatmap.png
# Saved heatmap: P001_id085_person_processed_heatmap.png
# Saved heatmap: P001_id086_person_processed_heatmap.png
# Saved heatmap: P001_id087_person_processed_heatmap.png
# Saved heatmap: P001_id088_politik_processed_heatmap.png
# Saved heatmap: P001_id089_politik_processed_heatmap.png
# Saved heatmap: P001_id090_politik_ncc_processed_heatmap.png
# Saved heatmap: P001_id091_politik_ncc_processed_heatmap.png
# Saved heatmap: P001_id092_politik_processed_heatmap.png
# Saved heatmap: P001_id093_politik_processed_heatmap.png
# Saved heatmap: P001_id094_politik_processed_heatmap.png
# Saved heatmap: P001_id095_politik_processed_heatmap.png
# Saved heatmap: P001_id096_politik_processed_heatmap.png
# Saved heatmap: P001_id097_politik_processed_heatmap.png
# Saved heatmap: P001_id098_politik_processed_heatmap.png
# Saved heatmap: P001_id099_politik_processed_heatmap.png
# Saved heatmap: P001_id100_politik_processed_heatmap.png
# Saved heatmap: P001_id101_politik_processed_heatmap.png
# Saved heatmap: P001_id102_politik_processed_heatmap.png
# Saved heatmap: P001_id103_politik_processed_heatmap.png
# Saved heatmap: P001_id104_politik_processed_heatmap.png
# Saved heatmap: P001_id105_politik_processed_heatmap.png
# Saved heatmap: P001_id106_textigm_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id107_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id108_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id109_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id110_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id111_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id112_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id113_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id114_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id115_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id116_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id117_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id118_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id119_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id120_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id121_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id122_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id123_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id124_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id125_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P001_id126_text_politik_processed_heatmap.png
# Saved heatmap: P001_id127_textimg_ncc_processed_heatmap.png
# Saved heatmap: P001_id128_textimg_processed_heatmap.png
# Saved heatmap: P001_id129_textimg_ort_processed_heatmap.png
# Saved heatmap: P001_id130_textimg_ort_processed_heatmap.png
# Saved heatmap: P001_id131_textimg_person_processed_heatmap.png
# Saved heatmap: P001_id132_textimg_person_ncc_processed_heatmap.png
# Saved heatmap: P001_id133_textimg_person_ncc_processed_heatmap.png
# Saved heatmap: P001_id134_textimg_person_politik_ncc_processed_heatmap.png
# Saved heatmap: P001_id135_textimg_politik_processed_heatmap.png
# Saved heatmap: P001_id136_textimg_politik_processed_heatmap.png
# Saved heatmap: P001_id137_textimg_politik_processed_heatmap.png
# Saved heatmap: P001_id138_textimg_politik_processed_heatmap.png
# Saved heatmap: P001_id139_textimg_politik_processed_heatmap.png
# Saved heatmap: P001_id140_textimg_politik_processed_heatmap.png
# Saved heatmap: P001_id141_textimg_politik_ncc_processed_heatmap.png
# Saved heatmap: P001_id142_text_processed_heatmap.png
# Saved heatmap: P001_id143_text_processed_heatmap.png
# Saved heatmap: P001_id144_text_processed_heatmap.png
# Saved heatmap: P001_id146_processed_heatmap.png
# Saved heatmap: P001_id147_text_ncc_processed_heatmap.png
# Saved heatmap: P001_id148_text_ncc_processed_heatmap.png
# Saved heatmap: P001_id149_text_ncc_processed_heatmap.png
# Saved heatmap: P001_id150_text_ncc_processed_heatmap.png
# Saved heatmap: P001_id151_text_ncc_processed_heatmap.png
# Saved heatmap: P001_id152_text_ncc_processed_heatmap.png
# Saved heatmap: P001_id153_text_ncc_processed_heatmap.png
# Saved heatmap: P002_id001_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id002_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id003_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id004_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id005_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id006_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id007_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id008_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id009_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id010_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id011_ort_processed_heatmap.png
# Saved heatmap: P002_id012_ort_processed_heatmap.png
# Saved heatmap: P002_id013_ort_processed_heatmap.png
# Saved heatmap: P002_id014_ort_processed_heatmap.png
# Saved heatmap: P002_id015_ort_processed_heatmap.png
# Saved heatmap: P002_id016_ort_processed_heatmap.png
# Saved heatmap: P002_id017_ort_processed_heatmap.png
# Saved heatmap: P002_id018_ort_processed_heatmap.png
# Saved heatmap: P002_id019_ort_processed_heatmap.png
# Saved heatmap: P002_id020_ort_processed_heatmap.png
# Saved heatmap: P002_id021_ort_processed_heatmap.png
# Saved heatmap: P002_id022_ort_processed_heatmap.png
# Saved heatmap: P002_id023_ort_processed_heatmap.png
# Saved heatmap: P002_id024_ort_processed_heatmap.png
# Saved heatmap: P002_id025_ort_processed_heatmap.png
# Saved heatmap: P002_id026_ort_processed_heatmap.png
# Saved heatmap: P002_id027_ort_processed_heatmap.png
# Saved heatmap: P002_id028_ort_processed_heatmap.png
# Saved heatmap: P002_id029_ort_processed_heatmap.png
# Saved heatmap: P002_id030_ort_processed_heatmap.png
# Saved heatmap: P002_id031_ort_processed_heatmap.png
# Saved heatmap: P002_id032_ort_processed_heatmap.png
# Saved heatmap: P002_id033_person_processed_heatmap.png
# Saved heatmap: P002_id034_person_processed_heatmap.png
# Saved heatmap: P002_id035_person_processed_heatmap.png
# Saved heatmap: P002_id036_person_processed_heatmap.png
# Saved heatmap: P002_id037_person_processed_heatmap.png
# Saved heatmap: P002_id038_person_processed_heatmap.png
# Saved heatmap: P002_id039_person_processed_heatmap.png
# Saved heatmap: P002_id040_person_processed_heatmap.png
# Saved heatmap: P002_id041_person_processed_heatmap.png
# Saved heatmap: P002_id042_person_processed_heatmap.png
# Saved heatmap: P002_id043_person_processed_heatmap.png
# Saved heatmap: P002_id044_person_processed_heatmap.png
# Saved heatmap: P002_id045_person_processed_heatmap.png
# Saved heatmap: P002_id046_person_processed_heatmap.png
# Saved heatmap: P002_id047_person_processed_heatmap.png
# Saved heatmap: P002_id048_person_processed_heatmap.png
# Saved heatmap: P002_id049_person_processed_heatmap.png
# Saved heatmap: P002_id050_person_processed_heatmap.png
# Saved heatmap: P002_id051_person_processed_heatmap.png
# Saved heatmap: P002_id052_person_processed_heatmap.png
# Saved heatmap: P002_id053_person_processed_heatmap.png
# Saved heatmap: P002_id054_person_processed_heatmap.png
# Saved heatmap: P002_id055_person_processed_heatmap.png
# Saved heatmap: P002_id056_person_processed_heatmap.png
# Saved heatmap: P002_id057_person_processed_heatmap.png
# Saved heatmap: P002_id058_person_processed_heatmap.png
# Saved heatmap: P002_id059_person_processed_heatmap.png
# Saved heatmap: P002_id060_person_processed_heatmap.png
# Saved heatmap: P002_id061_person_processed_heatmap.png
# Saved heatmap: P002_id062_person_processed_heatmap.png
# Saved heatmap: P002_id063_person_processed_heatmap.png
# Saved heatmap: P002_id064_person_processed_heatmap.png
# Saved heatmap: P002_id065_person_processed_heatmap.png
# Saved heatmap: P002_id066_person_processed_heatmap.png
# Saved heatmap: P002_id067_person_processed_heatmap.png
# Saved heatmap: P002_id068_person_processed_heatmap.png
# Saved heatmap: P002_id069_person_processed_heatmap.png
# Saved heatmap: P002_id070_person_processed_heatmap.png
# Saved heatmap: P002_id071_person_processed_heatmap.png
# Saved heatmap: P002_id072_person_processed_heatmap.png
# Saved heatmap: P002_id073_person_processed_heatmap.png
# Saved heatmap: P002_id074_person_processed_heatmap.png
# Saved heatmap: P002_id075_person_processed_heatmap.png
# Saved heatmap: P002_id076_person_processed_heatmap.png
# Saved heatmap: P002_id077_person_processed_heatmap.png
# Saved heatmap: P002_id078_person_processed_heatmap.png
# Saved heatmap: P002_id079_person_processed_heatmap.png
# Saved heatmap: P002_id080_person_processed_heatmap.png
# Saved heatmap: P002_id081_person_processed_heatmap.png
# Saved heatmap: P002_id082_person_processed_heatmap.png
# Saved heatmap: P002_id083_person_processed_heatmap.png
# Saved heatmap: P002_id084_person_processed_heatmap.png
# Saved heatmap: P002_id085_person_processed_heatmap.png
# Saved heatmap: P002_id086_person_processed_heatmap.png
# Saved heatmap: P002_id087_person_processed_heatmap.png
# Saved heatmap: P002_id089_politik_processed_heatmap.png
# Saved heatmap: P002_id090_politik_ncc_processed_heatmap.png
# Saved heatmap: P002_id091_politik_ncc_processed_heatmap.png
# Saved heatmap: P002_id092_politik_processed_heatmap.png
# Saved heatmap: P002_id093_politik_processed_heatmap.png
# Saved heatmap: P002_id094_politik_processed_heatmap.png
# Saved heatmap: P002_id095_politik_processed_heatmap.png
# Saved heatmap: P002_id096_politik_processed_heatmap.png
# Saved heatmap: P002_id097_politik_processed_heatmap.png
# Saved heatmap: P002_id098_politik_processed_heatmap.png
# Saved heatmap: P002_id099_politik_processed_heatmap.png
# Saved heatmap: P002_id100_politik_processed_heatmap.png
# Saved heatmap: P002_id101_politik_processed_heatmap.png
# Saved heatmap: P002_id102_politik_processed_heatmap.png
# Saved heatmap: P002_id103_politik_processed_heatmap.png
# Saved heatmap: P002_id104_politik_processed_heatmap.png
# Saved heatmap: P002_id105_politik_processed_heatmap.png
# Saved heatmap: P002_id106_textigm_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id107_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id108_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id109_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id110_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id111_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id112_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id113_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id114_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id115_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id116_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id117_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id118_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id119_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id120_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id121_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id122_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id123_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id124_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id125_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P002_id126_text_politik_processed_heatmap.png
# Saved heatmap: P002_id127_textimg_ncc_processed_heatmap.png
# Saved heatmap: P002_id128_textimg_processed_heatmap.png
# Saved heatmap: P002_id129_textimg_ort_processed_heatmap.png
# Saved heatmap: P002_id130_textimg_ort_processed_heatmap.png
# Saved heatmap: P002_id131_textimg_person_processed_heatmap.png
# Saved heatmap: P002_id132_textimg_person_ncc_processed_heatmap.png
# Saved heatmap: P002_id133_textimg_person_ncc_processed_heatmap.png
# Saved heatmap: P002_id134_textimg_person_politik_ncc_processed_heatmap.png
# Saved heatmap: P002_id135_textimg_politik_processed_heatmap.png
# Saved heatmap: P002_id136_textimg_politik_processed_heatmap.png
# Saved heatmap: P002_id137_textimg_politik_processed_heatmap.png
# Saved heatmap: P002_id138_textimg_politik_processed_heatmap.png
# Saved heatmap: P002_id139_textimg_politik_processed_heatmap.png
# Saved heatmap: P002_id140_textimg_politik_processed_heatmap.png
# Saved heatmap: P002_id141_textimg_politik_ncc_processed_heatmap.png
# Saved heatmap: P002_id142_text_processed_heatmap.png
# Saved heatmap: P002_id143_text_processed_heatmap.png
# Saved heatmap: P002_id144_text_processed_heatmap.png
# Saved heatmap: P002_id146_processed_heatmap.png
# Saved heatmap: P002_id147_text_ncc_processed_heatmap.png
# Saved heatmap: P002_id148_text_ncc_processed_heatmap.png
# Saved heatmap: P002_id149_text_ncc_processed_heatmap.png
# Saved heatmap: P002_id150_text_ncc_processed_heatmap.png
# Saved heatmap: P002_id151_text_ncc_processed_heatmap.png
# Saved heatmap: P002_id152_text_ncc_processed_heatmap.png
# Saved heatmap: P002_id153_text_ncc_processed_heatmap.png
# Saved heatmap: P004_id001_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id002_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id003_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id004_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id005_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id006_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id007_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id009_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id010_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id011_ort_processed_heatmap.png
# Saved heatmap: P004_id012_ort_processed_heatmap.png
# Saved heatmap: P004_id013_ort_processed_heatmap.png
# Saved heatmap: P004_id014_ort_processed_heatmap.png
# Saved heatmap: P004_id015_ort_processed_heatmap.png
# Saved heatmap: P004_id016_ort_processed_heatmap.png
# Saved heatmap: P004_id017_ort_processed_heatmap.png
# Saved heatmap: P004_id018_ort_processed_heatmap.png
# Saved heatmap: P004_id019_ort_processed_heatmap.png
# Saved heatmap: P004_id020_ort_processed_heatmap.png
# Saved heatmap: P004_id021_ort_processed_heatmap.png
# Saved heatmap: P004_id022_ort_processed_heatmap.png
# Saved heatmap: P004_id023_ort_processed_heatmap.png
# Saved heatmap: P004_id024_ort_processed_heatmap.png
# Saved heatmap: P004_id025_ort_processed_heatmap.png
# Saved heatmap: P004_id026_ort_processed_heatmap.png
# Saved heatmap: P004_id027_ort_processed_heatmap.png
# Saved heatmap: P004_id028_ort_processed_heatmap.png
# Saved heatmap: P004_id029_ort_processed_heatmap.png
# Saved heatmap: P004_id030_ort_processed_heatmap.png
# Saved heatmap: P004_id031_ort_processed_heatmap.png
# Saved heatmap: P004_id032_ort_processed_heatmap.png
# Saved heatmap: P004_id033_person_processed_heatmap.png
# Saved heatmap: P004_id034_person_processed_heatmap.png
# Saved heatmap: P004_id035_person_processed_heatmap.png
# Saved heatmap: P004_id036_person_processed_heatmap.png
# Saved heatmap: P004_id037_person_processed_heatmap.png
# Saved heatmap: P004_id038_person_processed_heatmap.png
# Saved heatmap: P004_id039_person_processed_heatmap.png
# Saved heatmap: P004_id040_person_processed_heatmap.png
# Saved heatmap: P004_id041_person_processed_heatmap.png
# Saved heatmap: P004_id042_person_processed_heatmap.png
# Saved heatmap: P004_id043_person_processed_heatmap.png
# Saved heatmap: P004_id044_person_processed_heatmap.png
# Saved heatmap: P004_id045_person_processed_heatmap.png
# Saved heatmap: P004_id046_person_processed_heatmap.png
# Saved heatmap: P004_id047_person_processed_heatmap.png
# Saved heatmap: P004_id048_person_processed_heatmap.png
# Saved heatmap: P004_id049_person_processed_heatmap.png
# Saved heatmap: P004_id050_person_processed_heatmap.png
# Saved heatmap: P004_id051_person_processed_heatmap.png
# Saved heatmap: P004_id052_person_processed_heatmap.png
# Saved heatmap: P004_id053_person_processed_heatmap.png
# Saved heatmap: P004_id054_person_processed_heatmap.png
# Saved heatmap: P004_id055_person_processed_heatmap.png
# Saved heatmap: P004_id056_person_processed_heatmap.png
# Saved heatmap: P004_id057_person_processed_heatmap.png
# Saved heatmap: P004_id058_person_processed_heatmap.png
# Saved heatmap: P004_id059_person_processed_heatmap.png
# Saved heatmap: P004_id060_person_processed_heatmap.png
# Saved heatmap: P004_id061_person_processed_heatmap.png
# Saved heatmap: P004_id062_person_processed_heatmap.png
# Saved heatmap: P004_id063_person_processed_heatmap.png
# Saved heatmap: P004_id064_person_processed_heatmap.png
# Saved heatmap: P004_id065_person_processed_heatmap.png
# Saved heatmap: P004_id066_person_processed_heatmap.png
# Saved heatmap: P004_id067_person_processed_heatmap.png
# Saved heatmap: P004_id068_person_processed_heatmap.png
# Saved heatmap: P004_id069_person_processed_heatmap.png
# Saved heatmap: P004_id070_person_processed_heatmap.png
# Saved heatmap: P004_id071_person_processed_heatmap.png
# Saved heatmap: P004_id072_person_processed_heatmap.png
# Saved heatmap: P004_id073_person_processed_heatmap.png
# Saved heatmap: P004_id074_person_processed_heatmap.png
# Saved heatmap: P004_id075_person_processed_heatmap.png
# Saved heatmap: P004_id076_person_processed_heatmap.png
# Saved heatmap: P004_id077_person_processed_heatmap.png
# Saved heatmap: P004_id078_person_processed_heatmap.png
# Saved heatmap: P004_id079_person_processed_heatmap.png
# Saved heatmap: P004_id080_person_processed_heatmap.png
# Saved heatmap: P004_id081_person_processed_heatmap.png
# Saved heatmap: P004_id082_person_processed_heatmap.png
# Saved heatmap: P004_id083_person_processed_heatmap.png
# Saved heatmap: P004_id084_person_processed_heatmap.png
# Saved heatmap: P004_id085_person_processed_heatmap.png
# Saved heatmap: P004_id086_person_processed_heatmap.png
# Saved heatmap: P004_id087_person_processed_heatmap.png
# Saved heatmap: P004_id088_politik_processed_heatmap.png
# Saved heatmap: P004_id089_politik_processed_heatmap.png
# Saved heatmap: P004_id090_politik_ncc_processed_heatmap.png
# Saved heatmap: P004_id091_politik_ncc_processed_heatmap.png
# Saved heatmap: P004_id092_politik_processed_heatmap.png
# Saved heatmap: P004_id093_politik_processed_heatmap.png
# Saved heatmap: P004_id094_politik_processed_heatmap.png
# Saved heatmap: P004_id095_politik_processed_heatmap.png
# Saved heatmap: P004_id096_politik_processed_heatmap.png
# Saved heatmap: P004_id097_politik_processed_heatmap.png
# Saved heatmap: P004_id098_politik_processed_heatmap.png
# Saved heatmap: P004_id099_politik_processed_heatmap.png
# Saved heatmap: P004_id100_politik_processed_heatmap.png
# Saved heatmap: P004_id101_politik_processed_heatmap.png
# Saved heatmap: P004_id102_politik_processed_heatmap.png
# Saved heatmap: P004_id103_politik_processed_heatmap.png
# Saved heatmap: P004_id104_politik_processed_heatmap.png
# Saved heatmap: P004_id105_politik_processed_heatmap.png
# Saved heatmap: P004_id106_textigm_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id107_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id108_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id109_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id110_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id111_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id112_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id113_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id114_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id115_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id116_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id117_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id118_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id119_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id120_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id121_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id122_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id123_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id124_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id125_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P004_id126_text_politik_processed_heatmap.png
# Saved heatmap: P004_id127_textimg_ncc_processed_heatmap.png
# Saved heatmap: P004_id128_textimg_processed_heatmap.png
# Saved heatmap: P004_id129_textimg_ort_processed_heatmap.png
# Saved heatmap: P004_id130_textimg_ort_processed_heatmap.png
# Saved heatmap: P004_id131_textimg_person_processed_heatmap.png
# Saved heatmap: P004_id132_textimg_person_ncc_processed_heatmap.png
# Saved heatmap: P004_id133_textimg_person_ncc_processed_heatmap.png
# Saved heatmap: P004_id134_textimg_person_politik_ncc_processed_heatmap.png
# Saved heatmap: P004_id135_textimg_politik_processed_heatmap.png
# Saved heatmap: P004_id136_textimg_politik_processed_heatmap.png
# Saved heatmap: P004_id137_textimg_politik_processed_heatmap.png
# Saved heatmap: P004_id138_textimg_politik_processed_heatmap.png
# Saved heatmap: P004_id139_textimg_politik_processed_heatmap.png
# Saved heatmap: P004_id140_textimg_politik_processed_heatmap.png
# Saved heatmap: P004_id141_textimg_politik_ncc_processed_heatmap.png
# Saved heatmap: P004_id142_text_processed_heatmap.png
# Saved heatmap: P004_id143_text_processed_heatmap.png
# Saved heatmap: P004_id144_text_processed_heatmap.png
# Saved heatmap: P004_id146_processed_heatmap.png
# Saved heatmap: P004_id147_text_ncc_processed_heatmap.png
# Saved heatmap: P004_id148_text_ncc_processed_heatmap.png
# Saved heatmap: P004_id149_text_ncc_processed_heatmap.png
# Saved heatmap: P004_id150_text_ncc_processed_heatmap.png
# Saved heatmap: P004_id151_text_ncc_processed_heatmap.png
# Saved heatmap: P004_id152_text_ncc_processed_heatmap.png
# Saved heatmap: P004_id153_text_ncc_processed_heatmap.png
# Saved heatmap: P005_id001_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id002_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id003_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id004_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id005_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id006_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id007_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id008_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id009_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id010_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id011_ort_processed_heatmap.png
# Saved heatmap: P005_id012_ort_processed_heatmap.png
# Saved heatmap: P005_id013_ort_processed_heatmap.png
# Saved heatmap: P005_id014_ort_processed_heatmap.png
# Saved heatmap: P005_id015_ort_processed_heatmap.png
# Saved heatmap: P005_id016_ort_processed_heatmap.png
# Saved heatmap: P005_id017_ort_processed_heatmap.png
# Saved heatmap: P005_id018_ort_processed_heatmap.png
# Saved heatmap: P005_id019_ort_processed_heatmap.png
# Saved heatmap: P005_id020_ort_processed_heatmap.png
# Saved heatmap: P005_id021_ort_processed_heatmap.png
# Saved heatmap: P005_id022_ort_processed_heatmap.png
# Saved heatmap: P005_id023_ort_processed_heatmap.png
# Saved heatmap: P005_id024_ort_processed_heatmap.png
# Saved heatmap: P005_id025_ort_processed_heatmap.png
# Saved heatmap: P005_id026_ort_processed_heatmap.png
# Saved heatmap: P005_id027_ort_processed_heatmap.png
# Saved heatmap: P005_id028_ort_processed_heatmap.png
# Saved heatmap: P005_id029_ort_processed_heatmap.png
# Saved heatmap: P005_id030_ort_processed_heatmap.png
# Saved heatmap: P005_id031_ort_processed_heatmap.png
# Saved heatmap: P005_id032_ort_processed_heatmap.png
# Saved heatmap: P005_id033_person_processed_heatmap.png
# Saved heatmap: P005_id034_person_processed_heatmap.png
# Saved heatmap: P005_id035_person_processed_heatmap.png
# Saved heatmap: P005_id036_person_processed_heatmap.png
# Saved heatmap: P005_id037_person_processed_heatmap.png
# Saved heatmap: P005_id038_person_processed_heatmap.png
# Saved heatmap: P005_id039_person_processed_heatmap.png
# Saved heatmap: P005_id040_person_processed_heatmap.png
# Saved heatmap: P005_id041_person_processed_heatmap.png
# Saved heatmap: P005_id042_person_processed_heatmap.png
# Saved heatmap: P005_id043_person_processed_heatmap.png
# Saved heatmap: P005_id044_person_processed_heatmap.png
# Saved heatmap: P005_id045_person_processed_heatmap.png
# Saved heatmap: P005_id046_person_processed_heatmap.png
# Saved heatmap: P005_id047_person_processed_heatmap.png
# Saved heatmap: P005_id048_person_processed_heatmap.png
# Saved heatmap: P005_id049_person_processed_heatmap.png
# Saved heatmap: P005_id050_person_processed_heatmap.png
# Saved heatmap: P005_id051_person_processed_heatmap.png
# Saved heatmap: P005_id052_person_processed_heatmap.png
# Saved heatmap: P005_id053_person_processed_heatmap.png
# Saved heatmap: P005_id054_person_processed_heatmap.png
# Saved heatmap: P005_id055_person_processed_heatmap.png
# Saved heatmap: P005_id056_person_processed_heatmap.png
# Saved heatmap: P005_id057_person_processed_heatmap.png
# Saved heatmap: P005_id058_person_processed_heatmap.png
# Saved heatmap: P005_id059_person_processed_heatmap.png
# Saved heatmap: P005_id060_person_processed_heatmap.png
# Saved heatmap: P005_id061_person_processed_heatmap.png
# Saved heatmap: P005_id062_person_processed_heatmap.png
# Saved heatmap: P005_id063_person_processed_heatmap.png
# Saved heatmap: P005_id064_person_processed_heatmap.png
# Saved heatmap: P005_id065_person_processed_heatmap.png
# Saved heatmap: P005_id066_person_processed_heatmap.png
# Saved heatmap: P005_id067_person_processed_heatmap.png
# Saved heatmap: P005_id068_person_processed_heatmap.png
# Saved heatmap: P005_id069_person_processed_heatmap.png
# Saved heatmap: P005_id070_person_processed_heatmap.png
# Saved heatmap: P005_id071_person_processed_heatmap.png
# Saved heatmap: P005_id073_person_processed_heatmap.png
# Saved heatmap: P005_id074_person_processed_heatmap.png
# Saved heatmap: P005_id075_person_processed_heatmap.png
# Saved heatmap: P005_id076_person_processed_heatmap.png
# Saved heatmap: P005_id077_person_processed_heatmap.png
# Saved heatmap: P005_id078_person_processed_heatmap.png
# Saved heatmap: P005_id079_person_processed_heatmap.png
# Saved heatmap: P005_id080_person_processed_heatmap.png
# Saved heatmap: P005_id081_person_processed_heatmap.png
# Saved heatmap: P005_id082_person_processed_heatmap.png
# Saved heatmap: P005_id083_person_processed_heatmap.png
# Saved heatmap: P005_id084_person_processed_heatmap.png
# Saved heatmap: P005_id085_person_processed_heatmap.png
# Saved heatmap: P005_id086_person_processed_heatmap.png
# Saved heatmap: P005_id087_person_processed_heatmap.png
# Saved heatmap: P005_id088_politik_processed_heatmap.png
# Saved heatmap: P005_id089_politik_processed_heatmap.png
# Saved heatmap: P005_id090_politik_ncc_processed_heatmap.png
# Saved heatmap: P005_id091_politik_ncc_processed_heatmap.png
# Saved heatmap: P005_id092_politik_processed_heatmap.png
# Saved heatmap: P005_id093_politik_processed_heatmap.png
# Saved heatmap: P005_id094_politik_processed_heatmap.png
# Saved heatmap: P005_id095_politik_processed_heatmap.png
# Saved heatmap: P005_id096_politik_processed_heatmap.png
# Saved heatmap: P005_id097_politik_processed_heatmap.png
# Saved heatmap: P005_id098_politik_processed_heatmap.png
# Saved heatmap: P005_id099_politik_processed_heatmap.png
# Saved heatmap: P005_id100_politik_processed_heatmap.png
# Saved heatmap: P005_id101_politik_processed_heatmap.png
# Saved heatmap: P005_id102_politik_processed_heatmap.png
# Saved heatmap: P005_id103_politik_processed_heatmap.png
# Saved heatmap: P005_id104_politik_processed_heatmap.png
# Saved heatmap: P005_id105_politik_processed_heatmap.png
# Saved heatmap: P005_id106_textigm_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id107_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id108_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id109_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id110_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id111_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id112_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id113_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id114_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id115_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id116_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id117_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id118_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id119_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id120_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id121_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id122_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id123_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id124_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id125_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P005_id126_text_politik_processed_heatmap.png
# Saved heatmap: P005_id127_textimg_ncc_processed_heatmap.png
# Saved heatmap: P005_id128_textimg_processed_heatmap.png
# Saved heatmap: P005_id129_textimg_ort_processed_heatmap.png
# Saved heatmap: P005_id130_textimg_ort_processed_heatmap.png
# Saved heatmap: P005_id131_textimg_person_processed_heatmap.png
# Saved heatmap: P005_id132_textimg_person_ncc_processed_heatmap.png
# Saved heatmap: P005_id133_textimg_person_ncc_processed_heatmap.png
# Saved heatmap: P005_id134_textimg_person_politik_ncc_processed_heatmap.png
# Saved heatmap: P005_id135_textimg_politik_processed_heatmap.png
# Saved heatmap: P005_id136_textimg_politik_processed_heatmap.png
# Saved heatmap: P005_id137_textimg_politik_processed_heatmap.png
# Saved heatmap: P005_id138_textimg_politik_processed_heatmap.png
# Saved heatmap: P005_id139_textimg_politik_processed_heatmap.png
# Saved heatmap: P005_id140_textimg_politik_processed_heatmap.png
# Saved heatmap: P005_id141_textimg_politik_ncc_processed_heatmap.png
# Saved heatmap: P005_id142_text_processed_heatmap.png
# Saved heatmap: P005_id143_text_processed_heatmap.png
# Saved heatmap: P005_id144_text_processed_heatmap.png
# Saved heatmap: P005_id146_processed_heatmap.png
# Saved heatmap: P005_id147_text_ncc_processed_heatmap.png
# Saved heatmap: P005_id148_text_ncc_processed_heatmap.png
# Saved heatmap: P005_id149_text_ncc_processed_heatmap.png
# Saved heatmap: P005_id150_text_ncc_processed_heatmap.png
# Saved heatmap: P005_id151_text_ncc_processed_heatmap.png
# Saved heatmap: P005_id152_text_ncc_processed_heatmap.png
# Saved heatmap: P005_id153_text_ncc_processed_heatmap.png
# Saved heatmap: P006_id001_meme_ncc_processed_heatmap.png
# Saved heatmap: P006_id002_meme_ncc_processed_heatmap.png
# Saved heatmap: P006_id003_meme_ncc_processed_heatmap.png
# Saved heatmap: P006_id004_meme_ncc_processed_heatmap.png
# Saved heatmap: P006_id005_meme_ncc_processed_heatmap.png
# Saved heatmap: P006_id006_meme_ncc_processed_heatmap.png
# Saved heatmap: P006_id007_meme_ncc_processed_heatmap.png
# Saved heatmap: P006_id008_meme_ncc_processed_heatmap.png
# Saved heatmap: P006_id009_meme_ncc_processed_heatmap.png
# Saved heatmap: P006_id010_meme_ncc_processed_heatmap.png
# Saved heatmap: P006_id011_ort_processed_heatmap.png
# Saved heatmap: P006_id012_ort_processed_heatmap.png
# Saved heatmap: P006_id013_ort_processed_heatmap.png
# Saved heatmap: P006_id014_ort_processed_heatmap.png
# Saved heatmap: P006_id015_ort_processed_heatmap.png
# Saved heatmap: P006_id016_ort_processed_heatmap.png
# Saved heatmap: P006_id017_ort_processed_heatmap.png
# Saved heatmap: P006_id019_ort_processed_heatmap.png
# Saved heatmap: P006_id020_ort_processed_heatmap.png
# Saved heatmap: P006_id021_ort_processed_heatmap.png
# Saved heatmap: P006_id022_ort_processed_heatmap.png
# Saved heatmap: P006_id023_ort_processed_heatmap.png
# Saved heatmap: P006_id024_ort_processed_heatmap.png
# Saved heatmap: P006_id025_ort_processed_heatmap.png
# Saved heatmap: P006_id026_ort_processed_heatmap.png
# Saved heatmap: P006_id027_ort_processed_heatmap.png
# Saved heatmap: P006_id028_ort_processed_heatmap.png
# Saved heatmap: P006_id029_ort_processed_heatmap.png
# Saved heatmap: P006_id030_ort_processed_heatmap.png
# Saved heatmap: P006_id031_ort_processed_heatmap.png
# Saved heatmap: P006_id032_ort_processed_heatmap.png
# Saved heatmap: P006_id033_person_processed_heatmap.png
# Saved heatmap: P006_id034_person_processed_heatmap.png
# Saved heatmap: P006_id035_person_processed_heatmap.png
# Saved heatmap: P006_id036_person_processed_heatmap.png
# Saved heatmap: P006_id037_person_processed_heatmap.png
# Saved heatmap: P006_id038_person_processed_heatmap.png
# Saved heatmap: P006_id039_person_processed_heatmap.png
# Saved heatmap: P006_id040_person_processed_heatmap.png
# Saved heatmap: P006_id041_person_processed_heatmap.png
# Saved heatmap: P006_id042_person_processed_heatmap.png
# Saved heatmap: P006_id043_person_processed_heatmap.png
# Saved heatmap: P006_id044_person_processed_heatmap.png
# Saved heatmap: P006_id045_person_processed_heatmap.png
# Saved heatmap: P006_id046_person_processed_heatmap.png
# Saved heatmap: P006_id047_person_processed_heatmap.png
# Saved heatmap: P006_id048_person_processed_heatmap.png
# Saved heatmap: P006_id049_person_processed_heatmap.png
# Saved heatmap: P006_id050_person_processed_heatmap.png
# Saved heatmap: P006_id051_person_processed_heatmap.png
# Saved heatmap: P006_id052_person_processed_heatmap.png
# Saved heatmap: P006_id053_person_processed_heatmap.png
# Saved heatmap: P006_id054_person_processed_heatmap.png
# Saved heatmap: P006_id055_person_processed_heatmap.png
# Saved heatmap: P006_id056_person_processed_heatmap.png
# Saved heatmap: P006_id057_person_processed_heatmap.png
# Saved heatmap: P006_id058_person_processed_heatmap.png
# Saved heatmap: P006_id059_person_processed_heatmap.png
# Saved heatmap: P006_id060_person_processed_heatmap.png
# Saved heatmap: P006_id061_person_processed_heatmap.png
# Saved heatmap: P006_id062_person_processed_heatmap.png
# Saved heatmap: P006_id063_person_processed_heatmap.png
# Saved heatmap: P006_id064_person_processed_heatmap.png
# Saved heatmap: P006_id065_person_processed_heatmap.png
# Saved heatmap: P006_id066_person_processed_heatmap.png
# Saved heatmap: P006_id067_person_processed_heatmap.png
# Saved heatmap: P006_id068_person_processed_heatmap.png
# Saved heatmap: P006_id069_person_processed_heatmap.png
# Saved heatmap: P006_id070_person_processed_heatmap.png
# Saved heatmap: P006_id071_person_processed_heatmap.png
# Saved heatmap: P006_id072_person_processed_heatmap.png
# Saved heatmap: P006_id073_person_processed_heatmap.png
# Saved heatmap: P006_id074_person_processed_heatmap.png
# Saved heatmap: P006_id075_person_processed_heatmap.png
# Saved heatmap: P006_id076_person_processed_heatmap.png
# Saved heatmap: P006_id077_person_processed_heatmap.png
# Saved heatmap: P006_id078_person_processed_heatmap.png
# Saved heatmap: P006_id079_person_processed_heatmap.png
# Saved heatmap: P006_id080_person_processed_heatmap.png
# Saved heatmap: P006_id081_person_processed_heatmap.png
# Saved heatmap: P006_id082_person_processed_heatmap.png
# Saved heatmap: P006_id083_person_processed_heatmap.png
# Saved heatmap: P006_id084_person_processed_heatmap.png
# Saved heatmap: P006_id085_person_processed_heatmap.png
# Saved heatmap: P006_id086_person_processed_heatmap.png
# Saved heatmap: P006_id087_person_processed_heatmap.png
# Saved heatmap: P006_id088_politik_processed_heatmap.png
# Saved heatmap: P006_id089_politik_processed_heatmap.png
# ...
# Saved heatmap: P053_id029_ort_processed_heatmap.png
# Saved heatmap: P053_id030_ort_processed_heatmap.png
# Saved heatmap: P053_id031_ort_processed_heatmap.png
# Saved heatmap: P053_id032_ort_processed_heatmap.png
# Saved heatmap: P053_id033_person_processed_heatmap.png
# Saved heatmap: P053_id034_person_processed_heatmap.png
# Saved heatmap: P053_id035_person_processed_heatmap.png
# Saved heatmap: P053_id036_person_processed_heatmap.png
# Saved heatmap: P053_id037_person_processed_heatmap.png
# Saved heatmap: P053_id038_person_processed_heatmap.png
# Saved heatmap: P053_id039_person_processed_heatmap.png
# Saved heatmap: P053_id040_person_processed_heatmap.png
# Saved heatmap: P053_id041_person_processed_heatmap.png
# Saved heatmap: P053_id042_person_processed_heatmap.png
# Saved heatmap: P053_id043_person_processed_heatmap.png
# Saved heatmap: P053_id044_person_processed_heatmap.png
# Saved heatmap: P053_id045_person_processed_heatmap.png
# Saved heatmap: P053_id046_person_processed_heatmap.png
# Saved heatmap: P053_id047_person_processed_heatmap.png
# Saved heatmap: P053_id048_person_processed_heatmap.png
# Saved heatmap: P053_id049_person_processed_heatmap.png
# Saved heatmap: P053_id050_person_processed_heatmap.png
# Saved heatmap: P053_id051_person_processed_heatmap.png
# Saved heatmap: P053_id052_person_processed_heatmap.png
# Saved heatmap: P053_id053_person_processed_heatmap.png
# Saved heatmap: P053_id054_person_processed_heatmap.png
# Saved heatmap: P053_id055_person_processed_heatmap.png
# Saved heatmap: P053_id056_person_processed_heatmap.png
# Saved heatmap: P053_id057_person_processed_heatmap.png
# Saved heatmap: P053_id058_person_processed_heatmap.png
# Saved heatmap: P053_id059_person_processed_heatmap.png
# Saved heatmap: P053_id060_person_processed_heatmap.png
# Saved heatmap: P053_id061_person_processed_heatmap.png
# Saved heatmap: P053_id062_person_processed_heatmap.png
# Saved heatmap: P053_id063_person_processed_heatmap.png
# Saved heatmap: P053_id064_person_processed_heatmap.png
# Saved heatmap: P053_id065_person_processed_heatmap.png
# Saved heatmap: P053_id066_person_processed_heatmap.png
# Saved heatmap: P053_id067_person_processed_heatmap.png
# Saved heatmap: P053_id068_person_processed_heatmap.png
# Saved heatmap: P053_id069_person_processed_heatmap.png
# Saved heatmap: P053_id070_person_processed_heatmap.png
# Saved heatmap: P053_id071_person_processed_heatmap.png
# Saved heatmap: P053_id072_person_processed_heatmap.png
# Saved heatmap: P053_id073_person_processed_heatmap.png
# Saved heatmap: P053_id074_person_processed_heatmap.png
# Saved heatmap: P053_id075_person_processed_heatmap.png
# Saved heatmap: P053_id076_person_processed_heatmap.png
# Saved heatmap: P053_id077_person_processed_heatmap.png
# Saved heatmap: P053_id078_person_processed_heatmap.png
# Saved heatmap: P053_id079_person_processed_heatmap.png
# Saved heatmap: P053_id080_person_processed_heatmap.png
# Saved heatmap: P053_id081_person_processed_heatmap.png
# Saved heatmap: P053_id082_person_processed_heatmap.png
# Saved heatmap: P053_id083_person_processed_heatmap.png
# Saved heatmap: P053_id084_person_processed_heatmap.png
# Saved heatmap: P053_id085_person_processed_heatmap.png
# Saved heatmap: P053_id086_person_processed_heatmap.png
# Saved heatmap: P053_id087_person_processed_heatmap.png
# Saved heatmap: P053_id088_politik_processed_heatmap.png
# Saved heatmap: P053_id089_politik_processed_heatmap.png
# Saved heatmap: P053_id090_politik_ncc_processed_heatmap.png
# Saved heatmap: P053_id091_politik_ncc_processed_heatmap.png
# Saved heatmap: P053_id092_politik_processed_heatmap.png
# Saved heatmap: P053_id093_politik_processed_heatmap.png
# Saved heatmap: P053_id094_politik_processed_heatmap.png
# Saved heatmap: P053_id095_politik_processed_heatmap.png
# Saved heatmap: P053_id096_politik_processed_heatmap.png
# Saved heatmap: P053_id097_politik_processed_heatmap.png
# Saved heatmap: P053_id098_politik_processed_heatmap.png
# Saved heatmap: P053_id099_politik_processed_heatmap.png
# Saved heatmap: P053_id100_politik_processed_heatmap.png
# Saved heatmap: P053_id101_politik_processed_heatmap.png
# Saved heatmap: P053_id102_politik_processed_heatmap.png
# Saved heatmap: P053_id103_politik_processed_heatmap.png
# Saved heatmap: P053_id104_politik_processed_heatmap.png
# Saved heatmap: P053_id105_politik_processed_heatmap.png
# Saved heatmap: P053_id106_textigm_meme_ncc_processed_heatmap.png
# Saved heatmap: P053_id107_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P053_id108_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P053_id109_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P053_id110_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P053_id111_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P053_id112_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P053_id113_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P053_id114_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P053_id115_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P053_id116_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P053_id117_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P053_id118_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P053_id119_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P053_id120_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P053_id121_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P053_id122_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P053_id123_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P053_id124_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P053_id125_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P053_id126_text_politik_processed_heatmap.png
# Saved heatmap: P053_id127_textimg_ncc_processed_heatmap.png
# Saved heatmap: P053_id128_textimg_processed_heatmap.png
# Saved heatmap: P053_id129_textimg_ort_processed_heatmap.png
# Saved heatmap: P053_id130_textimg_ort_processed_heatmap.png
# Saved heatmap: P053_id131_textimg_person_processed_heatmap.png
# Saved heatmap: P053_id132_textimg_person_ncc_processed_heatmap.png
# Saved heatmap: P053_id133_textimg_person_ncc_processed_heatmap.png
# Saved heatmap: P053_id134_textimg_person_politik_ncc_processed_heatmap.png
# Saved heatmap: P053_id135_textimg_politik_processed_heatmap.png
# Saved heatmap: P053_id136_textimg_politik_processed_heatmap.png
# Saved heatmap: P053_id137_textimg_politik_processed_heatmap.png
# Saved heatmap: P053_id138_textimg_politik_processed_heatmap.png
# Saved heatmap: P053_id139_textimg_politik_processed_heatmap.png
# Saved heatmap: P053_id140_textimg_politik_processed_heatmap.png
# Saved heatmap: P053_id141_textimg_politik_ncc_processed_heatmap.png
# Skipping P053_id142_text_processed_fixations.csv: file is empty or has no header
# Saved heatmap: P053_id143_text_processed_heatmap.png
# Saved heatmap: P053_id144_text_processed_heatmap.png
# Saved heatmap: P053_id146_processed_heatmap.png
# Saved heatmap: P053_id147_text_ncc_processed_heatmap.png
# Saved heatmap: P053_id148_text_ncc_processed_heatmap.png
# Saved heatmap: P053_id149_text_ncc_processed_heatmap.png
# Saved heatmap: P053_id150_text_ncc_processed_heatmap.png
# Saved heatmap: P053_id151_text_ncc_processed_heatmap.png
# Saved heatmap: P053_id152_text_ncc_processed_heatmap.png
# Saved heatmap: P053_id153_text_ncc_processed_heatmap.png
# Saved heatmap: P054_id001_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id002_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id003_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id004_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id005_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id006_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id007_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id008_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id009_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id010_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id011_ort_processed_heatmap.png
# Saved heatmap: P054_id012_ort_processed_heatmap.png
# Saved heatmap: P054_id013_ort_processed_heatmap.png
# Saved heatmap: P054_id014_ort_processed_heatmap.png
# Saved heatmap: P054_id015_ort_processed_heatmap.png
# Saved heatmap: P054_id016_ort_processed_heatmap.png
# Saved heatmap: P054_id017_ort_processed_heatmap.png
# Saved heatmap: P054_id018_ort_processed_heatmap.png
# Skipping P054_id019_ort_processed_fixations.csv: file is empty or has no header
# Saved heatmap: P054_id020_ort_processed_heatmap.png
# Saved heatmap: P054_id021_ort_processed_heatmap.png
# Saved heatmap: P054_id022_ort_processed_heatmap.png
# Saved heatmap: P054_id023_ort_processed_heatmap.png
# Saved heatmap: P054_id024_ort_processed_heatmap.png
# Saved heatmap: P054_id025_ort_processed_heatmap.png
# Saved heatmap: P054_id026_ort_processed_heatmap.png
# Saved heatmap: P054_id027_ort_processed_heatmap.png
# Saved heatmap: P054_id028_ort_processed_heatmap.png
# Saved heatmap: P054_id029_ort_processed_heatmap.png
# Saved heatmap: P054_id030_ort_processed_heatmap.png
# Saved heatmap: P054_id031_ort_processed_heatmap.png
# Saved heatmap: P054_id032_ort_processed_heatmap.png
# Saved heatmap: P054_id033_person_processed_heatmap.png
# Saved heatmap: P054_id034_person_processed_heatmap.png
# Saved heatmap: P054_id035_person_processed_heatmap.png
# Saved heatmap: P054_id036_person_processed_heatmap.png
# Saved heatmap: P054_id037_person_processed_heatmap.png
# Saved heatmap: P054_id038_person_processed_heatmap.png
# Saved heatmap: P054_id039_person_processed_heatmap.png
# Saved heatmap: P054_id040_person_processed_heatmap.png
# Saved heatmap: P054_id041_person_processed_heatmap.png
# Saved heatmap: P054_id042_person_processed_heatmap.png
# Saved heatmap: P054_id043_person_processed_heatmap.png
# Skipping P054_id044_person_processed_fixations.csv: file is empty or has no header
# Saved heatmap: P054_id045_person_processed_heatmap.png
# Saved heatmap: P054_id046_person_processed_heatmap.png
# Saved heatmap: P054_id047_person_processed_heatmap.png
# Saved heatmap: P054_id048_person_processed_heatmap.png
# Saved heatmap: P054_id049_person_processed_heatmap.png
# Saved heatmap: P054_id050_person_processed_heatmap.png
# Saved heatmap: P054_id051_person_processed_heatmap.png
# Saved heatmap: P054_id052_person_processed_heatmap.png
# Saved heatmap: P054_id053_person_processed_heatmap.png
# Saved heatmap: P054_id054_person_processed_heatmap.png
# Saved heatmap: P054_id055_person_processed_heatmap.png
# Saved heatmap: P054_id056_person_processed_heatmap.png
# Saved heatmap: P054_id057_person_processed_heatmap.png
# Saved heatmap: P054_id058_person_processed_heatmap.png
# Saved heatmap: P054_id059_person_processed_heatmap.png
# Saved heatmap: P054_id060_person_processed_heatmap.png
# Saved heatmap: P054_id061_person_processed_heatmap.png
# Saved heatmap: P054_id062_person_processed_heatmap.png
# Saved heatmap: P054_id063_person_processed_heatmap.png
# Saved heatmap: P054_id064_person_processed_heatmap.png
# Saved heatmap: P054_id065_person_processed_heatmap.png
# Saved heatmap: P054_id066_person_processed_heatmap.png
# Saved heatmap: P054_id067_person_processed_heatmap.png
# Saved heatmap: P054_id068_person_processed_heatmap.png
# Saved heatmap: P054_id069_person_processed_heatmap.png
# Saved heatmap: P054_id070_person_processed_heatmap.png
# Saved heatmap: P054_id071_person_processed_heatmap.png
# Saved heatmap: P054_id072_person_processed_heatmap.png
# Saved heatmap: P054_id073_person_processed_heatmap.png
# Saved heatmap: P054_id074_person_processed_heatmap.png
# Saved heatmap: P054_id075_person_processed_heatmap.png
# Saved heatmap: P054_id076_person_processed_heatmap.png
# Saved heatmap: P054_id077_person_processed_heatmap.png
# Saved heatmap: P054_id078_person_processed_heatmap.png
# Saved heatmap: P054_id079_person_processed_heatmap.png
# Saved heatmap: P054_id080_person_processed_heatmap.png
# Saved heatmap: P054_id081_person_processed_heatmap.png
# Saved heatmap: P054_id082_person_processed_heatmap.png
# Saved heatmap: P054_id083_person_processed_heatmap.png
# Saved heatmap: P054_id084_person_processed_heatmap.png
# Saved heatmap: P054_id085_person_processed_heatmap.png
# Saved heatmap: P054_id086_person_processed_heatmap.png
# Saved heatmap: P054_id087_person_processed_heatmap.png
# Saved heatmap: P054_id088_politik_processed_heatmap.png
# Saved heatmap: P054_id089_politik_processed_heatmap.png
# Saved heatmap: P054_id090_politik_ncc_processed_heatmap.png
# Saved heatmap: P054_id091_politik_ncc_processed_heatmap.png
# Saved heatmap: P054_id092_politik_processed_heatmap.png
# Saved heatmap: P054_id093_politik_processed_heatmap.png
# Saved heatmap: P054_id094_politik_processed_heatmap.png
# Saved heatmap: P054_id095_politik_processed_heatmap.png
# Saved heatmap: P054_id096_politik_processed_heatmap.png
# Saved heatmap: P054_id097_politik_processed_heatmap.png
# Saved heatmap: P054_id098_politik_processed_heatmap.png
# Saved heatmap: P054_id099_politik_processed_heatmap.png
# Saved heatmap: P054_id100_politik_processed_heatmap.png
# Saved heatmap: P054_id101_politik_processed_heatmap.png
# Saved heatmap: P054_id102_politik_processed_heatmap.png
# Saved heatmap: P054_id103_politik_processed_heatmap.png
# Saved heatmap: P054_id104_politik_processed_heatmap.png
# Saved heatmap: P054_id105_politik_processed_heatmap.png
# Saved heatmap: P054_id106_textigm_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id107_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id108_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id109_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id110_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id111_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id112_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id113_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id114_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id115_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id116_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id117_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id118_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id119_textimg_meme_ncc_processed_heatmap.png
# Skipping P054_id120_textimg_meme_ncc_processed_fixations.csv: file is empty or has no header
# Saved heatmap: P054_id121_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id122_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id123_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id124_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id125_textimg_meme_ncc_processed_heatmap.png
# Saved heatmap: P054_id126_text_politik_processed_heatmap.png
# Saved heatmap: P054_id127_textimg_ncc_processed_heatmap.png
# Saved heatmap: P054_id128_textimg_processed_heatmap.png
# Saved heatmap: P054_id129_textimg_ort_processed_heatmap.png
# Saved heatmap: P054_id130_textimg_ort_processed_heatmap.png
# Saved heatmap: P054_id131_textimg_person_processed_heatmap.png
# Saved heatmap: P054_id132_textimg_person_ncc_processed_heatmap.png
# Saved heatmap: P054_id133_textimg_person_ncc_processed_heatmap.png
# Saved heatmap: P054_id134_textimg_person_politik_ncc_processed_heatmap.png
# Saved heatmap: P054_id135_textimg_politik_processed_heatmap.png
# Saved heatmap: P054_id136_textimg_politik_processed_heatmap.png
# Saved heatmap: P054_id137_textimg_politik_processed_heatmap.png
# Saved heatmap: P054_id138_textimg_politik_processed_heatmap.png
# Saved heatmap: P054_id139_textimg_politik_processed_heatmap.png
# Saved heatmap: P054_id140_textimg_politik_processed_heatmap.png
# Saved heatmap: P054_id141_textimg_politik_ncc_processed_heatmap.png
# Saved heatmap: P054_id142_text_processed_heatmap.png
# Saved heatmap: P054_id143_text_processed_heatmap.png
# Saved heatmap: P054_id144_text_processed_heatmap.png
# Skipping P054_id146_processed_fixations.csv: file is empty or has no header
# Saved heatmap: P054_id147_text_ncc_processed_heatmap.png
# Saved heatmap: P054_id148_text_ncc_processed_heatmap.png
# Saved heatmap: P054_id149_text_ncc_processed_heatmap.png
# Saved heatmap: P054_id150_text_ncc_processed_heatmap.png
# Saved heatmap: P054_id151_text_ncc_processed_heatmap.png
# Saved heatmap: P054_id152_text_ncc_processed_heatmap.png
# Saved heatmap: P054_id153_text_ncc_processed_heatmap.png

# %%
import os
import glob

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
from scipy.cluster.hierarchy import linkage, fcluster
from numpy.linalg import svd
from pandas.errors import EmptyDataError

def make_heatmap(fix_df, size=800, bins=50, sigma=2):
    x, y = fix_df['x'], fix_df['y']
    H, _, _ = np.histogram2d(
        y, x,
        bins=bins,
        range=[[0, size], [0, size]],
        density=False
    )
    H = gaussian_filter(H, sigma=sigma)
    return H / H.max() if H.max() > 0 else H

def pca_manual(X, n_components=2):
    Xc = X - X.mean(axis=0)
    U, S, VT = svd(Xc, full_matrices=False)
    return Xc.dot(VT.T[:, :n_components])

def cluster_hierarchy(X_red, k=3):
    Z = linkage(X_red, method='ward')
    labels = fcluster(Z, t=k, criterion='maxclust') - 1
    return labels

# === Workflow ===
fix_folder = "processed/fixations"
heatmaps   = []
ids        = []

for path in glob.glob(os.path.join(fix_folder, "*_fixations.csv")):
    subj = os.path.basename(path).replace("_fixations.csv", "")
    
    # 1) Datei nur einlesen, wenn sie tatsächlich Header + Daten enthält
    try:
        df = pd.read_csv(path)
    except EmptyDataError:
        print(f"Skipping {subj}: file empty or no header")
        continue
    
    if df.empty:
        print(f"Skipping {subj}: no fixation rows")
        continue

    # 2) Heatmap-Feature erzeugen
    H = make_heatmap(df)
    heatmaps.append(H.flatten())
    ids.append(subj)

if not heatmaps:
    raise RuntimeError("Keine gültigen Fixations-Dateien gefunden.")

X = np.vstack(heatmaps)
X_red = pca_manual(X, n_components=2)

# 3) Clustering (hier k=3 als Beispiel)
labels = cluster_hierarchy(X_red, k=3)

# === Visualisierung ===

# 3a) 2D-PCA-Scatter
plt.figure(figsize=(6,5))
for lbl in np.unique(labels):
    idx = labels == lbl
    plt.scatter(X_red[idx,0], X_red[idx,1], label=f"Cluster {lbl+1}", alpha=0.7)
plt.xlabel("PC1"); plt.ylabel("PC2")
plt.legend(); plt.title("Teilnehmer im 2D-PCA-Raum")
plt.show()

# 3b) Durchschnitts-Heatmap pro Cluster
n_clusters = labels.max() + 1
fig, axes = plt.subplots(1, n_clusters, figsize=(3*n_clusters,3))
bins = int(np.sqrt(heatmaps[0].size))
for c in range(n_clusters):
    group_idx = [i for i, lab in enumerate(labels) if lab == c]
    mean_H = np.mean([heatmaps[i].reshape((bins, bins)) for i in group_idx], axis=0)
    ax = axes[c] if n_clusters > 1 else axes
    ax.imshow(mean_H, origin='lower', extent=[0,800,0,800])
    ax.set_title(f"Cluster {c+1}")
    ax.axis('off')
fig.suptitle("Mittel-Heatmaps pro Cluster")
plt.show()
# Out:
# Skipping P013_id012_ort_processed: file empty or no header
# Skipping P013_id015_ort_processed: file empty or no header
# Skipping P013_id022_ort_processed: file empty or no header
# Skipping P013_id025_ort_processed: file empty or no header
# Skipping P013_id032_ort_processed: file empty or no header
# Skipping P013_id033_person_processed: file empty or no header
# Skipping P013_id045_person_processed: file empty or no header
# Skipping P013_id047_person_processed: file empty or no header
# Skipping P013_id062_person_processed: file empty or no header
# Skipping P013_id077_person_processed: file empty or no header
# Skipping P013_id104_politik_processed: file empty or no header
# Skipping P013_id115_textimg_meme_ncc_processed: file empty or no header
# Skipping P013_id123_textimg_meme_ncc_processed: file empty or no header
# Skipping P013_id126_text_politik_processed: file empty or no header
# Skipping P013_id129_textimg_ort_processed: file empty or no header
# Skipping P013_id135_textimg_politik_processed: file empty or no header
# Skipping P013_id142_text_processed: file empty or no header
# Skipping P013_id144_text_processed: file empty or no header
# Skipping P016_id003_meme_ncc_processed: file empty or no header
# Skipping P016_id021_ort_processed: file empty or no header
# Skipping P016_id030_ort_processed: file empty or no header
# Skipping P016_id038_person_processed: file empty or no header
# Skipping P016_id040_person_processed: file empty or no header
# Skipping P016_id043_person_processed: file empty or no header
# Skipping P016_id049_person_processed: file empty or no header
# Skipping P016_id052_person_processed: file empty or no header
# Skipping P016_id064_person_processed: file empty or no header
# Skipping P016_id072_person_processed: file empty or no header
# Skipping P016_id085_person_processed: file empty or no header
# Skipping P016_id086_person_processed: file empty or no header
# Skipping P016_id095_politik_processed: file empty or no header
# Skipping P016_id101_politik_processed: file empty or no header
# Skipping P016_id103_politik_processed: file empty or no header
# Skipping P016_id110_textimg_meme_ncc_processed: file empty or no header
# Skipping P016_id114_textimg_meme_ncc_processed: file empty or no header
# Skipping P016_id117_textimg_meme_ncc_processed: file empty or no header
# Skipping P016_id137_textimg_politik_processed: file empty or no header
# Skipping P016_id143_text_processed: file empty or no header
# Skipping P016_id151_text_ncc_processed: file empty or no header
# Skipping P025_id066_person_processed: file empty or no header
# Skipping P027_id060_person_processed: file empty or no header
# Skipping P035_id069_person_processed: file empty or no header
# Skipping P038_id152_text_ncc_processed: file empty or no header
# Skipping P040_id021_ort_processed: file empty or no header
# Skipping P040_id023_ort_processed: file empty or no header
# Skipping P040_id027_ort_processed: file empty or no header
# Skipping P040_id029_ort_processed: file empty or no header
# Skipping P040_id033_person_processed: file empty or no header
# Skipping P040_id035_person_processed: file empty or no header
# Skipping P040_id040_person_processed: file empty or no header
# Skipping P040_id042_person_processed: file empty or no header
# Skipping P040_id046_person_processed: file empty or no header
# Skipping P040_id053_person_processed: file empty or no header
# Skipping P040_id065_person_processed: file empty or no header
# Skipping P040_id072_person_processed: file empty or no header
# Skipping P040_id079_person_processed: file empty or no header
# Skipping P040_id082_person_processed: file empty or no header
# Skipping P040_id086_person_processed: file empty or no header
# Skipping P040_id093_politik_processed: file empty or no header
# Skipping P040_id098_politik_processed: file empty or no header
# Skipping P040_id101_politik_processed: file empty or no header
# Skipping P040_id105_politik_processed: file empty or no header
# Skipping P040_id109_textimg_meme_ncc_processed: file empty or no header
# Skipping P040_id128_textimg_processed: file empty or no header
# Skipping P040_id130_textimg_ort_processed: file empty or no header
# Skipping P040_id146_processed: file empty or no header
# Skipping P040_id153_text_ncc_processed: file empty or no header
# Skipping P046_id151_text_ncc_processed: file empty or no header
# Skipping P048_id042_person_processed: file empty or no header
# Skipping P048_id044_person_processed: file empty or no header
# Skipping P048_id056_person_processed: file empty or no header
# Skipping P048_id081_person_processed: file empty or no header
# Skipping P048_id114_textimg_meme_ncc_processed: file empty or no header
# Skipping P048_id118_textimg_meme_ncc_processed: file empty or no header
# Skipping P048_id135_textimg_politik_processed: file empty or no header
# Skipping P048_id141_textimg_politik_ncc_processed: file empty or no header
# Skipping P053_id142_text_processed: file empty or no header
# Skipping P054_id019_ort_processed: file empty or no header
# Skipping P054_id044_person_processed: file empty or no header
# Skipping P054_id120_textimg_meme_ncc_processed: file empty or no header
# Skipping P054_id146_processed: file empty or no header
